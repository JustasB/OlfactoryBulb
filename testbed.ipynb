# %%
from olfactorybulb import OlfactoryBulb as OB

# %%
ob = OB()

# %%
ob.build()

# %%
ob.setup_simulation()

# %%
ob.run()
# Out:
# Creating network of 4 cell populations on 1 hosts...
#   Number of cells on node 0: 8
#   Done; cell creation time = 0.00 s.
# Making connections...
#   Number of connections on node 0: 24
#   Done; cell connection time = 0.00 s.
# Adding stims...
#   Number of stims on node 0: 2
#   Done; cell stims creation time = 0.00 s.
# Recording 2 traces of 1 types on node 0
#
# Running simulation for 1000 ms...
#   Done; run time = 0.91 s; real-time ratio: 1.10.
#
# Gathering data...
#   Done; gather time = 0.01 s.
#
# Analyzing...
#   Cells: 8
#   Connections: 26 (3.25 per cell)
#   Spikes: 113 (14.12 Hz)
#   Simulated time: 1.0 s; 1 workers
#   Run time: 0.91 s
#   Done; saving time = 0.01 s.
# Plotting raster...
# Plotting recorded cell traces ...
# Plotting 2D representation of network cell locations and connections...
# Plotting LFP ...
# Plotting 3D cell shape ...
#   Done; plotting time = 1.61 s
#
# Total time = 2.55 s
