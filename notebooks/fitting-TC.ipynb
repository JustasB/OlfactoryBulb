# %%
import os; os.chdir('..')
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
import sys
cell_id = sys.argv[1] if len(sys.argv) > 1 and sys.argv[1].isdigit() else 1
print(cell_id)
# Out:
# 1

# %%
fitter = CellFitter(cell_type="tc", fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells.TC"+str(cell_id))
# Out:
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC1')

# %%
import prev_ob_models.Birgiolas2020.fitting

# %%
prev_ob_models.Birgiolas2020.fitting.SHOW_ERRORS = False

# %%
#fitter.clear_cache()
fitter.fit(int(multiprocessing.cpu_count()*1.5), 200)
# Out:
# ('STARTED GEN', 'ZERO', 'size', 4)
# ('DONE with', 1, 'of', 4, 'of GEN', 'ZERO', 'with Fitness', '4.61')
# ('DONE with', 2, 'of', 4, 'of GEN', 'ZERO', 'with Fitness', '4.61')
# ('DONE with', 3, 'of', 4, 'of GEN', 'ZERO', 'with Fitness', '4.61')
# ('DONE with', 4, 'of', 4, 'of GEN', 'ZERO', 'with Fitness', '4.61')
# ('GEN', 1, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '1', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '1', 'with Fitness', '31.49')
# ('DONE with', 2, 'of', 24, 'of GEN', '1', 'with Fitness', '7.62')
# ('DONE with', 3, 'of', 24, 'of GEN', '1', 'with Fitness', '20.22')
# ('DONE with', 4, 'of', 24, 'of GEN', '1', 'with Fitness', '18.07')
# ('DONE with', 5, 'of', 24, 'of GEN', '1', 'with Fitness', '11.85')
# ('DONE with', 6, 'of', 24, 'of GEN', '1', 'with Fitness', '18.33')
# ('DONE with', 7, 'of', 24, 'of GEN', '1', 'with Fitness', '5.16')
# ('DONE with', 8, 'of', 24, 'of GEN', '1', 'with Fitness', '4.61')
# ('DONE with', 9, 'of', 24, 'of GEN', '1', 'with Fitness', '5.36')
# ('DONE with', 10, 'of', 24, 'of GEN', '1', 'with Fitness', '4.61')
# ('DONE with', 11, 'of', 24, 'of GEN', '1', 'with Fitness', '18.29')
# ('DONE with', 12, 'of', 24, 'of GEN', '1', 'with Fitness', '6.24')
# ('DONE with', 13, 'of', 24, 'of GEN', '1', 'with Fitness', '4.61')
# ('DONE with', 14, 'of', 24, 'of GEN', '1', 'with Fitness', '7.80')
# ('DONE with', 15, 'of', 24, 'of GEN', '1', 'with Fitness', '5.56')
# ('DONE with', 16, 'of', 24, 'of GEN', '1', 'with Fitness', '4.94')
# ('DONE with', 17, 'of', 24, 'of GEN', '1', 'with Fitness', '8.61')
# ('DONE with', 18, 'of', 24, 'of GEN', '1', 'with Fitness', '4.61')
# ('DONE with', 19, 'of', 24, 'of GEN', '1', 'with Fitness', '5.20')
# ('DONE with', 20, 'of', 24, 'of GEN', '1', 'with Fitness', '90.00')
# ('DONE with', 21, 'of', 24, 'of GEN', '1', 'with Fitness', '4.72')
# ('DONE with', 22, 'of', 24, 'of GEN', '1', 'with Fitness', '6.12')
# ('DONE with', 23, 'of', 24, 'of GEN', '1', 'with Fitness', '90.00')
# ('DONE with', 24, 'of', 24, 'of GEN', '1', 'with Fitness', '5.74')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-1.6951587573349804]
# AfterHyperpolarizationTimeTest                                   -0.9654850746268636
# CellCapacitanceTest                                              -1.6455498411375695
# FISlopeTest                                                      -1.0138888888888888
# ISICVTest                                                        -0.6525853767802919
# InputResistanceTest                                              0.23084755954891215
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                1.6304991487085736
# RheobaseTest                                                      0.5175688242341911
# SagVoltageTest                                                    0.7410542946666584
# SpikeAccommodationTest                                           0.21855282588266894
# SpikeAccommodationTimeConstantTest                               -0.7484982900210381
# SpikeAmplitudeTest                                              [0.1376732637371121]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [2.1928565520285646]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 73.51% of range. Val: -63.2461627049 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.07% of range. Val: 186.603273593 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 90.29% of range. Val: 0.0902920962956 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 84.33% of range. Val: 0.0168652746685 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -63.24616270491288, -56.60436604364108, 0.0003188139654598454, 3.933167368370544, 186.60327359307794, 0.09029209629563073, 0.10671848783327488, 0.0008854398327198871, 0.008072924400407685, 0.002953503923700737, 0.00011687707963054088, -38.91275512857027, 8.010476529149849e-06, 0.016865274668460554])
# ('Best fitness:', 4.606330467551202)
# ('Generation', 1, 'out of', 200, 'COMPLETE')
# ('GEN', 2, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '2', 'size', 24)
# NEURON: variable step integrator error
#  near line 0
#  ^
#         fadvance()
#       advance()
#     step()
#   continuerun(3100)
# and others
# ('DONE with', 1, 'of', 24, 'of GEN', '2', 'with Fitness', '14.81')
# ('DONE with', 2, 'of', 24, 'of GEN', '2', 'with Fitness', '45.12')
# ('DONE with', 3, 'of', 24, 'of GEN', '2', 'with Fitness', '19.31')
# ('DONE with', 4, 'of', 24, 'of GEN', '2', 'with Fitness', '17.32')
# ('DONE with', 5, 'of', 24, 'of GEN', '2', 'with Fitness', '23.97')
# ('DONE with', 6, 'of', 24, 'of GEN', '2', 'with Fitness', '19.47')
# ('DONE with', 7, 'of', 24, 'of GEN', '2', 'with Fitness', '20.42')
# ('DONE with', 8, 'of', 24, 'of GEN', '2', 'with Fitness', '5.53')
# ('DONE with', 9, 'of', 24, 'of GEN', '2', 'with Fitness', '18.25')
# ('DONE with', 10, 'of', 24, 'of GEN', '2', 'with Fitness', '7.61')
# ('DONE with', 11, 'of', 24, 'of GEN', '2', 'with Fitness', '7.17')
# ('DONE with', 12, 'of', 24, 'of GEN', '2', 'with Fitness', '7.41')
# ('DONE with', 13, 'of', 24, 'of GEN', '2', 'with Fitness', '4.61')
# ('DONE with', 14, 'of', 24, 'of GEN', '2', 'with Fitness', '4.85')
# ('DONE with', 15, 'of', 24, 'of GEN', '2', 'with Fitness', '4.69')
# ('DONE with', 16, 'of', 24, 'of GEN', '2', 'with Fitness', '5.50')
# ('DONE with', 17, 'of', 24, 'of GEN', '2', 'with Fitness', '4.61')
# ('DONE with', 18, 'of', 24, 'of GEN', '2', 'with Fitness', '4.61')
# ('DONE with', 19, 'of', 24, 'of GEN', '2', 'with Fitness', '4.61')
# ('DONE with', 20, 'of', 24, 'of GEN', '2', 'with Fitness', '10.69')
# ('DONE with', 21, 'of', 24, 'of GEN', '2', 'with Fitness', '4.61')
# ('DONE with', 22, 'of', 24, 'of GEN', '2', 'with Fitness', '90.00')
# ('DONE with', 23, 'of', 24, 'of GEN', '2', 'with Fitness', '4.61')
# ('DONE with', 24, 'of', 24, 'of GEN', '2', 'with Fitness', '5.41')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-1.6951587573349804]
# AfterHyperpolarizationTimeTest                                   -0.9654850746268636
# CellCapacitanceTest                                              -1.6455498411375695
# FISlopeTest                                                      -1.0138888888888888
# ISICVTest                                                        -0.6525853767802919
# InputResistanceTest                                              0.23084755954891215
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                1.6304991487085736
# RheobaseTest                                                      0.5175688242341911
# SagVoltageTest                                                    0.7410542946666584
# SpikeAccommodationTest                                           0.21855282588266894
# SpikeAccommodationTimeConstantTest                               -0.7484982900210381
# SpikeAmplitudeTest                                              [0.1376732637371121]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [2.1928565520285646]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 73.51% of range. Val: -63.2461627049 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.07% of range. Val: 186.603273593 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 90.29% of range. Val: 0.0902920962956 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 84.33% of range. Val: 0.0168652746685 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -63.24616270491288, -56.60436604364108, 0.0003188139654598454, 3.933167368370544, 186.60327359307794, 0.09029209629563073, 0.10671848783327488, 0.0008854398327198871, 0.008072924400407685, 0.002953503923700737, 0.00011687707963054088, -38.91275512857027, 8.010476529149849e-06, 0.016865274668460554])
# ('Best fitness:', 4.606330467551202)
# ('Generation', 2, 'out of', 200, 'COMPLETE')
# ('GEN', 3, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '3', 'size', 24)
# NEURON: variable step integrator error
#  near line 0
#  ^
#         fadvance()
#       advance()
#     step()
#   continuerun(3100)
# and others
# ('DONE with', 1, 'of', 24, 'of GEN', '3', 'with Fitness', '19.01')
# ('DONE with', 2, 'of', 24, 'of GEN', '3', 'with Fitness', '18.30')
# ('DONE with', 3, 'of', 24, 'of GEN', '3', 'with Fitness', '19.74')
# ('DONE with', 4, 'of', 24, 'of GEN', '3', 'with Fitness', '18.24')
# ('DONE with', 5, 'of', 24, 'of GEN', '3', 'with Fitness', '18.49')
# ('DONE with', 6, 'of', 24, 'of GEN', '3', 'with Fitness', '18.42')
# ('DONE with', 7, 'of', 24, 'of GEN', '3', 'with Fitness', '4.76')
# ('DONE with', 8, 'of', 24, 'of GEN', '3', 'with Fitness', '5.30')
# ('DONE with', 9, 'of', 24, 'of GEN', '3', 'with Fitness', '18.24')
# ('DONE with', 10, 'of', 24, 'of GEN', '3', 'with Fitness', '4.72')
# ('DONE with', 11, 'of', 24, 'of GEN', '3', 'with Fitness', '5.03')
# ('DONE with', 12, 'of', 24, 'of GEN', '3', 'with Fitness', '5.52')
# ('DONE with', 13, 'of', 24, 'of GEN', '3', 'with Fitness', '8.91')
# ('DONE with', 14, 'of', 24, 'of GEN', '3', 'with Fitness', '5.17')
# ('DONE with', 15, 'of', 24, 'of GEN', '3', 'with Fitness', '18.15')
# ('DONE with', 16, 'of', 24, 'of GEN', '3', 'with Fitness', '8.40')
# ('DONE with', 17, 'of', 24, 'of GEN', '3', 'with Fitness', '18.04')
# ('DONE with', 18, 'of', 24, 'of GEN', '3', 'with Fitness', '5.08')
# ('DONE with', 19, 'of', 24, 'of GEN', '3', 'with Fitness', '6.46')
# ('DONE with', 20, 'of', 24, 'of GEN', '3', 'with Fitness', '5.32')
# ('DONE with', 21, 'of', 24, 'of GEN', '3', 'with Fitness', '90.00')
# ('DONE with', 22, 'of', 24, 'of GEN', '3', 'with Fitness', '90.00')
# ('DONE with', 23, 'of', 24, 'of GEN', '3', 'with Fitness', '7241.66')
# ('DONE with', 24, 'of', 24, 'of GEN', '3', 'with Fitness', '6.79')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-1.6951587573349804]
# AfterHyperpolarizationTimeTest                                   -0.9654850746268636
# CellCapacitanceTest                                              -1.6455498411375695
# FISlopeTest                                                      -1.0138888888888888
# ISICVTest                                                        -0.6525853767802919
# InputResistanceTest                                              0.23084755954891215
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                1.6304991487085736
# RheobaseTest                                                      0.5175688242341911
# SagVoltageTest                                                    0.7410542946666584
# SpikeAccommodationTest                                           0.21855282588266894
# SpikeAccommodationTimeConstantTest                               -0.7484982900210381
# SpikeAmplitudeTest                                              [0.1376732637371121]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [2.1928565520285646]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 73.51% of range. Val: -63.2461627049 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.07% of range. Val: 186.603273593 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 90.29% of range. Val: 0.0902920962956 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 84.33% of range. Val: 0.0168652746685 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -63.24616270491288, -56.60436604364108, 0.0003188139654598454, 3.933167368370544, 186.60327359307794, 0.09029209629563073, 0.10671848783327488, 0.0008854398327198871, 0.008072924400407685, 0.002953503923700737, 0.00011687707963054088, -38.91275512857027, 8.010476529149849e-06, 0.016865274668460554])
# ('Best fitness:', 4.606330467551202)
# ('Generation', 3, 'out of', 200, 'COMPLETE')
# ('GEN', 4, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '4', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '4', 'with Fitness', '18.25')
# ('DONE with', 2, 'of', 24, 'of GEN', '4', 'with Fitness', '18.24')
# ('DONE with', 3, 'of', 24, 'of GEN', '4', 'with Fitness', '30.75')
# ('DONE with', 4, 'of', 24, 'of GEN', '4', 'with Fitness', '24.39')
# ('DONE with', 5, 'of', 24, 'of GEN', '4', 'with Fitness', '37.82')
# ('DONE with', 6, 'of', 24, 'of GEN', '4', 'with Fitness', '350.44')
# ('DONE with', 7, 'of', 24, 'of GEN', '4', 'with Fitness', '5.64')
# ('DONE with', 8, 'of', 24, 'of GEN', '4', 'with Fitness', '18.02')
# ('DONE with', 9, 'of', 24, 'of GEN', '4', 'with Fitness', '18.18')
# ('DONE with', 10, 'of', 24, 'of GEN', '4', 'with Fitness', '10.76')
# ('DONE with', 11, 'of', 24, 'of GEN', '4', 'with Fitness', '18.18')
# ('DONE with', 12, 'of', 24, 'of GEN', '4', 'with Fitness', '7.31')
# ('DONE with', 13, 'of', 24, 'of GEN', '4', 'with Fitness', '5.72')
# ('DONE with', 14, 'of', 24, 'of GEN', '4', 'with Fitness', '4.61')
# ('DONE with', 15, 'of', 24, 'of GEN', '4', 'with Fitness', '90.00')
# ('DONE with', 16, 'of', 24, 'of GEN', '4', 'with Fitness', '11.30')
# ('DONE with', 17, 'of', 24, 'of GEN', '4', 'with Fitness', '5.13')
# ('DONE with', 18, 'of', 24, 'of GEN', '4', 'with Fitness', '4.61')
# ('DONE with', 19, 'of', 24, 'of GEN', '4', 'with Fitness', '4.61')
# ('DONE with', 20, 'of', 24, 'of GEN', '4', 'with Fitness', '9.63')
# ('DONE with', 21, 'of', 24, 'of GEN', '4', 'with Fitness', '4.61')
# ('DONE with', 22, 'of', 24, 'of GEN', '4', 'with Fitness', '6.00')
# ('DONE with', 23, 'of', 24, 'of GEN', '4', 'with Fitness', '6.02')
# ('DONE with', 24, 'of', 24, 'of GEN', '4', 'with Fitness', '5.08')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-1.6951587573349804]
# AfterHyperpolarizationTimeTest                                   -0.9654850746268636
# CellCapacitanceTest                                              -1.6455498411375695
# FISlopeTest                                                      -1.0138888888888888
# ISICVTest                                                        -0.6525853767802919
# InputResistanceTest                                              0.23084755954891215
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                1.6304991487085736
# RheobaseTest                                                      0.5175688242341911
# SagVoltageTest                                                    0.7410542946666584
# SpikeAccommodationTest                                           0.21855282588266894
# SpikeAccommodationTimeConstantTest                               -0.7484982900210381
# SpikeAmplitudeTest                                              [0.1376732637371121]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [2.1928565520285646]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 73.51% of range. Val: -63.2461627049 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.07% of range. Val: 186.603273593 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 90.29% of range. Val: 0.0902920962956 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 84.33% of range. Val: 0.0168652746685 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -63.24616270491288, -56.60436604364108, 0.0003188139654598454, 3.933167368370544, 186.60327359307794, 0.09029209629563073, 0.10671848783327488, 0.0008854398327198871, 0.008072924400407685, 0.002953503923700737, 0.00011687707963054088, -38.91275512857027, 8.010476529149849e-06, 0.016865274668460554])
# ('Best fitness:', 4.606330467551202)
# ('Generation', 4, 'out of', 200, 'COMPLETE')
# ('GEN', 5, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '5', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '5', 'with Fitness', '13.32')
# ('DONE with', 2, 'of', 24, 'of GEN', '5', 'with Fitness', '36.39')
# ('DONE with', 3, 'of', 24, 'of GEN', '5', 'with Fitness', '6.81')
# ('DONE with', 4, 'of', 24, 'of GEN', '5', 'with Fitness', '19.26')
# ('DONE with', 5, 'of', 24, 'of GEN', '5', 'with Fitness', '21.01')
# ('DONE with', 6, 'of', 24, 'of GEN', '5', 'with Fitness', '16.81')
# ('DONE with', 7, 'of', 24, 'of GEN', '5', 'with Fitness', '44.61')
# ('DONE with', 8, 'of', 24, 'of GEN', '5', 'with Fitness', '2302.76')
# ('DONE with', 9, 'of', 24, 'of GEN', '5', 'with Fitness', '90.00')
# ('DONE with', 10, 'of', 24, 'of GEN', '5', 'with Fitness', '5.42')
# ('DONE with', 11, 'of', 24, 'of GEN', '5', 'with Fitness', '6.10')
# ('DONE with', 12, 'of', 24, 'of GEN', '5', 'with Fitness', '90.00')
# ('DONE with', 13, 'of', 24, 'of GEN', '5', 'with Fitness', '5.12')
# ('DONE with', 14, 'of', 24, 'of GEN', '5', 'with Fitness', '6.06')
# ('DONE with', 15, 'of', 24, 'of GEN', '5', 'with Fitness', '4.93')
# ('DONE with', 16, 'of', 24, 'of GEN', '5', 'with Fitness', '5.88')
# ('DONE with', 17, 'of', 24, 'of GEN', '5', 'with Fitness', '6.35')
# ('DONE with', 18, 'of', 24, 'of GEN', '5', 'with Fitness', '5.13')
# ('DONE with', 19, 'of', 24, 'of GEN', '5', 'with Fitness', '5.57')
# ('DONE with', 20, 'of', 24, 'of GEN', '5', 'with Fitness', '5.61')
# ('DONE with', 21, 'of', 24, 'of GEN', '5', 'with Fitness', '18.07')
# ('DONE with', 22, 'of', 24, 'of GEN', '5', 'with Fitness', '90.00')
# ('DONE with', 23, 'of', 24, 'of GEN', '5', 'with Fitness', '90.00')
# ('DONE with', 24, 'of', 24, 'of GEN', '5', 'with Fitness', '90.00')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-1.6951587573349804]
# AfterHyperpolarizationTimeTest                                   -0.9654850746268636
# CellCapacitanceTest                                              -1.6455498411375695
# FISlopeTest                                                      -1.0138888888888888
# ISICVTest                                                        -0.6525853767802919
# InputResistanceTest                                              0.23084755954891215
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                1.6304991487085736
# RheobaseTest                                                      0.5175688242341911
# SagVoltageTest                                                    0.7410542946666584
# SpikeAccommodationTest                                           0.21855282588266894
# SpikeAccommodationTimeConstantTest                               -0.7484982900210381
# SpikeAmplitudeTest                                              [0.1376732637371121]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [2.1928565520285646]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 73.51% of range. Val: -63.2461627049 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.07% of range. Val: 186.603273593 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 90.29% of range. Val: 0.0902920962956 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 84.33% of range. Val: 0.0168652746685 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -63.24616270491288, -56.60436604364108, 0.0003188139654598454, 3.933167368370544, 186.60327359307794, 0.09029209629563073, 0.10671848783327488, 0.0008854398327198871, 0.008072924400407685, 0.002953503923700737, 0.00011687707963054088, -38.91275512857027, 8.010476529149849e-06, 0.016865274668460554])
# ('Best fitness:', 4.606330467551202)
# ('Generation', 5, 'out of', 200, 'COMPLETE')
# ('GEN', 6, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '6', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '6', 'with Fitness', '27.64')
# ('DONE with', 2, 'of', 24, 'of GEN', '6', 'with Fitness', '19.85')
# ('DONE with', 3, 'of', 24, 'of GEN', '6', 'with Fitness', '9.24')
# ('DONE with', 4, 'of', 24, 'of GEN', '6', 'with Fitness', '9.11')
# ('DONE with', 5, 'of', 24, 'of GEN', '6', 'with Fitness', '12.50')
# ('DONE with', 6, 'of', 24, 'of GEN', '6', 'with Fitness', '15.88')
# ('DONE with', 7, 'of', 24, 'of GEN', '6', 'with Fitness', '18.08')
# ('DONE with', 8, 'of', 24, 'of GEN', '6', 'with Fitness', '10.69')
# ('DONE with', 9, 'of', 24, 'of GEN', '6', 'with Fitness', '90.00')
# ('DONE with', 10, 'of', 24, 'of GEN', '6', 'with Fitness', '5.09')
# ('DONE with', 11, 'of', 24, 'of GEN', '6', 'with Fitness', '90.00')
# ('DONE with', 12, 'of', 24, 'of GEN', '6', 'with Fitness', '5.53')
# ('DONE with', 13, 'of', 24, 'of GEN', '6', 'with Fitness', '5.48')
# ('DONE with', 14, 'of', 24, 'of GEN', '6', 'with Fitness', '8.26')
# ('DONE with', 15, 'of', 24, 'of GEN', '6', 'with Fitness', '4.89')
# ('DONE with', 16, 'of', 24, 'of GEN', '6', 'with Fitness', '5.82')
# ('DONE with', 17, 'of', 24, 'of GEN', '6', 'with Fitness', '90.00')
# ('DONE with', 18, 'of', 24, 'of GEN', '6', 'with Fitness', '5.81')
# ('DONE with', 19, 'of', 24, 'of GEN', '6', 'with Fitness', '5.67')
# ('DONE with', 20, 'of', 24, 'of GEN', '6', 'with Fitness', '8.83')
# ('DONE with', 21, 'of', 24, 'of GEN', '6', 'with Fitness', '90.00')
# ('DONE with', 22, 'of', 24, 'of GEN', '6', 'with Fitness', '7.06')
# ('DONE with', 23, 'of', 24, 'of GEN', '6', 'with Fitness', '6.31')
# ('DONE with', 24, 'of', 24, 'of GEN', '6', 'with Fitness', '90.00')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-1.6951587573349804]
# AfterHyperpolarizationTimeTest                                   -0.9654850746268636
# CellCapacitanceTest                                              -1.6455498411375695
# FISlopeTest                                                      -1.0138888888888888
# ISICVTest                                                        -0.6525853767802919
# InputResistanceTest                                              0.23084755954891215
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                1.6304991487085736
# RheobaseTest                                                      0.5175688242341911
# SagVoltageTest                                                    0.7410542946666584
# SpikeAccommodationTest                                           0.21855282588266894
# SpikeAccommodationTimeConstantTest                               -0.7484982900210381
# SpikeAmplitudeTest                                              [0.1376732637371121]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [2.1928565520285646]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 73.51% of range. Val: -63.2461627049 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.07% of range. Val: 186.603273593 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 90.29% of range. Val: 0.0902920962956 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 84.33% of range. Val: 0.0168652746685 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -63.24616270491288, -56.60436604364108, 0.0003188139654598454, 3.933167368370544, 186.60327359307794, 0.09029209629563073, 0.10671848783327488, 0.0008854398327198871, 0.008072924400407685, 0.002953503923700737, 0.00011687707963054088, -38.91275512857027, 8.010476529149849e-06, 0.016865274668460554])
# ('Best fitness:', 4.606330467551202)
# ('Generation', 6, 'out of', 200, 'COMPLETE')
# ('GEN', 7, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '7', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '7', 'with Fitness', '17545943.43')
# ('DONE with', 2, 'of', 24, 'of GEN', '7', 'with Fitness', '90.00')
# ('DONE with', 3, 'of', 24, 'of GEN', '7', 'with Fitness', '14.95')
# ('DONE with', 4, 'of', 24, 'of GEN', '7', 'with Fitness', '48.70')
# ('DONE with', 5, 'of', 24, 'of GEN', '7', 'with Fitness', '18.24')
# ('DONE with', 6, 'of', 24, 'of GEN', '7', 'with Fitness', '18.38')
# ('DONE with', 7, 'of', 24, 'of GEN', '7', 'with Fitness', '17.83')
# ('DONE with', 8, 'of', 24, 'of GEN', '7', 'with Fitness', '5.63')
# ('DONE with', 9, 'of', 24, 'of GEN', '7', 'with Fitness', '25.22')
# ('DONE with', 10, 'of', 24, 'of GEN', '7', 'with Fitness', '6.90')
# ('DONE with', 11, 'of', 24, 'of GEN', '7', 'with Fitness', '90.00')
# ('DONE with', 12, 'of', 24, 'of GEN', '7', 'with Fitness', '6.72')
# ('DONE with', 13, 'of', 24, 'of GEN', '7', 'with Fitness', '4.61')
# ('DONE with', 14, 'of', 24, 'of GEN', '7', 'with Fitness', '5.91')
# ('DONE with', 15, 'of', 24, 'of GEN', '7', 'with Fitness', '5.59')
# ('DONE with', 16, 'of', 24, 'of GEN', '7', 'with Fitness', '5.59')
# ('DONE with', 17, 'of', 24, 'of GEN', '7', 'with Fitness', '4.61')
# ('DONE with', 18, 'of', 24, 'of GEN', '7', 'with Fitness', '4.61')
# ('DONE with', 19, 'of', 24, 'of GEN', '7', 'with Fitness', '11787.00')
# ('DONE with', 20, 'of', 24, 'of GEN', '7', 'with Fitness', '5.16')
# ('DONE with', 21, 'of', 24, 'of GEN', '7', 'with Fitness', '5.18')
# ('DONE with', 22, 'of', 24, 'of GEN', '7', 'with Fitness', '11.73')
# ('DONE with', 23, 'of', 24, 'of GEN', '7', 'with Fitness', '4.96')
# ('DONE with', 24, 'of', 24, 'of GEN', '7', 'with Fitness', '4.47')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-0.8063246434465267]
# AfterHyperpolarizationTimeTest                                   -0.9816303099885146
# CellCapacitanceTest                                              -1.6394831551382594
# FISlopeTest                                                      -1.7777777777777775
# ISICVTest                                                        -0.8137228754197962
# InputResistanceTest                                              0.20030609214332618
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                  0.90522288254954
# RheobaseTest                                                       1.341980797032533
# SagVoltageTest                                                    0.7447207522730156
# SpikeAccommodationTest                                           0.36982780113309094
# SpikeAccommodationTimeConstantTest                               -0.8252162459456384
# SpikeAmplitudeTest                                             [0.22208240382415376]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [1.8633886645073556]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 63.37% of range. Val: -68.3174433221 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.07% of range. Val: 186.603273593 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 97.68% of range. Val: 0.0976827986218 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 84.33% of range. Val: 0.0168652746685 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -68.31744332210725, -56.60436604364108, 0.0003188139654598454, 3.933167368370544, 186.60327359307794, 0.09768279862180132, 0.10671848783327488, 0.0008854398327198871, 0.008072924400407685, 0.002953503923700737, 0.00011687707963054088, -38.91275512857027, 8.010476529149849e-06, 0.016865274668460554])
# ('Best fitness:', 4.468232686522099)
# ('Generation', 7, 'out of', 200, 'COMPLETE')
# ('GEN', 8, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '8', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '8', 'with Fitness', '18.29')
# ('DONE with', 2, 'of', 24, 'of GEN', '8', 'with Fitness', '18.48')
# NEURON: variable step integrator error
#  near line 0
#  ^
#         fadvance()
#       advance()
#     step()
#   continuerun(3100)
# and others
# ('DONE with', 3, 'of', 24, 'of GEN', '8', 'with Fitness', '24.87')
# ('DONE with', 4, 'of', 24, 'of GEN', '8', 'with Fitness', '19.73')
# ('DONE with', 5, 'of', 24, 'of GEN', '8', 'with Fitness', '18.13')
# ('DONE with', 6, 'of', 24, 'of GEN', '8', 'with Fitness', '45.96')
# ('DONE with', 7, 'of', 24, 'of GEN', '8', 'with Fitness', '18.24')
# ('DONE with', 8, 'of', 24, 'of GEN', '8', 'with Fitness', '7.60')
# ('DONE with', 9, 'of', 24, 'of GEN', '8', 'with Fitness', '2825.94')
# ('DONE with', 10, 'of', 24, 'of GEN', '8', 'with Fitness', '5.84')
# ('DONE with', 11, 'of', 24, 'of GEN', '8', 'with Fitness', '18.26')
# ('DONE with', 12, 'of', 24, 'of GEN', '8', 'with Fitness', '7.04')
# ('DONE with', 13, 'of', 24, 'of GEN', '8', 'with Fitness', '4.95')
# ('DONE with', 14, 'of', 24, 'of GEN', '8', 'with Fitness', '14.68')
# ('DONE with', 15, 'of', 24, 'of GEN', '8', 'with Fitness', '5.01')
# ('DONE with', 16, 'of', 24, 'of GEN', '8', 'with Fitness', '4.86')
# ('DONE with', 17, 'of', 24, 'of GEN', '8', 'with Fitness', '4.61')
# ('DONE with', 18, 'of', 24, 'of GEN', '8', 'with Fitness', '5273.26')
# ('DONE with', 19, 'of', 24, 'of GEN', '8', 'with Fitness', '4.61')
# ('DONE with', 20, 'of', 24, 'of GEN', '8', 'with Fitness', '5.77')
# ('DONE with', 21, 'of', 24, 'of GEN', '8', 'with Fitness', '11.68')
# ('DONE with', 22, 'of', 24, 'of GEN', '8', 'with Fitness', '4.61')
# ('DONE with', 23, 'of', 24, 'of GEN', '8', 'with Fitness', '90.00')
# ('DONE with', 24, 'of', 24, 'of GEN', '8', 'with Fitness', '5.01')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-0.8063246434465267]
# AfterHyperpolarizationTimeTest                                   -0.9816303099885146
# CellCapacitanceTest                                              -1.6394831551382594
# FISlopeTest                                                      -1.7777777777777775
# ISICVTest                                                        -0.8137228754197962
# InputResistanceTest                                              0.20030609214332618
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                  0.90522288254954
# RheobaseTest                                                       1.341980797032533
# SagVoltageTest                                                    0.7447207522730156
# SpikeAccommodationTest                                           0.36982780113309094
# SpikeAccommodationTimeConstantTest                               -0.8252162459456384
# SpikeAmplitudeTest                                             [0.22208240382415376]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [1.8633886645073556]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 63.37% of range. Val: -68.3174433221 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.07% of range. Val: 186.603273593 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 97.68% of range. Val: 0.0976827986218 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 84.33% of range. Val: 0.0168652746685 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -68.31744332210725, -56.60436604364108, 0.0003188139654598454, 3.933167368370544, 186.60327359307794, 0.09768279862180132, 0.10671848783327488, 0.0008854398327198871, 0.008072924400407685, 0.002953503923700737, 0.00011687707963054088, -38.91275512857027, 8.010476529149849e-06, 0.016865274668460554])
# ('Best fitness:', 4.468232686522099)
# ('Generation', 8, 'out of', 200, 'COMPLETE')
# ('GEN', 9, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '9', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '9', 'with Fitness', '18.25')
# ('DONE with', 2, 'of', 24, 'of GEN', '9', 'with Fitness', '78.17')
# ('DONE with', 3, 'of', 24, 'of GEN', '9', 'with Fitness', '15.24')
# ('DONE with', 4, 'of', 24, 'of GEN', '9', 'with Fitness', '25.74')
# ('DONE with', 5, 'of', 24, 'of GEN', '9', 'with Fitness', '61.02')
# ('DONE with', 6, 'of', 24, 'of GEN', '9', 'with Fitness', '12.68')
# ('DONE with', 7, 'of', 24, 'of GEN', '9', 'with Fitness', '8.34')
# ('DONE with', 8, 'of', 24, 'of GEN', '9', 'with Fitness', '7.34')
# ('DONE with', 9, 'of', 24, 'of GEN', '9', 'with Fitness', '4.96')
# ('DONE with', 10, 'of', 24, 'of GEN', '9', 'with Fitness', '18.22')
# ('DONE with', 11, 'of', 24, 'of GEN', '9', 'with Fitness', '7.41')
# ('DONE with', 12, 'of', 24, 'of GEN', '9', 'with Fitness', '6.62')
# ('DONE with', 13, 'of', 24, 'of GEN', '9', 'with Fitness', '5.10')
# ('DONE with', 14, 'of', 24, 'of GEN', '9', 'with Fitness', '4.61')
# ('DONE with', 15, 'of', 24, 'of GEN', '9', 'with Fitness', '5.68')
# ('DONE with', 16, 'of', 24, 'of GEN', '9', 'with Fitness', '10925.95')
# ('DONE with', 17, 'of', 24, 'of GEN', '9', 'with Fitness', '4.76')
# ('DONE with', 18, 'of', 24, 'of GEN', '9', 'with Fitness', '5.11')
# ('DONE with', 19, 'of', 24, 'of GEN', '9', 'with Fitness', '7.83')
# ('DONE with', 20, 'of', 24, 'of GEN', '9', 'with Fitness', '4.36')
# ('DONE with', 21, 'of', 24, 'of GEN', '9', 'with Fitness', '5.68')
# ('DONE with', 22, 'of', 24, 'of GEN', '9', 'with Fitness', '4.61')
# ('DONE with', 23, 'of', 24, 'of GEN', '9', 'with Fitness', '4.61')
# ('DONE with', 24, 'of', 24, 'of GEN', '9', 'with Fitness', '4.61')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                             [-1.257530775209538]
# AfterHyperpolarizationTimeTest                                   -0.9611940298507438
# CellCapacitanceTest                                               -1.639518202214513
# FISlopeTest                                                      -1.8472222222222225
# ISICVTest                                                       -0.28202882035062055
# InputResistanceTest                                              0.20158104175063773
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                0.9089484911470345
# RheobaseTest                                                      1.3182814154543336
# SagVoltageTest                                                    0.7440640009378124
# SpikeAccommodationTest                                            0.4534836890857831
# SpikeAccommodationTimeConstantTest                               -0.6817696004901491
# SpikeAmplitudeTest                                              [0.6423312508539399]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                               [1.329348659783739]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 63.37% of range. Val: -68.3174433221 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 79.70% of range. Val: 0.00031881396546 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.33% of range. Val: 3.93316736837 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 63.70% of range. Val: 191.470760059 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 97.39% of range. Val: 0.0973908730263 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.36% of range. Val: 0.106718487833 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 44.27% of range. Val: 0.00088543983272 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 40.36% of range. Val: 0.00807292440041 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.46% of range. Val: 0.0029535039237 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 11.69% of range. Val: 0.000116877079631 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 13.35% of range. Val: 8.01047652915e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 79.24% of range. Val: 0.0158485425702 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ...
# ('DONE with', 1, 'of', 24, 'of GEN', '198', 'with Fitness', '45.92')
# ('DONE with', 2, 'of', 24, 'of GEN', '198', 'with Fitness', '10.91')
# ('DONE with', 3, 'of', 24, 'of GEN', '198', 'with Fitness', '9.19')
# ('DONE with', 4, 'of', 24, 'of GEN', '198', 'with Fitness', '13.41')
# ('DONE with', 5, 'of', 24, 'of GEN', '198', 'with Fitness', '8.11')
# ('DONE with', 6, 'of', 24, 'of GEN', '198', 'with Fitness', '3328.80')
# ('DONE with', 7, 'of', 24, 'of GEN', '198', 'with Fitness', '10.80')
# ('DONE with', 8, 'of', 24, 'of GEN', '198', 'with Fitness', '13.74')
# ('DONE with', 9, 'of', 24, 'of GEN', '198', 'with Fitness', '8.77')
# ('DONE with', 10, 'of', 24, 'of GEN', '198', 'with Fitness', '11.15')
# ('DONE with', 11, 'of', 24, 'of GEN', '198', 'with Fitness', '15.20')
# ('DONE with', 12, 'of', 24, 'of GEN', '198', 'with Fitness', '18.48')
# ('DONE with', 13, 'of', 24, 'of GEN', '198', 'with Fitness', '4.61')
# ('DONE with', 14, 'of', 24, 'of GEN', '198', 'with Fitness', '8.72')
# ('DONE with', 15, 'of', 24, 'of GEN', '198', 'with Fitness', '6.13')
# ('DONE with', 16, 'of', 24, 'of GEN', '198', 'with Fitness', '4.57')
# ('DONE with', 17, 'of', 24, 'of GEN', '198', 'with Fitness', '7.67')
# ('DONE with', 18, 'of', 24, 'of GEN', '198', 'with Fitness', '5.76')
# ('DONE with', 19, 'of', 24, 'of GEN', '198', 'with Fitness', '4.24')
# ('DONE with', 20, 'of', 24, 'of GEN', '198', 'with Fitness', '5.40')
# ('DONE with', 21, 'of', 24, 'of GEN', '198', 'with Fitness', '9.37')
# ('DONE with', 22, 'of', 24, 'of GEN', '198', 'with Fitness', '90.00')
# ('DONE with', 23, 'of', 24, 'of GEN', '198', 'with Fitness', '5.34')
# ('DONE with', 24, 'of', 24, 'of GEN', '198', 'with Fitness', '3.83')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-0.7413212428208619]
# AfterHyperpolarizationTimeTest                                   -0.9772565742714951
# CellCapacitanceTest                                              -1.6460751191424035
# FISlopeTest                                                       0.2361111111111111
# ISICVTest                                                        -0.9773314997242611
# InputResistanceTest                                               0.4368900983791314
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                 1.056989566638901
# RheobaseTest                                                     0.47095482520753496
# SagVoltageTest                                                    0.7500402855672688
# SpikeAccommodationTest                                           0.17068635024175297
# SpikeAccommodationTimeConstantTest                               -0.7212841935585831
# SpikeAmplitudeTest                                             [0.35398011019607495]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                               [1.545620401803023]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 63.37% of range. Val: -68.3174433221 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 72.88% of range. Val: 0.000291507201922 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.13% of range. Val: 3.91334971574 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.66% of range. Val: 188.342479464 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 89.80% of range. Val: 0.0898025801274 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.65% of range. Val: 0.107309491669 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 16.79% of range. Val: 0.000335795449626 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 24.99% of range. Val: 0.00499709482131 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.38% of range. Val: 0.0029412988658 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 1.80% of range. Val: 1.79825956636e-05 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 12.95% of range. Val: 7.77139335091e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 26.92% of range. Val: 0.00538436503619 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -68.31744332210725, -56.60436604364108, 0.00029150720192176895, 3.913349715740908, 188.34247946378073, 0.08980258012743354, 0.10730949166868958, 0.0003357954496264246, 0.0049970948213131534, 0.0029412988658005113, 1.798259566363729e-05, -38.91275512857027, 7.77139335091131e-06, 0.005384365036192561])
# ('Best fitness:', 3.829830455480862)
# ('Generation', 198, 'out of', 200, 'COMPLETE')
# ('GEN', 199, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '199', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '199', 'with Fitness', '18.14')
# ('DONE with', 2, 'of', 24, 'of GEN', '199', 'with Fitness', '11.93')
# ('DONE with', 3, 'of', 24, 'of GEN', '199', 'with Fitness', '13.52')
# ('DONE with', 4, 'of', 24, 'of GEN', '199', 'with Fitness', '15.69')
# ('DONE with', 5, 'of', 24, 'of GEN', '199', 'with Fitness', '18.15')
# ('DONE with', 6, 'of', 24, 'of GEN', '199', 'with Fitness', '90.00')
# ('DONE with', 7, 'of', 24, 'of GEN', '199', 'with Fitness', '10.79')
# ('DONE with', 8, 'of', 24, 'of GEN', '199', 'with Fitness', '10.93')
# ('DONE with', 9, 'of', 24, 'of GEN', '199', 'with Fitness', '5.57')
# ('DONE with', 10, 'of', 24, 'of GEN', '199', 'with Fitness', '11.35')
# ('DONE with', 11, 'of', 24, 'of GEN', '199', 'with Fitness', '48.45')
# ('DONE with', 12, 'of', 24, 'of GEN', '199', 'with Fitness', '18.11')
# ('DONE with', 13, 'of', 24, 'of GEN', '199', 'with Fitness', '2129.39')
# ('DONE with', 14, 'of', 24, 'of GEN', '199', 'with Fitness', '4.27')
# ('DONE with', 15, 'of', 24, 'of GEN', '199', 'with Fitness', '5.35')
# ('DONE with', 16, 'of', 24, 'of GEN', '199', 'with Fitness', '4.73')
# ('DONE with', 17, 'of', 24, 'of GEN', '199', 'with Fitness', '4.32')
# ('DONE with', 18, 'of', 24, 'of GEN', '199', 'with Fitness', '18.03')
# ('DONE with', 19, 'of', 24, 'of GEN', '199', 'with Fitness', '4.69')
# ('DONE with', 20, 'of', 24, 'of GEN', '199', 'with Fitness', '6.25')
# ('DONE with', 21, 'of', 24, 'of GEN', '199', 'with Fitness', '3.83')
# ('DONE with', 22, 'of', 24, 'of GEN', '199', 'with Fitness', '7.46')
# ('DONE with', 23, 'of', 24, 'of GEN', '199', 'with Fitness', '16.62')
# ('DONE with', 24, 'of', 24, 'of GEN', '199', 'with Fitness', '4.67')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-0.7413212428208619]
# AfterHyperpolarizationTimeTest                                   -0.9772565742714951
# CellCapacitanceTest                                              -1.6460751191424035
# FISlopeTest                                                       0.2361111111111111
# ISICVTest                                                        -0.9773314997242611
# InputResistanceTest                                               0.4368900983791314
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                 1.056989566638901
# RheobaseTest                                                     0.47095482520753496
# SagVoltageTest                                                    0.7500402855672688
# SpikeAccommodationTest                                           0.17068635024175297
# SpikeAccommodationTimeConstantTest                               -0.7212841935585831
# SpikeAmplitudeTest                                             [0.35398011019607495]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                               [1.545620401803023]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 63.37% of range. Val: -68.3174433221 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 72.88% of range. Val: 0.000291507201922 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.13% of range. Val: 3.91334971574 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.66% of range. Val: 188.342479464 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 89.80% of range. Val: 0.0898025801274 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.65% of range. Val: 0.107309491669 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 16.79% of range. Val: 0.000335795449626 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 24.99% of range. Val: 0.00499709482131 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.38% of range. Val: 0.0029412988658 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 1.80% of range. Val: 1.79825956636e-05 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 12.95% of range. Val: 7.77139335091e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 26.92% of range. Val: 0.00538436503619 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -68.31744332210725, -56.60436604364108, 0.00029150720192176895, 3.913349715740908, 188.34247946378073, 0.08980258012743354, 0.10730949166868958, 0.0003357954496264246, 0.0049970948213131534, 0.0029412988658005113, 1.798259566363729e-05, -38.91275512857027, 7.77139335091131e-06, 0.005384365036192561])
# ('Best fitness:', 3.829830455480862)
# ('Generation', 199, 'out of', 200, 'COMPLETE')
# ('GEN', 200, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '200', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '200', 'with Fitness', '10.25')
# ('DONE with', 2, 'of', 24, 'of GEN', '200', 'with Fitness', '7.36')
# ('DONE with', 3, 'of', 24, 'of GEN', '200', 'with Fitness', '13.35')
# ('DONE with', 4, 'of', 24, 'of GEN', '200', 'with Fitness', '19.08')
# ('DONE with', 5, 'of', 24, 'of GEN', '200', 'with Fitness', '29.47')
# ('DONE with', 6, 'of', 24, 'of GEN', '200', 'with Fitness', '8.51')
# ('DONE with', 7, 'of', 24, 'of GEN', '200', 'with Fitness', '22.06')
# ('DONE with', 8, 'of', 24, 'of GEN', '200', 'with Fitness', '8.42')
# ('DONE with', 9, 'of', 24, 'of GEN', '200', 'with Fitness', '17.98')
# ('DONE with', 10, 'of', 24, 'of GEN', '200', 'with Fitness', '90.00')
# ('DONE with', 11, 'of', 24, 'of GEN', '200', 'with Fitness', '24.84')
# ('DONE with', 12, 'of', 24, 'of GEN', '200', 'with Fitness', '15.57')
# ('DONE with', 13, 'of', 24, 'of GEN', '200', 'with Fitness', '3.83')
# ('DONE with', 14, 'of', 24, 'of GEN', '200', 'with Fitness', '8.72')
# ('DONE with', 15, 'of', 24, 'of GEN', '200', 'with Fitness', '3.83')
# ('DONE with', 16, 'of', 24, 'of GEN', '200', 'with Fitness', '3.83')
# ('DONE with', 17, 'of', 24, 'of GEN', '200', 'with Fitness', '3.83')
# ('DONE with', 18, 'of', 24, 'of GEN', '200', 'with Fitness', '9.21')
# ('DONE with', 19, 'of', 24, 'of GEN', '200', 'with Fitness', '3.83')
# ('DONE with', 20, 'of', 24, 'of GEN', '200', 'with Fitness', '4.89')
# ('DONE with', 21, 'of', 24, 'of GEN', '200', 'with Fitness', '4.82')
# ('DONE with', 22, 'of', 24, 'of GEN', '200', 'with Fitness', '2614.39')
# ('DONE with', 23, 'of', 24, 'of GEN', '200', 'with Fitness', '10.69')
# ('DONE with', 24, 'of', 24, 'of GEN', '200', 'with Fitness', '5.08')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-0.7413212428208619]
# AfterHyperpolarizationTimeTest                                   -0.9772565742714951
# CellCapacitanceTest                                              -1.6460751191424035
# FISlopeTest                                                       0.2361111111111111
# ISICVTest                                                        -0.9773314997242611
# InputResistanceTest                                               0.4368900983791314
# MembraneTimeConstantTest                                         -2.0697674418604652
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                 1.056989566638901
# RheobaseTest                                                     0.47095482520753496
# SagVoltageTest                                                    0.7500402855672688
# SpikeAccommodationTest                                           0.17068635024175297
# SpikeAccommodationTimeConstantTest                               -0.7212841935585831
# SpikeAmplitudeTest                                             [0.35398011019607495]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                               [1.545620401803023]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 22.74% of range. Val: 0.53207961044 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.24% of range. Val: 9.27016543209 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 69.28% of range. Val: 104.230418067 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.19% of range. Val: 0.30530014688 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 14.87% of range. Val: 28.9244619029 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 63.37% of range. Val: -68.3174433221 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 83.49% of range. Val: -56.6043660436 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 72.88% of range. Val: 0.000291507201922 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 39.13% of range. Val: 3.91334971574 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 62.66% of range. Val: 188.342479464 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 89.80% of range. Val: 0.0898025801274 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.65% of range. Val: 0.107309491669 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 16.79% of range. Val: 0.000335795449626 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 24.99% of range. Val: 0.00499709482131 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 18.38% of range. Val: 0.0029412988658 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 1.80% of range. Val: 1.79825956636e-05 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 3.62% of range. Val: -38.9127551286 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 12.95% of range. Val: 7.77139335091e-06 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 26.92% of range. Val: 0.00538436503619 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.5320796104395679, 9.270165432086312, 104.23041806738314, 0.30530014688033, 28.924461902858308, -68.31744332210725, -56.60436604364108, 0.00029150720192176895, 3.913349715740908, 188.34247946378073, 0.08980258012743354, 0.10730949166868958, 0.0003357954496264246, 0.0049970948213131534, 0.0029412988658005113, 1.798259566363729e-05, -38.91275512857027, 7.77139335091131e-06, 0.005384365036192561])
# ('Best fitness:', 3.829830455480862)
# ('Generation', 200, 'out of', 200, 'COMPLETE')
