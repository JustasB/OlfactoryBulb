# %%
import os; os.chdir("..");
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
import sys
cell_id = sys.argv[1] if len(sys.argv) > 1 and sys.argv[1].isdigit() else 5
print(cell_id)
# Out:
# 5

# %%
fitter = CellFitter(cell_type="gc", fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells.GC"+str(cell_id))
# Out:
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC5')

# %%
fitter.clear_cache()
#fitter.top = [[0.518568993696911, 22.331096575385537, 3.9991551066170175, 44.54836939907614, -55.16528090080958, -89.29463560245307, 0.00018368809366833735, 2.922232364299777, 0.07465156310126753, 0.19498287109045842, 0.03935002363776688, -49.39660394446575, 2.548528534052994e-06, 0.006660630409332343]]
fitter.fit(25, 200)
raise
# Out:
# ('STARTED GEN', 'ZERO', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '17.25')
# ('DONE with', 2, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '16.43')
# ('DONE with', 3, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '28.39')
# ('DONE with', 4, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '44.50')
# ('DONE with', 5, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '7.92')
# ('DONE with', 6, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '43.52')
# ('DONE with', 7, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '8.37')
# ('DONE with', 8, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '15.81')
# ('DONE with', 9, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '36.38')
# ('DONE with', 10, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '15.47')
# ('DONE with', 11, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '22.38')
# ('DONE with', 12, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '43.32')
# ('DONE with', 13, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '12.69')
# ('DONE with', 14, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '21.47')
# ('DONE with', 15, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '16.37')
# ('DONE with', 16, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '35.49')
# ('DONE with', 17, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '31.32')
# ('DONE with', 18, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '12.81')
# ('DONE with', 19, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '8.45')
# ('DONE with', 20, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '25.22')
# ('DONE with', 21, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '17.75')
# ('DONE with', 22, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '13.34')
# ('DONE with', 23, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '8.03')
# ('DONE with', 24, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '11.28')
# ('DONE with', 25, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '27.34')
# ('GEN', 1, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '1', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '1', 'with Fitness', '43.23')
# ('DONE with', 2, 'of', 25, 'of GEN', '1', 'with Fitness', '40.90')
# ('DONE with', 3, 'of', 25, 'of GEN', '1', 'with Fitness', '63.18')
# ('DONE with', 4, 'of', 25, 'of GEN', '1', 'with Fitness', '29.96')
# ('DONE with', 5, 'of', 25, 'of GEN', '1', 'with Fitness', '7.49')
# ('DONE with', 6, 'of', 25, 'of GEN', '1', 'with Fitness', '12.13')
# ('DONE with', 7, 'of', 25, 'of GEN', '1', 'with Fitness', '8.73')
# ('DONE with', 8, 'of', 25, 'of GEN', '1', 'with Fitness', '9.77')
# ('DONE with', 9, 'of', 25, 'of GEN', '1', 'with Fitness', '22.31')
# ('DONE with', 10, 'of', 25, 'of GEN', '1', 'with Fitness', '15.00')
# ('DONE with', 11, 'of', 25, 'of GEN', '1', 'with Fitness', '8.16')
# ('DONE with', 12, 'of', 25, 'of GEN', '1', 'with Fitness', '15.86')
# ('DONE with', 13, 'of', 25, 'of GEN', '1', 'with Fitness', '13.60')
# ('DONE with', 14, 'of', 25, 'of GEN', '1', 'with Fitness', '25.89')
# ('DONE with', 15, 'of', 25, 'of GEN', '1', 'with Fitness', '8.50')
# ('DONE with', 16, 'of', 25, 'of GEN', '1', 'with Fitness', '10.15')
# ('DONE with', 17, 'of', 25, 'of GEN', '1', 'with Fitness', '7.73')
# ('DONE with', 18, 'of', 25, 'of GEN', '1', 'with Fitness', '8.13')
# ('DONE with', 19, 'of', 25, 'of GEN', '1', 'with Fitness', '10.11')
# ('DONE with', 20, 'of', 25, 'of GEN', '1', 'with Fitness', '8.53')
# ('DONE with', 21, 'of', 25, 'of GEN', '1', 'with Fitness', '7.77')
# ('DONE with', 22, 'of', 25, 'of GEN', '1', 'with Fitness', '8.20')
# ('DONE with', 23, 'of', 25, 'of GEN', '1', 'with Fitness', '48.67')
# ('DONE with', 24, 'of', 25, 'of GEN', '1', 'with Fitness', '12.43')
# ('DONE with', 25, 'of', 25, 'of GEN', '1', 'with Fitness', '8.32')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                           0.00012938475931179028
# AfterDepolarizationTimeTest                               -1.7500000000000073
# CellCapacitanceTest                                       -2.6015417616673475
# FISlopeTest                                               -1.8181818181818181
# InputResistanceTest                                        -1.217677698887801
# MembraneTimeConstantTest                                  -1.6893939393939394
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        -1.0099689094264033
# RheobaseTest                                               3.6389375735395246
# SagVoltageTest                                              3.013799866103287
# SpikeAccommodationTest                                   -0.31328320802005294
# SpikeAmplitudeTest                                        [3.538045100967595]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                       [-1.479135962427216]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 23.04% of range. Val: 0.768148620047 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 74.16% of range. Val: 3.96774082481 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 75.06% of range. Val: 113.840913406 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 55.16% of range. Val: 5.56064119974 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 46.25% of range. Val: 46.9995954614 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 39.60% of range. Val: -72.2811264655 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 9.20% of range. Val: -95.3977023635 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 18.20% of range. Val: 0.000727914404307 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 15.39% of range. Val: 1.53853716259 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 99.55% of range. Val: 0.398204476172 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 67.01% of range. Val: 1.07217611689 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 91.09% of range. Val: 4.55453473383 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 35.84% of range. Val: 1.7921474134 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 70.39% of range. Val: 0.563093593108 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 19.11% of range. Val: -50.4447240316 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 17.34% of range. Val: 3.46836790882e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 12.82% of range. Val: 0.0166598526871 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.7681486200473592, 3.967740824812011, 113.84091340613763, 5.560641199741356, 46.99959546143167, -72.28112646548925, -95.3977023634895, 0.0007279144043066698, 1.5385371625851474, 0.3982044761716727, 1.0721761168885122, 4.55453473382674, 1.7921474134034427, 0.5630935931078308, -50.444724031642636, 3.46836790882231e-05, 0.016659852687112956])
# ('Best fitness:', 7.4869598115192675)
# ('Generation', 1, 'out of', 200, 'COMPLETE')
# ('GEN', 2, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '2', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '2', 'with Fitness', '10.86')
# ('DONE with', 2, 'of', 25, 'of GEN', '2', 'with Fitness', '14.25')
# ('DONE with', 3, 'of', 25, 'of GEN', '2', 'with Fitness', '13.76')
# ('DONE with', 4, 'of', 25, 'of GEN', '2', 'with Fitness', '42.70')
# ('DONE with', 5, 'of', 25, 'of GEN', '2', 'with Fitness', '13.70')
# ('DONE with', 6, 'of', 25, 'of GEN', '2', 'with Fitness', '12.30')
# ('DONE with', 7, 'of', 25, 'of GEN', '2', 'with Fitness', '16.41')
# ('DONE with', 8, 'of', 25, 'of GEN', '2', 'with Fitness', '9.40')
# ('DONE with', 9, 'of', 25, 'of GEN', '2', 'with Fitness', '285.60')
# ('DONE with', 10, 'of', 25, 'of GEN', '2', 'with Fitness', '40.49')
# ('DONE with', 11, 'of', 25, 'of GEN', '2', 'with Fitness', '28.96')
# ('DONE with', 12, 'of', 25, 'of GEN', '2', 'with Fitness', '31.35')
# ('DONE with', 13, 'of', 25, 'of GEN', '2', 'with Fitness', '29.86')
# ('DONE with', 14, 'of', 25, 'of GEN', '2', 'with Fitness', '15.60')
# ('DONE with', 15, 'of', 25, 'of GEN', '2', 'with Fitness', '7.91')
# ('DONE with', 16, 'of', 25, 'of GEN', '2', 'with Fitness', '7.51')
# ('DONE with', 17, 'of', 25, 'of GEN', '2', 'with Fitness', '14.71')
# ('DONE with', 18, 'of', 25, 'of GEN', '2', 'with Fitness', '311.22')
# ('DONE with', 19, 'of', 25, 'of GEN', '2', 'with Fitness', '8.56')
# ('DONE with', 20, 'of', 25, 'of GEN', '2', 'with Fitness', '7.52')
# ('DONE with', 21, 'of', 25, 'of GEN', '2', 'with Fitness', '8.35')
# ('DONE with', 22, 'of', 25, 'of GEN', '2', 'with Fitness', '8.08')
# ('DONE with', 23, 'of', 25, 'of GEN', '2', 'with Fitness', '14.04')
# ('DONE with', 24, 'of', 25, 'of GEN', '2', 'with Fitness', '7.60')
# ('DONE with', 25, 'of', 25, 'of GEN', '2', 'with Fitness', '7.92')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                           0.00012938475931179028
# AfterDepolarizationTimeTest                               -1.7500000000000073
# CellCapacitanceTest                                       -2.6015417616673475
# FISlopeTest                                               -1.8181818181818181
# InputResistanceTest                                        -1.217677698887801
# MembraneTimeConstantTest                                  -1.6893939393939394
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        -1.0099689094264033
# RheobaseTest                                               3.6389375735395246
# SagVoltageTest                                              3.013799866103287
# SpikeAccommodationTest                                   -0.31328320802005294
# SpikeAmplitudeTest                                        [3.538045100967595]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                       [-1.479135962427216]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 23.04% of range. Val: 0.768148620047 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 74.16% of range. Val: 3.96774082481 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 75.06% of range. Val: 113.840913406 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 55.16% of range. Val: 5.56064119974 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 46.25% of range. Val: 46.9995954614 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 39.60% of range. Val: -72.2811264655 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 9.20% of range. Val: -95.3977023635 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 18.20% of range. Val: 0.000727914404307 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 15.39% of range. Val: 1.53853716259 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 99.55% of range. Val: 0.398204476172 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 67.01% of range. Val: 1.07217611689 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 91.09% of range. Val: 4.55453473383 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 35.84% of range. Val: 1.7921474134 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 70.39% of range. Val: 0.563093593108 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 19.11% of range. Val: -50.4447240316 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 17.34% of range. Val: 3.46836790882e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 12.82% of range. Val: 0.0166598526871 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.7681486200473592, 3.967740824812011, 113.84091340613763, 5.560641199741356, 46.99959546143167, -72.28112646548925, -95.3977023634895, 0.0007279144043066698, 1.5385371625851474, 0.3982044761716727, 1.0721761168885122, 4.55453473382674, 1.7921474134034427, 0.5630935931078308, -50.444724031642636, 3.46836790882231e-05, 0.016659852687112956])
# ('Best fitness:', 7.4869598115192675)
# ('Generation', 2, 'out of', 200, 'COMPLETE')
# ('GEN', 3, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '3', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '3', 'with Fitness', '9.29')
# ('DONE with', 2, 'of', 24, 'of GEN', '3', 'with Fitness', '12.68')
# ('DONE with', 3, 'of', 24, 'of GEN', '3', 'with Fitness', '30.42')
# ('DONE with', 4, 'of', 24, 'of GEN', '3', 'with Fitness', '29.88')
# ('DONE with', 5, 'of', 24, 'of GEN', '3', 'with Fitness', '18.37')
# ('DONE with', 6, 'of', 24, 'of GEN', '3', 'with Fitness', '14.68')
# ('DONE with', 7, 'of', 24, 'of GEN', '3', 'with Fitness', '7.08')
# ('DONE with', 8, 'of', 24, 'of GEN', '3', 'with Fitness', '6.97')
# ('DONE with', 9, 'of', 24, 'of GEN', '3', 'with Fitness', '7.79')
# ('DONE with', 10, 'of', 24, 'of GEN', '3', 'with Fitness', '19.25')
# ('DONE with', 11, 'of', 24, 'of GEN', '3', 'with Fitness', '9.57')
# ('DONE with', 12, 'of', 24, 'of GEN', '3', 'with Fitness', '15.25')
# ('DONE with', 13, 'of', 24, 'of GEN', '3', 'with Fitness', '8.67')
# ('DONE with', 14, 'of', 24, 'of GEN', '3', 'with Fitness', '6.96')
# ('DONE with', 15, 'of', 24, 'of GEN', '3', 'with Fitness', '11.24')
# ('DONE with', 16, 'of', 24, 'of GEN', '3', 'with Fitness', '11.70')
# ('DONE with', 17, 'of', 24, 'of GEN', '3', 'with Fitness', '6.42')
# ('DONE with', 18, 'of', 24, 'of GEN', '3', 'with Fitness', '8.14')
# ('DONE with', 19, 'of', 24, 'of GEN', '3', 'with Fitness', '7.08')
# ('DONE with', 20, 'of', 24, 'of GEN', '3', 'with Fitness', '7.42')
# ('DONE with', 21, 'of', 24, 'of GEN', '3', 'with Fitness', '7.44')
# ('DONE with', 22, 'of', 24, 'of GEN', '3', 'with Fitness', '7.67')
# ('DONE with', 23, 'of', 24, 'of GEN', '3', 'with Fitness', '15.57')
# ('DONE with', 24, 'of', 24, 'of GEN', '3', 'with Fitness', '14.83')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                            7.870274718158043e-05
# AfterDepolarizationTimeTest                                -1.738636363636357
# CellCapacitanceTest                                        -3.456876237994679
# FISlopeTest                                               -1.6363636363636365
# InputResistanceTest                                       -0.6467963898740993
# MembraneTimeConstantTest                                   -1.840909090909091
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        -0.5283023744021277
# RheobaseTest                                               1.5142076083608695
# SagVoltageTest                                             3.0104648509018332
# SpikeAccommodationTest                                    -0.9057971014492772
# SpikeAmplitudeTest                                        [2.544418914359067]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                      [-0.6537665412504696]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 7.16% of range. Val: 0.307706798832 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 50.74% of range. Val: 2.99572693433 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 60.01% of range. Val: 92.0156107232 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 87.73% of range. Val: 8.78561737527 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 40.00% of range. Val: 42.003632618 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 51.55% of range. Val: -63.9171606475 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 16.14% of range. Val: -91.930103214 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 67.33% of range. Val: 0.00269332514893 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 54.71% of range. Val: 5.47092595481 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 53.97% of range. Val: 0.215875602005 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 92.66% of range. Val: 1.4825682137 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 48.22% of range. Val: 2.41123205892 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 21.64% of range. Val: 1.08208538456 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 31.55% of range. Val: 0.25237729228 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 82.86% of range. Val: -18.5719069851 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 10.07% of range. Val: 2.01463275058e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 15.44% of range. Val: 0.0200717714606 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.30770679883221114, 2.995726934329732, 92.01561072322966, 8.785617375274635, 42.00363261795615, -63.91716064747699, -91.93010321398715, 0.0026933251489323303, 5.4709259548118165, 0.2158756020053448, 1.4825682137030642, 2.411232058917091, 1.0820853845612106, 0.25237729227957645, -18.571906985123345, 2.0146327505831286e-05, 0.020071771460644844])
# ('Best fitness:', 6.4224159326395185)
# ('Generation', 3, 'out of', 200, 'COMPLETE')
# ('GEN', 4, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '4', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '4', 'with Fitness', '101.76')
# ('DONE with', 2, 'of', 25, 'of GEN', '4', 'with Fitness', '9.67')
# ('DONE with', 3, 'of', 25, 'of GEN', '4', 'with Fitness', '6.94')
# ('DONE with', 4, 'of', 25, 'of GEN', '4', 'with Fitness', '54.01')
# ('DONE with', 5, 'of', 25, 'of GEN', '4', 'with Fitness', '11.23')
# ('DONE with', 6, 'of', 25, 'of GEN', '4', 'with Fitness', '97.82')
# ('DONE with', 7, 'of', 25, 'of GEN', '4', 'with Fitness', '6.65')
# ('DONE with', 8, 'of', 25, 'of GEN', '4', 'with Fitness', '9.78')
# ('DONE with', 9, 'of', 25, 'of GEN', '4', 'with Fitness', '16.86')
# ('DONE with', 10, 'of', 25, 'of GEN', '4', 'with Fitness', '7.57')
# ('DONE with', 11, 'of', 25, 'of GEN', '4', 'with Fitness', '8.16')
# ('DONE with', 12, 'of', 25, 'of GEN', '4', 'with Fitness', '9.50')
# ('DONE with', 13, 'of', 25, 'of GEN', '4', 'with Fitness', '7.97')
# ('DONE with', 14, 'of', 25, 'of GEN', '4', 'with Fitness', '11.69')
# ('DONE with', 15, 'of', 25, 'of GEN', '4', 'with Fitness', '6.86')
# ('DONE with', 16, 'of', 25, 'of GEN', '4', 'with Fitness', '6.58')
# ('DONE with', 17, 'of', 25, 'of GEN', '4', 'with Fitness', '10.30')
# ('DONE with', 18, 'of', 25, 'of GEN', '4', 'with Fitness', '7.00')
# ('DONE with', 19, 'of', 25, 'of GEN', '4', 'with Fitness', '6.95')
# ('DONE with', 20, 'of', 25, 'of GEN', '4', 'with Fitness', '7.02')
# ('DONE with', 21, 'of', 25, 'of GEN', '4', 'with Fitness', '7.05')
# ('DONE with', 22, 'of', 25, 'of GEN', '4', 'with Fitness', '9.22')
# ('DONE with', 23, 'of', 25, 'of GEN', '4', 'with Fitness', '6.98')
# ('DONE with', 24, 'of', 25, 'of GEN', '4', 'with Fitness', '7.12')
# ('DONE with', 25, 'of', 25, 'of GEN', '4', 'with Fitness', '7.29')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                            7.870274718158043e-05
# AfterDepolarizationTimeTest                                -1.738636363636357
# CellCapacitanceTest                                        -3.456876237994679
# FISlopeTest                                               -1.6363636363636365
# InputResistanceTest                                       -0.6467963898740993
# MembraneTimeConstantTest                                   -1.840909090909091
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        -0.5283023744021277
# RheobaseTest                                               1.5142076083608695
# SagVoltageTest                                             3.0104648509018332
# SpikeAccommodationTest                                    -0.9057971014492772
# SpikeAmplitudeTest                                        [2.544418914359067]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                      [-0.6537665412504696]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 7.16% of range. Val: 0.307706798832 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 50.74% of range. Val: 2.99572693433 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 60.01% of range. Val: 92.0156107232 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 87.73% of range. Val: 8.78561737527 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 40.00% of range. Val: 42.003632618 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 51.55% of range. Val: -63.9171606475 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 16.14% of range. Val: -91.930103214 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 67.33% of range. Val: 0.00269332514893 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 54.71% of range. Val: 5.47092595481 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 53.97% of range. Val: 0.215875602005 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 92.66% of range. Val: 1.4825682137 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 48.22% of range. Val: 2.41123205892 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 21.64% of range. Val: 1.08208538456 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 31.55% of range. Val: 0.25237729228 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 82.86% of range. Val: -18.5719069851 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 10.07% of range. Val: 2.01463275058e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 15.44% of range. Val: 0.0200717714606 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.30770679883221114, 2.995726934329732, 92.01561072322966, 8.785617375274635, 42.00363261795615, -63.91716064747699, -91.93010321398715, 0.0026933251489323303, 5.4709259548118165, 0.2158756020053448, 1.4825682137030642, 2.411232058917091, 1.0820853845612106, 0.25237729227957645, -18.571906985123345, 2.0146327505831286e-05, 0.020071771460644844])
# ('Best fitness:', 6.4224159326395185)
# ('Generation', 4, 'out of', 200, 'COMPLETE')
# ('GEN', 5, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '5', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '5', 'with Fitness', '15.43')
# ('DONE with', 2, 'of', 25, 'of GEN', '5', 'with Fitness', '66.21')
# ('DONE with', 3, 'of', 25, 'of GEN', '5', 'with Fitness', '256.13')
# ('DONE with', 4, 'of', 25, 'of GEN', '5', 'with Fitness', '23.73')
# ('DONE with', 5, 'of', 25, 'of GEN', '5', 'with Fitness', '23.63')
# ('DONE with', 6, 'of', 25, 'of GEN', '5', 'with Fitness', '20.36')
# ('DONE with', 7, 'of', 25, 'of GEN', '5', 'with Fitness', '6.33')
# ('DONE with', 8, 'of', 25, 'of GEN', '5', 'with Fitness', '7.24')
# ('DONE with', 9, 'of', 25, 'of GEN', '5', 'with Fitness', '22.71')
# ('DONE with', 10, 'of', 25, 'of GEN', '5', 'with Fitness', '10.49')
# ('DONE with', 11, 'of', 25, 'of GEN', '5', 'with Fitness', '52.71')
# ('DONE with', 12, 'of', 25, 'of GEN', '5', 'with Fitness', '10.79')
# ('DONE with', 13, 'of', 25, 'of GEN', '5', 'with Fitness', '12.82')
# ('DONE with', 14, 'of', 25, 'of GEN', '5', 'with Fitness', '6.52')
# ('DONE with', 15, 'of', 25, 'of GEN', '5', 'with Fitness', '6.78')
# ('DONE with', 16, 'of', 25, 'of GEN', '5', 'with Fitness', '9.24')
# ('DONE with', 17, 'of', 25, 'of GEN', '5', 'with Fitness', '6.56')
# ('DONE with', 18, 'of', 25, 'of GEN', '5', 'with Fitness', '6.84')
# ('DONE with', 19, 'of', 25, 'of GEN', '5', 'with Fitness', '11.46')
# ('DONE with', 20, 'of', 25, 'of GEN', '5', 'with Fitness', '67.60')
# ('DONE with', 21, 'of', 25, 'of GEN', '5', 'with Fitness', '6.54')
# ('DONE with', 22, 'of', 25, 'of GEN', '5', 'with Fitness', '7.71')
# ('DONE with', 23, 'of', 25, 'of GEN', '5', 'with Fitness', '8.98')
# ('DONE with', 24, 'of', 25, 'of GEN', '5', 'with Fitness', '7.43')
# ('DONE with', 25, 'of', 25, 'of GEN', '5', 'with Fitness', '8.15')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                            0.0006651986380319386
# AfterDepolarizationTimeTest                               -1.7499999999999973
# CellCapacitanceTest                                          -3.4973960484566
# FISlopeTest                                               -1.5454545454545454
# InputResistanceTest                                       -0.5212124254985151
# MembraneTimeConstantTest                                   -1.840909090909091
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        -0.5512572650535428
# RheobaseTest                                               1.3618063816794637
# SagVoltageTest                                             2.9919194475282582
# SpikeAccommodationTest                                    -0.4625346901017586
# SpikeAmplitudeTest                                       [2.6286955736388755]
# SpikeHalfWidthTest                                     -5.796532844358712e-13
# SpikeThresholdTest                                      [-0.6903598926853123]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 8.16% of range. Val: 0.336640311362 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 36.54% of range. Val: 2.40642733396 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 60.01% of range. Val: 92.0156107232 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 87.73% of range. Val: 8.78561737527 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 40.00% of range. Val: 42.003632618 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 41.87% of range. Val: -70.6917613605 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 16.33% of range. Val: -91.8339170086 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 61.17% of range. Val: 0.00244676006006 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 54.71% of range. Val: 5.47092595481 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 54.59% of range. Val: 0.218354304154 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 92.66% of range. Val: 1.4825682137 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 49.02% of range. Val: 2.45076802947 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 21.64% of range. Val: 1.08208538456 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 31.63% of range. Val: 0.253024168431 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 82.86% of range. Val: -18.5719069851 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 10.07% of range. Val: 2.01463275058e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 1.10% of range. Val: 0.00143256397967 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.3366403113617181, 2.4064273339640425, 92.01561072322966, 8.785617375274635, 42.00363261795615, -70.69176136049109, -91.83391700856326, 0.0024467600600583095, 5.4709259548118165, 0.21835430415371615, 1.4825682137030642, 2.450768029467756, 1.0820853845612106, 0.25302416843074527, -18.571906985123345, 2.0146327505831286e-05, 0.0014325639796653362])
# ('Best fitness:', 6.328813214308083)
# ('Generation', 5, 'out of', 200, 'COMPLETE')
# ('GEN', 6, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '6', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '6', 'with Fitness', '42.47')
# ('DONE with', 2, 'of', 25, 'of GEN', '6', 'with Fitness', '23.79')
# ('DONE with', 3, 'of', 25, 'of GEN', '6', 'with Fitness', '15.38')
# ('DONE with', 4, 'of', 25, 'of GEN', '6', 'with Fitness', '7.93')
# ('DONE with', 5, 'of', 25, 'of GEN', '6', 'with Fitness', '23.05')
# ('DONE with', 6, 'of', 25, 'of GEN', '6', 'with Fitness', '107.80')
# ('DONE with', 7, 'of', 25, 'of GEN', '6', 'with Fitness', '37.34')
# ('DONE with', 8, 'of', 25, 'of GEN', '6', 'with Fitness', '16.41')
# ('DONE with', 9, 'of', 25, 'of GEN', '6', 'with Fitness', '16.26')
# ('DONE with', 10, 'of', 25, 'of GEN', '6', 'with Fitness', '12.57')
# ('DONE with', 11, 'of', 25, 'of GEN', '6', 'with Fitness', '11.85')
# ('DONE with', 12, 'of', 25, 'of GEN', '6', 'with Fitness', '10.22')
# ('DONE with', 13, 'of', 25, 'of GEN', '6', 'with Fitness', '7.82')
# ('DONE with', 14, 'of', 25, 'of GEN', '6', 'with Fitness', '6.49')
# ('DONE with', 15, 'of', 25, 'of GEN', '6', 'with Fitness', '10.92')
# ('DONE with', 16, 'of', 25, 'of GEN', '6', 'with Fitness', '4.93')
# ('DONE with', 17, 'of', 25, 'of GEN', '6', 'with Fitness', '10.68')
# ('DONE with', 18, 'of', 25, 'of GEN', '6', 'with Fitness', '6.82')
# ('DONE with', 19, 'of', 25, 'of GEN', '6', 'with Fitness', '6.89')
# ('DONE with', 20, 'of', 25, 'of GEN', '6', 'with Fitness', '8.16')
# ('DONE with', 21, 'of', 25, 'of GEN', '6', 'with Fitness', '6.63')
# ('DONE with', 22, 'of', 25, 'of GEN', '6', 'with Fitness', '61.27')
# ('DONE with', 23, 'of', 25, 'of GEN', '6', 'with Fitness', '6.52')
# ('DONE with', 24, 'of', 25, 'of GEN', '6', 'with Fitness', '7.30')
# ('DONE with', 25, 'of', 25, 'of GEN', '6', 'with Fitness', '10.65')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                             0.006203302209897288
# AfterDepolarizationTimeTest                               -1.6931818181818168
# CellCapacitanceTest                                        -1.837942820174708
# FISlopeTest                                               -1.5454545454545454
# InputResistanceTest                                       0.15696767957740493
# MembraneTimeConstantTest                                  -0.7803030303030304
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        -0.1521008733694304
# RheobaseTest                                               1.1476386799049205
# SagVoltageTest                                             2.9861885471492577
# SpikeAccommodationTest                                     -0.408163265306122
# SpikeAmplitudeTest                                        [1.640509443667394]
# SpikeHalfWidthTest                                         1.3157894736840703
# SpikeThresholdTest                                     [-0.43210654950440514]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 20.81% of range. Val: 0.703438861842 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.35% of range. Val: 1.85897604916 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 73.01% of range. Val: 110.869888747 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 54.53% of range. Val: 5.49819773211 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 29.17% of range. Val: 33.3380895396 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 49.59% of range. Val: -65.2862593471 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 15.97% of range. Val: -92.0159443111 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 5.83% of range. Val: 0.000233151025273 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 68.44% of range. Val: 6.844000163 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 76.76% of range. Val: 0.307027391248 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 96.87% of range. Val: 1.54987847682 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 76.02% of range. Val: 3.80123188374 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 26.66% of range. Val: 1.33324873753 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 45.13% of range. Val: 0.361036608819 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 25.13% of range. Val: -47.4361391308 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 24.36% of range. Val: 4.87142373635e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 13.33% of range. Val: 0.0173252739318 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.703438861842231, 1.858976049156634, 110.86988874667627, 5.498197732114764, 33.33808953963184, -65.2862593470878, -92.01594431114401, 0.00023315102527305773, 6.844000162995925, 0.30702739124838263, 1.5498784768160332, 3.8012318837377483, 1.3332487375256161, 0.36103660881875116, -47.43613913079791, 4.8714237363466645e-05, 0.017325273931793644])
# ('Best fitness:', 4.929533054328613)
# ('Generation', 6, 'out of', 200, 'COMPLETE')
# ('GEN', 7, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '7', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '7', 'with Fitness', '24.27')
# ('DONE with', 2, 'of', 25, 'of GEN', '7', 'with Fitness', '8.81')
# ('DONE with', 3, 'of', 25, 'of GEN', '7', 'with Fitness', '107.12')
# ('DONE with', 4, 'of', 25, 'of GEN', '7', 'with Fitness', '62.94')
# ('DONE with', 5, 'of', 25, 'of GEN', '7', 'with Fitness', '36.96')
# ('DONE with', 6, 'of', 25, 'of GEN', '7', 'with Fitness', '58.57')
# ('DONE with', 7, 'of', 25, 'of GEN', '7', 'with Fitness', '15.77')
# ('DONE with', 8, 'of', 25, 'of GEN', '7', 'with Fitness', '7.98')
# ('DONE with', 9, 'of', 25, 'of GEN', '7', 'with Fitness', '10.68')
# ('DONE with', 10, 'of', 25, 'of GEN', '7', 'with Fitness', '6.16')
# ('DONE with', 11, 'of', 25, 'of GEN', '7', 'with Fitness', '10.35')
# ('DONE with', 12, 'of', 25, 'of GEN', '7', 'with Fitness', '6.66')
# ('DONE with', 13, 'of', 25, 'of GEN', '7', 'with Fitness', '6.50')
# ('DONE with', 14, 'of', 25, 'of GEN', '7', 'with Fitness', '11.09')
# ('DONE with', 15, 'of', 25, 'of GEN', '7', 'with Fitness', '7.52')
# ('DONE with', 16, 'of', 25, 'of GEN', '7', 'with Fitness', '10.33')
# ('DONE with', 17, 'of', 25, 'of GEN', '7', 'with Fitness', '4.80')
# ('DONE with', 18, 'of', 25, 'of GEN', '7', 'with Fitness', '12.57')
# ('DONE with', 19, 'of', 25, 'of GEN', '7', 'with Fitness', '4.67')
# ('DONE with', 20, 'of', 25, 'of GEN', '7', 'with Fitness', '9.51')
# ('DONE with', 21, 'of', 25, 'of GEN', '7', 'with Fitness', '7.61')
# ('DONE with', 22, 'of', 25, 'of GEN', '7', 'with Fitness', '8.75')
# ('DONE with', 23, 'of', 25, 'of GEN', '7', 'with Fitness', '40.94')
# ('DONE with', 24, 'of', 25, 'of GEN', '7', 'with Fitness', '9.68')
# ('DONE with', 25, 'of', 25, 'of GEN', '7', 'with Fitness', '44.29')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                            0.0038273316800001567
# AfterDepolarizationTimeTest                               -1.6988636363636318
# CellCapacitanceTest                                        -0.374613727053345
# FISlopeTest                                               -1.1515151515151516
# InputResistanceTest                                        -0.624767630100342
# MembraneTimeConstantTest                                  -0.6287878787878789
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                       -0.16092515068013655
# RheobaseTest                                               1.7834465329962703
# SagVoltageTest                                              2.988944562094015
# SpikeAccommodationTest                                                    0.0
# SpikeAmplitudeTest                                       [1.8526574017159316]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                      [-0.8030075596613019]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 28.68% of range. Val: 0.931756745425 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.35% of range. Val: 1.85897604916 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 73.01% of range. Val: 110.869888747 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 54.53% of range. Val: 5.49819773211 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 32.53% of range. Val: 36.0238382692 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 49.59% of range. Val: -65.2862593471 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 16.35% of range. Val: -91.8239568678 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 5.83% of range. Val: 0.000233151025273 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 21.53% of range. Val: 2.15325508047 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 76.76% of range. Val: 0.307027391248 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 92.38% of range. Val: 1.47807273912 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 66.63% of range. Val: 3.33126592899 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 26.04% of range. Val: 1.30188639535 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 43.25% of range. Val: 0.346022001356 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 33.78% of range. Val: -43.1089732756 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 36.86% of range. Val: 7.37292692819e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 6.01% of range. Val: 0.00781210194919 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.9317567454251499, 1.858976049156634, 110.86988874667627, 5.498197732114764, 36.0238382692212, -65.2862593470878, -91.8239568677761, 0.00023315102527305773, 2.15325508047457, 0.30702739124838263, 1.478072739124618, 3.331265928990359, 1.3018863953475326, 0.34602200135594574, -43.10897327556184, 7.372926928189645e-05, 0.007812101949192167])
# ('Best fitness:', 4.667819382692957)
# ('Generation', 7, 'out of', 200, 'COMPLETE')
# ('GEN', 8, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '8', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '8', 'with Fitness', '64.10')
# ('DONE with', 2, 'of', 25, 'of GEN', '8', 'with Fitness', '20.31')
# ('DONE with', 3, 'of', 25, 'of GEN', '8', 'with Fitness', '128.71')
# ('DONE with', 4, 'of', 25, 'of GEN', '8', 'with Fitness', '173.74')
# ('DONE with', 5, 'of', 25, 'of GEN', '8', 'with Fitness', '14.08')
# ('DONE with', 6, 'of', 25, 'of GEN', '8', 'with Fitness', '48.58')
# ('DONE with', 7, 'of', 25, 'of GEN', '8', 'with Fitness', '8.35')
# ('DONE with', 8, 'of', 25, 'of GEN', '8', 'with Fitness', '10.55')
# ('DONE with', 9, 'of', 25, 'of GEN', '8', 'with Fitness', '5.47')
# ('DONE with', 10, 'of', 25, 'of GEN', '8', 'with Fitness', '16.93')
# ('DONE with', 11, 'of', 25, 'of GEN', '8', 'with Fitness', '18.29')
# ('DONE with', 12, 'of', 25, 'of GEN', '8', 'with Fitness', '9.56')
# ('DONE with', 13, 'of', 25, 'of GEN', '8', 'with Fitness', '8.85')
# ('DONE with', 14, 'of', 25, 'of GEN', '8', 'with Fitness', '5.30')
# ('DONE with', 15, 'of', 25, 'of GEN', '8', 'with Fitness', '6.29')
# ('DONE with', 16, 'of', 25, 'of GEN', '8', 'with Fitness', '4.87')
# ('DONE with', 17, 'of', 25, 'of GEN', '8', 'with Fitness', '6.54')
# ('DONE with', 18, 'of', 25, 'of GEN', '8', 'with Fitness', '6.33')
# ('DONE with', 19, 'of', 25, 'of GEN', '8', 'with Fitness', '4.79')
# ('DONE with', 20, 'of', 25, 'of GEN', '8', 'with Fitness', '6.87')
# ('DONE with', 21, 'of', 25, 'of GEN', '8', 'with Fitness', '5.11')
# ('DONE with', 22, 'of', 25, 'of GEN', '8', 'with Fitness', '4.84')
# ('DONE with', 23, 'of', 25, 'of GEN', '8', 'with Fitness', '26.45')
# ('DONE with', 24, 'of', 25, 'of GEN', '8', 'with Fitness', '6.27')
# ('DONE with', 25, 'of', 25, 'of GEN', '8', 'with Fitness', '4.93')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                            0.0038273316800001567
# AfterDepolarizationTimeTest                               -1.6988636363636318
# CellCapacitanceTest                                        -0.374613727053345
# FISlopeTest                                               -1.1515151515151516
# InputResistanceTest                                        -0.624767630100342
# MembraneTimeConstantTest                                  -0.6287878787878789
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                       -0.16092515068013655
# RheobaseTest                                               1.7834465329962703
# SagVoltageTest                                              2.988944562094015
# SpikeAccommodationTest                                                    0.0
# SpikeAmplitudeTest                                       [1.8526574017159316]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                      [-0.8030075596613019]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 28.68% of range. Val: 0.931756745425 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.35% of range. Val: 1.85897604916 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 73.01% of range. Val: 110.869888747 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 54.53% of range. Val: 5.49819773211 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 32.53% of range. Val: 36.0238382692 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 49.59% of range. Val: -65.2862593471 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 16.35% of range. Val: -91.8239568678 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 5.83% of range. Val: 0.000233151025273 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 21.53% of range. Val: 2.15325508047 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 76.76% of range. Val: 0.307027391248 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 92.38% of range. Val: 1.47807273912 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 66.63% of range. Val: 3.33126592899 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 26.04% of range. Val: 1.30188639535 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 43.25% of range. Val: 0.346022001356 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 33.78% of range. Val: -43.1089732756 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 36.86% of range. Val: 7.37292692819e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 6.01% of range. Val: 0.00781210194919 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.9317567454251499, 1.858976049156634, 110.86988874667627, 5.498197732114764, 36.0238382692212, -65.2862593470878, -91.8239568677761, 0.00023315102527305773, 2.15325508047457, 0.30702739124838263, 1.478072739124618, 3.331265928990359, 1.3018863953475326, 0.34602200135594574, -43.10897327556184, 7.372926928189645e-05, 0.007812101949192167])
# ('Best fitness:', 4.667819382692957)
# ('Generation', 8, 'out of', 200, 'COMPLETE')
# ('GEN', 9, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '9', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '9', 'with Fitness', '9.66')
# ('DONE with', 2, 'of', 25, 'of GEN', '9', 'with Fitness', '19.55')
# ('DONE with', 3, 'of', 25, 'of GEN', '9', 'with Fitness', '12.26')
# ('DONE with', 4, 'of', 25, 'of GEN', '9', 'with Fitness', '6.59')
# ('DONE with', 5, 'of', 25, 'of GEN', '9', 'with Fitness', '17.41')
# ('DONE with', 6, 'of', 25, 'of GEN', '9', 'with Fitness', '31.84')
# ('DONE with', 7, 'of', 25, 'of GEN', '9', 'with Fitness', '13.92')
# ('DONE with', 8, 'of', 25, 'of GEN', '9', 'with Fitness', '8.24')
# ('DONE with', 9, 'of', 25, 'of GEN', '9', 'with Fitness', '5.74')
# ('DONE with', 10, 'of', 25, 'of GEN', '9', 'with Fitness', '21.48')
# ('DONE with', 11, 'of', 25, 'of GEN', '9', 'with Fitness', '15.95')
# ('DONE with', 12, 'of', 25, 'of GEN', '9', 'with Fitness', '4.98')
# ('DONE with', 13, 'of', 25, 'of GEN', '9', 'with Fitness', '5.10')
# ('DONE with', 14, 'of', 25, 'of GEN', '9', 'with Fitness', '4.85')
# ('DONE with', 15, 'of', 25, 'of GEN', '9', 'with Fitness', '5.51')
# ('DONE with', 16, 'of', 25, 'of GEN', '9', 'with Fitness', '7.43')
# ('DONE with', 17, 'of', 25, 'of GEN', '9', 'with Fitness', '8.25')
# ('DONE with', 18, 'of', 25, 'of GEN', '9', 'with Fitness', '5.76')
# ('DONE with', 19, 'of', 25, 'of GEN', '9', 'with Fitness', '4.78')
# ('DONE with', 20, 'of', 25, 'of GEN', '9', 'with Fitness', '4.97')
# ('DONE with', 21, 'of', 25, 'of GEN', '9', 'with Fitness', '4.75')
# ('DONE with', 22, 'of', 25, 'of GEN', '9', 'with Fitness', '4.66')
# ('DONE with', 23, 'of', 25, 'of GEN', '9', 'with Fitness', '5.50')
# ('DONE with', 24, 'of', 25, 'of GEN', '9', 'with Fitness', '4.54')
# ('DONE with', 25, 'of', 25, 'of GEN', '9', 'with Fitness', '6.49')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                             0.006546724131361259
# AfterDepolarizationTimeTest                               -1.6420454545454513
# CellCapacitanceTest                                       -0.8650909243422816
# FISlopeTest                                                -1.606060606060606
# InputResistanceTest                                        0.2334940315985663
# MembraneTimeConstantTest                                  -0.1742424242424243
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                       -0.14741343318051958
# RheobaseTest                                               1.1561223586891358
# SagVoltageTest                                             2.9789651852755235
# SpikeAccommodationTest                                     -0.408163265306122
# SpikeAmplitudeTest                                       [1.4852504139627276]
# SpikeHalfWidthTest                                         1.3157894736840703
# SpikeThresholdTest                                     [-0.36302454143871443]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 20.81% of range. Val: 0.703438861842 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.35% of range. Val: 1.85897604916 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 73.86% of range. Val: 112.098319747 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 88.69% of range. Val: 8.88071461654 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 29.17% of range. Val: 33.3380895396 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 49.59% of range. Val: -65.2862593471 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 15.96% of range. Val: -92.0219237856 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 5.83% of range. Val: 0.000233151025273 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 68.44% of range. Val: 6.844000163 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 74.41% of range. Val: 0.29764004373 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 96.58% of range. Val: 1.54524117199 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 76.02% of range. Val: 3.80123188374 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 32.35% of range. Val: 1.61738380006 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 45.13% of range. Val: 0.361036608819 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 25.13% of range. Val: -47.4361391308 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 24.36% of range. Val: 4.87142373635e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 13.33% of range. Val: 0.0173252739318 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.703438861842231, 1.858976049156634, 112.0983197468052, 8.880714616544749, 33.33808953963184, -65.2862593470878, -92.02192378563956, 0.00023315102527305773, 6.844000162995925, 0.297640043729925, 1.5452411719946115, 3.8012318837377483, 1.6173838000613032, 0.36103660881875116, -47.43613913079791, 4.8714237363466645e-05, 0.017325273931793644])
# ('Best fitness:', 4.5362194612915765)
# ('Generation', 9, 'out of', 200, 'COMPLETE')
# ('GEN', 10, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '10', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '10', 'with Fitness', '7.32')
# ('DONE with', 2, 'of', 25, 'of GEN', '10', 'with Fitness', '112.67')
# ('DONE with', 3, 'of', 25, 'of GEN', '10', 'with Fitness', '9.50')
# ('DONE with', 4, 'of', 25, 'of GEN', '10', 'with Fitness', '54.02')
# ('DONE with', 5, 'of', 25, 'of GEN', '10', 'with Fitness', '37.85')
# ('DONE with', 6, 'of', 25, 'of GEN', '10', 'with Fitness', '12.26')
# ('DONE with', 7, 'of', 25, 'of GEN', '10', 'with Fitness', '11.30')
# ('DONE with', 8, 'of', 25, 'of GEN', '10', 'with Fitness', '30.37')
# ('DONE with', 9, 'of', 25, 'of GEN', '10', 'with Fitness', '4.85')
# ('DONE with', 10, 'of', 25, 'of GEN', '10', 'with Fitness', '13.22')
# ('DONE with', 11, 'of', 25, 'of GEN', '10', 'with Fitness', '5.42')
# ('DONE with', 12, 'of', 25, 'of GEN', '10', 'with Fitness', '4.88')
# ('DONE with', 13, 'of', 25, 'of GEN', '10', 'with Fitness', '8.56')
# ('DONE with', 14, 'of', 25, 'of GEN', '10', 'with Fitness', '22.79')
# ('DONE with', 15, 'of', 25, 'of GEN', '10', 'with Fitness', '5.74')
# ('DONE with', 16, 'of', 25, 'of GEN', '10', 'with Fitness', '4.57')
# ('DONE with', 17, 'of', 25, 'of GEN', '10', 'with Fitness', '6.43')
# ('DONE with', 18, 'of', 25, 'of GEN', '10', 'with Fitness', '4.75')
# ('DONE with', 19, 'of', 25, 'of GEN', '10', 'with Fitness', '7.15')
# ('DONE with', 20, 'of', 25, 'of GEN', '10', 'with Fitness', '5.83')
# ('DONE with', 21, 'of', 25, 'of GEN', '10', 'with Fitness', '24.54')
# ('DONE with', 22, 'of', 25, 'of GEN', '10', 'with Fitness', '5.72')
# ('DONE with', 23, 'of', 25, 'of GEN', '10', 'with Fitness', '4.92')
# ('DONE with', 24, 'of', 25, 'of GEN', '10', 'with Fitness', '4.72')
# ('DONE with', 25, 'of', 25, 'of GEN', '10', 'with Fitness', '8.68')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                             0.006546724131361259
# AfterDepolarizationTimeTest                               -1.6420454545454513
# CellCapacitanceTest                                       -0.8650909243422816
# FISlopeTest                                                -1.606060606060606
# InputResistanceTest                                        0.2334940315985663
# MembraneTimeConstantTest                                  -0.1742424242424243
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                       -0.14741343318051958
# ...
# 0.16% of range. Val: 0.000206976237278 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.8779752631390383, 1.858976049156634, 110.66782930144701, 3.9732889416523793, 27.681984895293596, -58.08391616048308, -91.92491812845267, 0.00015430675359767468, 4.8308294713153055, 0.1805187512240916, 1.1277751441096302, 1.989811028917615, 1.155885940569044, 0.3619221096015237, -45.459550085137906, 3.236141764651116e-05, 0.00020697623727848618])
# ('Best fitness:', 3.7084813168776862)
# ('Generation', 197, 'out of', 200, 'COMPLETE')
# ('GEN', 198, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '198', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '198', 'with Fitness', '10.58')
# ('DONE with', 2, 'of', 25, 'of GEN', '198', 'with Fitness', '28.47')
# ('DONE with', 3, 'of', 25, 'of GEN', '198', 'with Fitness', '24.71')
# ('DONE with', 4, 'of', 25, 'of GEN', '198', 'with Fitness', '26.27')
# ('DONE with', 5, 'of', 25, 'of GEN', '198', 'with Fitness', '21.24')
# ('DONE with', 6, 'of', 25, 'of GEN', '198', 'with Fitness', '12.78')
# ('DONE with', 7, 'of', 25, 'of GEN', '198', 'with Fitness', '10.78')
# ('DONE with', 8, 'of', 25, 'of GEN', '198', 'with Fitness', '4.94')
# ('DONE with', 9, 'of', 25, 'of GEN', '198', 'with Fitness', '4.38')
# ('DONE with', 10, 'of', 25, 'of GEN', '198', 'with Fitness', '7.22')
# ('DONE with', 11, 'of', 25, 'of GEN', '198', 'with Fitness', '5.90')
# ('DONE with', 12, 'of', 25, 'of GEN', '198', 'with Fitness', '3.99')
# ('DONE with', 13, 'of', 25, 'of GEN', '198', 'with Fitness', '6.35')
# ('DONE with', 14, 'of', 25, 'of GEN', '198', 'with Fitness', '3.71')
# ('DONE with', 15, 'of', 25, 'of GEN', '198', 'with Fitness', '3.71')
# ('DONE with', 16, 'of', 25, 'of GEN', '198', 'with Fitness', '13.51')
# ('DONE with', 17, 'of', 25, 'of GEN', '198', 'with Fitness', '3.71')
# ('DONE with', 18, 'of', 25, 'of GEN', '198', 'with Fitness', '3.71')
# ('DONE with', 19, 'of', 25, 'of GEN', '198', 'with Fitness', '3.99')
# ('DONE with', 20, 'of', 25, 'of GEN', '198', 'with Fitness', '3.71')
# ('DONE with', 21, 'of', 25, 'of GEN', '198', 'with Fitness', '14.12')
# ('DONE with', 22, 'of', 25, 'of GEN', '198', 'with Fitness', '11.23')
# ('DONE with', 23, 'of', 25, 'of GEN', '198', 'with Fitness', '4.46')
# ('DONE with', 24, 'of', 25, 'of GEN', '198', 'with Fitness', '3.71')
# ('DONE with', 25, 'of', 25, 'of GEN', '198', 'with Fitness', '3.92')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                              0.01562793281537722
# AfterDepolarizationTimeTest                               -1.6249999999999962
# CellCapacitanceTest                                       -0.3071835504738805
# FISlopeTest                                               -0.6666666666666666
# InputResistanceTest                                       0.27840106170594225
# MembraneTimeConstantTest                                  0.12878787878787873
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        0.22478879133160307
# RheobaseTest                                               0.7038014640579748
# SagVoltageTest                                              2.976074598938077
# SpikeAccommodationTest                                                    0.0
# SpikeAmplitudeTest                                       [0.7746811486552202]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                     [-0.20789880117357704]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 26.83% of range. Val: 0.877975263139 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.35% of range. Val: 1.85897604916 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 72.87% of range. Val: 110.667829301 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 39.12% of range. Val: 3.97328894165 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 22.10% of range. Val: 27.6819848953 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 59.88% of range. Val: -58.0839161605 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 16.15% of range. Val: -91.9249181285 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 3.86% of range. Val: 0.000154306753598 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 48.31% of range. Val: 4.83082947132 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 45.13% of range. Val: 0.180518751224 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 70.49% of range. Val: 1.12777514411 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 39.80% of range. Val: 1.98981102892 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 23.12% of range. Val: 1.15588594057 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 45.24% of range. Val: 0.361922109602 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 29.08% of range. Val: -45.4595500851 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 16.18% of range. Val: 3.23614176465e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 0.16% of range. Val: 0.000206976237278 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.8779752631390383, 1.858976049156634, 110.66782930144701, 3.9732889416523793, 27.681984895293596, -58.08391616048308, -91.92491812845267, 0.00015430675359767468, 4.8308294713153055, 0.1805187512240916, 1.1277751441096302, 1.989811028917615, 1.155885940569044, 0.3619221096015237, -45.459550085137906, 3.236141764651116e-05, 0.00020697623727848618])
# ('Best fitness:', 3.7084813168776862)
# ('Generation', 198, 'out of', 200, 'COMPLETE')
# ('GEN', 199, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '199', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '199', 'with Fitness', '35.37')
# ('DONE with', 2, 'of', 25, 'of GEN', '199', 'with Fitness', '12.25')
# ('DONE with', 3, 'of', 25, 'of GEN', '199', 'with Fitness', '14.11')
# ('DONE with', 4, 'of', 25, 'of GEN', '199', 'with Fitness', '19.63')
# ('DONE with', 5, 'of', 25, 'of GEN', '199', 'with Fitness', '30.03')
# ('DONE with', 6, 'of', 25, 'of GEN', '199', 'with Fitness', '17.30')
# ('DONE with', 7, 'of', 25, 'of GEN', '199', 'with Fitness', '4.22')
# ('DONE with', 8, 'of', 25, 'of GEN', '199', 'with Fitness', '26.61')
# ('DONE with', 9, 'of', 25, 'of GEN', '199', 'with Fitness', '3.71')
# ('DONE with', 10, 'of', 25, 'of GEN', '199', 'with Fitness', '4.09')
# ('DONE with', 11, 'of', 25, 'of GEN', '199', 'with Fitness', '25.83')
# ('DONE with', 12, 'of', 25, 'of GEN', '199', 'with Fitness', '27.34')
# ('DONE with', 13, 'of', 25, 'of GEN', '199', 'with Fitness', '3.83')
# ('DONE with', 14, 'of', 25, 'of GEN', '199', 'with Fitness', '3.71')
# ('DONE with', 15, 'of', 25, 'of GEN', '199', 'with Fitness', '6.10')
# ('DONE with', 16, 'of', 25, 'of GEN', '199', 'with Fitness', '7.40')
# ('DONE with', 17, 'of', 25, 'of GEN', '199', 'with Fitness', '4.76')
# ('DONE with', 18, 'of', 25, 'of GEN', '199', 'with Fitness', '3.86')
# ('DONE with', 19, 'of', 25, 'of GEN', '199', 'with Fitness', '3.71')
# ('DONE with', 20, 'of', 25, 'of GEN', '199', 'with Fitness', '4.33')
# ('DONE with', 21, 'of', 25, 'of GEN', '199', 'with Fitness', '4.94')
# ('DONE with', 22, 'of', 25, 'of GEN', '199', 'with Fitness', '3.87')
# ('DONE with', 23, 'of', 25, 'of GEN', '199', 'with Fitness', '3.88')
# ('DONE with', 24, 'of', 25, 'of GEN', '199', 'with Fitness', '6.66')
# ('DONE with', 25, 'of', 25, 'of GEN', '199', 'with Fitness', '5.97')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                              0.01562793281537722
# AfterDepolarizationTimeTest                               -1.6249999999999962
# CellCapacitanceTest                                       -0.3071835504738805
# FISlopeTest                                               -0.6666666666666666
# InputResistanceTest                                       0.27840106170594225
# MembraneTimeConstantTest                                  0.12878787878787873
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        0.22478879133160307
# RheobaseTest                                               0.7038014640579748
# SagVoltageTest                                              2.976074598938077
# SpikeAccommodationTest                                                    0.0
# SpikeAmplitudeTest                                       [0.7746811486552202]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                     [-0.20789880117357704]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 26.83% of range. Val: 0.877975263139 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.35% of range. Val: 1.85897604916 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 72.87% of range. Val: 110.667829301 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 39.12% of range. Val: 3.97328894165 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 22.10% of range. Val: 27.6819848953 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 59.88% of range. Val: -58.0839161605 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 16.15% of range. Val: -91.9249181285 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 3.86% of range. Val: 0.000154306753598 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 48.31% of range. Val: 4.83082947132 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 45.13% of range. Val: 0.180518751224 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 70.49% of range. Val: 1.12777514411 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 39.80% of range. Val: 1.98981102892 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 23.12% of range. Val: 1.15588594057 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 45.24% of range. Val: 0.361922109602 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 29.08% of range. Val: -45.4595500851 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 16.18% of range. Val: 3.23614176465e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 0.16% of range. Val: 0.000206976237278 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.8779752631390383, 1.858976049156634, 110.66782930144701, 3.9732889416523793, 27.681984895293596, -58.08391616048308, -91.92491812845267, 0.00015430675359767468, 4.8308294713153055, 0.1805187512240916, 1.1277751441096302, 1.989811028917615, 1.155885940569044, 0.3619221096015237, -45.459550085137906, 3.236141764651116e-05, 0.00020697623727848618])
# ('Best fitness:', 3.7084813168776862)
# ('Generation', 199, 'out of', 200, 'COMPLETE')
# ('GEN', 200, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '200', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '200', 'with Fitness', '11.96')
# ('DONE with', 2, 'of', 25, 'of GEN', '200', 'with Fitness', '61.04')
# ('DONE with', 3, 'of', 25, 'of GEN', '200', 'with Fitness', '89.35')
# ('DONE with', 4, 'of', 25, 'of GEN', '200', 'with Fitness', '101.90')
# ('DONE with', 5, 'of', 25, 'of GEN', '200', 'with Fitness', '18.54')
# ('DONE with', 6, 'of', 25, 'of GEN', '200', 'with Fitness', '22.47')
# ('DONE with', 7, 'of', 25, 'of GEN', '200', 'with Fitness', '6.89')
# ('DONE with', 8, 'of', 25, 'of GEN', '200', 'with Fitness', '7.60')
# ('DONE with', 9, 'of', 25, 'of GEN', '200', 'with Fitness', '11.34')
# ('DONE with', 10, 'of', 25, 'of GEN', '200', 'with Fitness', '34.19')
# ('DONE with', 11, 'of', 25, 'of GEN', '200', 'with Fitness', '5.44')
# ('DONE with', 12, 'of', 25, 'of GEN', '200', 'with Fitness', '31.38')
# ('DONE with', 13, 'of', 25, 'of GEN', '200', 'with Fitness', '6.17')
# ('DONE with', 14, 'of', 25, 'of GEN', '200', 'with Fitness', '3.91')
# ('DONE with', 15, 'of', 25, 'of GEN', '200', 'with Fitness', '3.71')
# ('DONE with', 16, 'of', 25, 'of GEN', '200', 'with Fitness', '3.91')
# ('DONE with', 17, 'of', 25, 'of GEN', '200', 'with Fitness', '3.71')
# ('DONE with', 18, 'of', 25, 'of GEN', '200', 'with Fitness', '3.71')
# ('DONE with', 19, 'of', 25, 'of GEN', '200', 'with Fitness', '3.71')
# ('DONE with', 20, 'of', 25, 'of GEN', '200', 'with Fitness', '3.71')
# ('DONE with', 21, 'of', 25, 'of GEN', '200', 'with Fitness', '3.86')
# ('DONE with', 22, 'of', 25, 'of GEN', '200', 'with Fitness', '3.71')
# ('DONE with', 23, 'of', 25, 'of GEN', '200', 'with Fitness', '3.71')
# ('DONE with', 24, 'of', 25, 'of GEN', '200', 'with Fitness', '4.99')
# ('DONE with', 25, 'of', 25, 'of GEN', '200', 'with Fitness', '4.66')
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                              0.01562793281537722
# AfterDepolarizationTimeTest                               -1.6249999999999962
# CellCapacitanceTest                                       -0.3071835504738805
# FISlopeTest                                               -0.6666666666666666
# InputResistanceTest                                       0.27840106170594225
# MembraneTimeConstantTest                                  0.12878787878787873
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        0.22478879133160307
# RheobaseTest                                               0.7038014640579748
# SagVoltageTest                                              2.976074598938077
# SpikeAccommodationTest                                                    0.0
# SpikeAmplitudeTest                                       [0.7746811486552202]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                     [-0.20789880117357704]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 26.83% of range. Val: 0.877975263139 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.35% of range. Val: 1.85897604916 Low: 0.89 High: 5.04 ATTR: L in ['somatic']
# 72.87% of range. Val: 110.667829301 Low: 5.0 High: 150.0 ATTR: Ra in ['all']
# 39.12% of range. Val: 3.97328894165 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 22.10% of range. Val: 27.6819848953 Low: 10.0 High: 90.0 ATTR: ena in ['all']
# 59.88% of range. Val: -58.0839161605 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 16.15% of range. Val: -91.9249181285 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 3.86% of range. Val: 0.000154306753598 Low: 0 High: 0.004 ATTR: g_pas in ['all']
# 48.31% of range. Val: 4.83082947132 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 45.13% of range. Val: 0.180518751224 Low: 0 High: 0.4 ATTR: gbar_Na in ['apical']
# 70.49% of range. Val: 1.12777514411 Low: 0 High: 1.6 ATTR: gbar_Kd in ['apical']
# 39.80% of range. Val: 1.98981102892 Low: 0 High: 5.0 ATTR: gbar_Na in ['somatic']
# 23.12% of range. Val: 1.15588594057 Low: 0 High: 5.0 ATTR: gbar_Kd in ['somatic']
# 45.24% of range. Val: 0.361922109602 Low: 0 High: 0.8 ATTR: gbar_KA in ['somatic']
# 29.08% of range. Val: -45.4595500851 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 16.18% of range. Val: 3.23614176465e-05 Low: 0 High: 0.0002 ATTR: gbar_Ih in ['somatic']
# 0.16% of range. Val: 0.000206976237278 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Best individual', [0.8779752631390383, 1.858976049156634, 110.66782930144701, 3.9732889416523793, 27.681984895293596, -58.08391616048308, -91.92491812845267, 0.00015430675359767468, 4.8308294713153055, 0.1805187512240916, 1.1277751441096302, 1.989811028917615, 1.155885940569044, 0.3619221096015237, -45.459550085137906, 3.236141764651116e-05, 0.00020697623727848618])
# ('Best fitness:', 3.7084813168776862)
# ('Generation', 200, 'out of', 200, 'COMPLETE')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a70bc2619298> in <module>()
#       2 #fitter.top = [[0.518568993696911, 22.331096575385537, 3.9991551066170175, 44.54836939907614, -55.16528090080958, -89.29463560245307, 0.00018368809366833735, 2.922232364299777, 0.07465156310126753, 0.19498287109045842, 0.03935002363776688, -49.39660394446575, 2.548528534052994e-06, 0.006660630409332343]]
#       3 fitter.fit(25, 200)
# ----> 4 raise
#
# TypeError: exceptions must be old-style classes or derived from BaseException, not NoneType

# %%
fitter.best = []

# %%
df, score = fitter.get_best_score()
print(score["model_score"]) 
df.transpose()

# %%
raise

# %%
from prev_ob_models.Birgiolas2020.isolated_cells import GC2
gc = GC2()
gc.param_values

# %%
from scipy.optimize import minimize
def evaluate(ind):
    print(ind)
    score = float(fitter.evaluate(ind)[0])
    print("score", score)
    return score

min_res = minimize(evaluate, gc.param_values, method='Powell', 
                   options={"disp":False, "maxfev":45, "maxiter":100})#,"xtol":0.1,"ftol":0.1})
min_res

# %%
raise

# %%
fitter.clear_cache()

# %%
fitter.fit(20, 7)

# %%
fitter.parameter_report(fitter.best)

# %%
raise

# %%
#fitter.clear_cache()
#fitter.best = []
df, score = fitter.get_best_score()
print(score["model_score"]) 
df.transpose()

# %%
score

# %%
fitter.clear_cache()
df = fitter.get_previous_model_scores()
df

# %%
df.to_csv("ephyz/"+fitter.cell_type+"_model_zscores.csv")

# %%
raise

# %%
np.linspace(0,100,0.1)

# %%
score["model_score"]

# %%
raise

# %%
fitter.top = None

# %%
cpus = multiprocessing.cpu_count()
fitter.fit(int(cpus*1.5), 48)

# %%
fitter.clear_cache()
fitter.best = []
df, score = fitter.get_best_score()
df

# %%
score["model_score"]

# %%
fitter.pretty_pop()

# %%
from prev_ob_models.Birgiolas2020.isolated_cells import MC1
mc = MC1()

# %%
fitter.print_params(fitter.best, mc.cell)
