# %%
from olfactorybulb.database import *
import os,sys
from neuronunit.tests.morphology import *
from neuronunit.models.morphology import SwcCellModel
from sciunit.suites import TestSuite
from pandas import DataFrame
# Out:
# Could not load HHpyNNBackend.

# %%
def get_swc_models_from_files(dir):
    files = os.listdir(dir)
    files = [os.path.join(dir,file) for file in files if file.endswith('.swc')]
    models = [SwcCellModel(file) for file in files]
    return models

# %%
from quantities import um
blank_obs = {'mean': 0, 'n': 1, 'std': 1}
blank_obs_um = {'mean': 0*um, 'n': 1, 'std': 1*um}
blank_obs_um2 = {'mean': 0*um**2, 'n': 1, 'std': 1*um**2}
blank_obs_um3 = {'mean': 0*um**3, 'n': 1, 'std': 1*um**3}

soma_tests = [    
    SomaSurfaceAreaTest(blank_obs_um2),
    NumberofStemsTest(blank_obs),
]

basal_tests = [    
    BasalDendriteNumberofBifurcationsTest(blank_obs),
    BasalDendriteNumberofBranchesTest(blank_obs),
    BasalDendriteOverallWidthTest(blank_obs_um),
    BasalDendriteOverallHeightTest(blank_obs_um),
    BasalDendriteOverallDepthTest(blank_obs_um),
    BasalDendriteAverageDiameterTest(blank_obs_um),
    BasalDendriteTotalLengthTest(blank_obs_um),
    BasalDendriteTotalSurfaceTest(blank_obs_um2),
    BasalDendriteTotalVolumeTest(blank_obs_um3),
    BasalDendriteMaxEuclideanDistanceTest(blank_obs_um),
    BasalDendriteMaxPathDistanceTest(blank_obs_um),
    BasalDendriteMaxBranchOrderTest(blank_obs),
    BasalDendriteAverageContractionTest(blank_obs),
    BasalDendritePartitionAsymmetryTest(blank_obs),
    BasalDendriteAverageRallsRatioTest(blank_obs),
    BasalDendriteAverageBifurcationAngleLocalTest(blank_obs),
    BasalDendriteAverageBifurcationAngleRemoteTest(blank_obs),
    BasalDendriteFractalDimensionTest(blank_obs),
]

apical_tests = [    
    ApicalDendriteNumberofBifurcationsTest(blank_obs),
    ApicalDendriteNumberofBranchesTest(blank_obs),
    ApicalDendriteOverallWidthTest(blank_obs_um),
    ApicalDendriteOverallHeightTest(blank_obs_um),
    ApicalDendriteOverallDepthTest(blank_obs_um),
    ApicalDendriteAverageDiameterTest(blank_obs_um),
    ApicalDendriteTotalLengthTest(blank_obs_um),
    ApicalDendriteTotalSurfaceTest(blank_obs_um2),
    ApicalDendriteTotalVolumeTest(blank_obs_um3),
    ApicalDendriteMaxEuclideanDistanceTest(blank_obs_um),
    ApicalDendriteMaxPathDistanceTest(blank_obs_um),
    ApicalDendriteMaxBranchOrderTest(blank_obs),
    ApicalDendriteAverageContractionTest(blank_obs),
    ApicalDendritePartitionAsymmetryTest(blank_obs),
    ApicalDendriteAverageRallsRatioTest(blank_obs),
    ApicalDendriteAverageBifurcationAngleLocalTest(blank_obs),
    ApicalDendriteAverageBifurcationAngleRemoteTest(blank_obs),
    ApicalDendriteFractalDimensionTest(blank_obs),
]

full_slice_only_tests = [
    'ApicalDendriteNumberofBifurcationsTest', 
    'ApicalDendriteNumberofBranchesTest',
    'ApicalDendriteOverallDepthTest',
    'ApicalDendriteTotalLengthTest',
    'ApicalDendriteTotalSurfaceTest',
    'ApicalDendriteTotalVolumeTest',
    
    'BasalDendriteNumberofBifurcationsTest', 
    'BasalDendriteNumberofBranchesTest',
    'BasalDendriteOverallDepthTest',
    'BasalDendriteTotalLengthTest',
    'BasalDendriteTotalSurfaceTest',
    'BasalDendriteTotalVolumeTest',
]

full_diameter_only_tests = [
    'ApicalDendriteAverageDiameterTest',
    'ApicalDendriteTotalSurfaceTest',
    'ApicalDendriteTotalVolumeTest',
    'ApicalDendriteAverageContractionTest',
    'ApicalDendriteAverageRallsRatioTest',
    
    'BasalDendriteAverageDiameterTest',
    'BasalDendriteTotalSurfaceTest',
    'BasalDendriteTotalVolumeTest',
    'BasalDendriteAverageContractionTest',
    'BasalDendriteAverageRallsRatioTest',
]

soma_suite = TestSuite(soma_tests)
basal_suite = TestSuite(basal_tests)
apical_suite = TestSuite(apical_tests)

# %%
def get_property_id(CellShort, test):
    test_to_property_map = {
        "SomaSurfaceAreaTest": CellShort + "_Soma_Surface_Area",
        "NumberofStemsTest": CellShort + "_Number_of_Stems",
        "BasalDendriteNumberofBifurcationsTest": CellShort + "_Basal_Dendrite_Number_of_Bifurcations",
        "BasalDendriteNumberofBranchesTest": CellShort + "_Basal_Dendrite_Number_of_Branches",
        "BasalDendriteOverallWidthTest": CellShort + "_Basal_Dendrite_Overall_Width",
        "BasalDendriteOverallHeightTest": CellShort + "_Basal_Dendrite_Overall_Height",
        "BasalDendriteOverallDepthTest": CellShort + "_Basal_Dendrite_Overall_Depth",
        "BasalDendriteAverageDiameterTest": CellShort + "_Basal_Dendrite_Average_Diameter",
        "BasalDendriteTotalLengthTest": CellShort + "_Basal_Dendrite_Total_Length",
        "BasalDendriteTotalSurfaceTest": CellShort + "_Basal_Dendrite_Total_Surface",
        "BasalDendriteTotalVolumeTest": CellShort + "_Basal_Dendrite_Total_Volume",
        "BasalDendriteMaxEuclideanDistanceTest": CellShort + "_Basal_Dendrite_Max_Euclidean_Distance",
        "BasalDendriteMaxPathDistanceTest": CellShort + "_Basal_Dendrite_Max_Path_Distance",
        "BasalDendriteMaxBranchOrderTest": CellShort + "_Basal_Dendrite_Max_Branch_Order",
        "BasalDendriteAverageContractionTest": CellShort + "_Basal_Dendrite_Average_Contraction",
        "BasalDendritePartitionAsymmetryTest": CellShort + "_Basal_Dendrite_Partition_Asymmetry",
        "BasalDendriteAverageRallsRatioTest": CellShort + "_Basal_Dendrite_Average_Ralls_Ratio",
        "BasalDendriteAverageBifurcationAngleLocalTest": CellShort + "_Basal_Dendrite_Average_Bifurcation_Angle_Local",
        "BasalDendriteAverageBifurcationAngleRemoteTest": CellShort + "_Basal_Dendrite_Average_Bifurcation_Angle_Remote",
        "BasalDendriteFractalDimensionTest": CellShort + "_Basal_Dendrite_Fractal_Dimension",
        "ApicalDendriteNumberofBifurcationsTest": CellShort + "_Apical_Dendrite_Number_of_Bifurcations",
        "ApicalDendriteNumberofBranchesTest": CellShort + "_Apical_Dendrite_Number_of_Branches",
        "ApicalDendriteOverallWidthTest": CellShort + "_Apical_Dendrite_Overall_Width",
        "ApicalDendriteOverallHeightTest": CellShort + "_Apical_Dendrite_Overall_Height",
        "ApicalDendriteOverallDepthTest": CellShort + "_Apical_Dendrite_Overall_Depth",
        "ApicalDendriteAverageDiameterTest": CellShort + "_Apical_Dendrite_Average_Diameter",
        "ApicalDendriteTotalLengthTest": CellShort + "_Apical_Dendrite_Total_Length",
        "ApicalDendriteTotalSurfaceTest": CellShort + "_Apical_Dendrite_Total_Surface",
        "ApicalDendriteTotalVolumeTest": CellShort + "_Apical_Dendrite_Total_Volume",
        "ApicalDendriteMaxEuclideanDistanceTest": CellShort + "_Apical_Dendrite_Max_Euclidean_Distance",
        "ApicalDendriteMaxPathDistanceTest": CellShort + "_Apical_Dendrite_Max_Path_Distance",
        "ApicalDendriteMaxBranchOrderTest": CellShort + "_Apical_Dendrite_Max_Branch_Order",
        "ApicalDendriteAverageContractionTest": CellShort + "_Apical_Dendrite_Average_Contraction",
        "ApicalDendritePartitionAsymmetryTest": CellShort + "_Apical_Dendrite_Partition_Asymmetry",
        "ApicalDendriteAverageRallsRatioTest": CellShort + "_Apical_Dendrite_Average_Ralls_Ratio",
        "ApicalDendriteAverageBifurcationAngleLocalTest": CellShort + "_Apical_Dendrite_Average_Bifurcation_Angle_Local",
        "ApicalDendriteAverageBifurcationAngleRemoteTest": CellShort + "_Apical_Dendrite_Average_Bifurcation_Angle_Remote",
        "ApicalDendriteFractalDimensionTest": CellShort + "_Apical_Dendrite_Fractal_Dimension",
    }
    
    return test_to_property_map[test]

# %%
def compute_morphology_stats(dir, CellShort, test_set, exclude, source_id):
    models = get_swc_models_from_files(dir)
    
    test_results = {}
    for m, model in enumerate(models):
        for test in test_set:
            test_name = test.__class__.__name__
            
            if test_name in exclude:
                continue
            
            prediction = test.generate_prediction(model)["mean"]

            if test_name not in test_results:
                test_results[test_name] = []

            test_results[test_name].append(prediction)
        
        print(m+1,"out of", len(models))

    import numpy as np
    import re

    for key in test_results:
        test_results[key] = {
            'mean': np.mean(test_results[key]),
            'std': np.std(test_results[key]),
            'n': len(test_results[key]),
            'property_id': get_property_id(CellShort, key),
            'source_id': source_id,
        }

    no_0_stdev = {}
    for key in test_results:
        if test_results[key]['std'] > 0:
            no_0_stdev[key] = test_results[key]
    test_results = no_0_stdev
    
    return test_results

# %% [markdown]
# ## Caile GC archive
#
# Computed soma and thin slice metrics for apical dends

# %%
# Apical
stats = compute_morphology_stats(dir='morphology-data/GCs/Caile-granule/done/',
                             CellShort="GC", 
                             test_set=apical_tests, 
                             exclude=full_slice_only_tests,
                             source_id=28)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 29)
# (2, 'out of', 29)
# (3, 'out of', 29)
# (4, 'out of', 29)
# (5, 'out of', 29)
# (6, 'out of', 29)
# (7, 'out of', 29)
# (8, 'out of', 29)
# (9, 'out of', 29)
# (10, 'out of', 29)
# (11, 'out of', 29)
# (12, 'out of', 29)
# (13, 'out of', 29)
# (14, 'out of', 29)
# (15, 'out of', 29)
# (16, 'out of', 29)
# (17, 'out of', 29)
# (18, 'out of', 29)
# (19, 'out of', 29)
# (20, 'out of', 29)
# (21, 'out of', 29)
# (22, 'out of', 29)
# (23, 'out of', 29)
# (24, 'out of', 29)
# (25, 'out of', 29)
# (26, 'out of', 29)
# (27, 'out of', 29)
# (28, 'out of', 29)
# (29, 'out of', 29)
#           mean   n                                        property_id  \
# 11   77.068534  29  GC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0    47.617846  29  GC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3     0.865666  29             GC_Apical_Dendrite_Average_Contraction
# 5     1.458592  29                GC_Apical_Dendrite_Average_Diameter
# 2     1.556345  29             GC_Apical_Dendrite_Average_Ralls_Ratio
# 8     1.045090  29               GC_Apical_Dendrite_Fractal_Dimension
# 1     3.965517  29                GC_Apical_Dendrite_Max_Branch_Order
# 7   346.459138  29          GC_Apical_Dendrite_Max_Euclidean_Distance
# 6   422.015138  29               GC_Apical_Dendrite_Max_Path_Distance
# 4   329.229345  29                  GC_Apical_Dendrite_Overall_Height
# 10   94.774928  29                   GC_Apical_Dendrite_Overall_Width
# 9     0.486978  29             GC_Apical_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 11         28  12.870561
# 0          28  14.176866
# 3          28   0.044090
# 5          28   0.261143
# 2          28   0.654360
# 8          28   0.022585
# 1          28   1.496727
# 7          28  76.262354
# 6          28  89.305999
# 4          28  74.917655
# 10         28  44.360856
# 9          28   0.197178

# %%
Measurement.insert(stats).execute()
# Out:
# 286

# %%
# Basal
stats = compute_morphology_stats(dir='morphology-data/GCs/Caile-granule/done/',
                             CellShort="GC", 
                             test_set=basal_tests, 
                             exclude=full_slice_only_tests,
                             source_id=28)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 29)
# (2, 'out of', 29)
# (3, 'out of', 29)
# (4, 'out of', 29)
# (5, 'out of', 29)
# (6, 'out of', 29)
# (7, 'out of', 29)
# (8, 'out of', 29)
# (9, 'out of', 29)
# (10, 'out of', 29)
# (11, 'out of', 29)
# (12, 'out of', 29)
# (13, 'out of', 29)
# (14, 'out of', 29)
# (15, 'out of', 29)
# (16, 'out of', 29)
# (17, 'out of', 29)
# (18, 'out of', 29)
# (19, 'out of', 29)
# (20, 'out of', 29)
# (21, 'out of', 29)
# (22, 'out of', 29)
# (23, 'out of', 29)
# (24, 'out of', 29)
# (25, 'out of', 29)
# (26, 'out of', 29)
# (27, 'out of', 29)
# (28, 'out of', 29)
# (29, 'out of', 29)
#          mean   n                                        property_id  \
# 9   44.155803  29  GC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4   35.131272  29  GC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 11   0.710333  29              GC_Basal_Dendrite_Average_Contraction
# 1    1.330479  29                 GC_Basal_Dendrite_Average_Diameter
# 8    1.145894  29              GC_Basal_Dendrite_Average_Ralls_Ratio
# 3    0.750165  29                GC_Basal_Dendrite_Fractal_Dimension
# 7    0.758621  29                 GC_Basal_Dendrite_Max_Branch_Order
# 2   46.342210  29           GC_Basal_Dendrite_Max_Euclidean_Distance
# 6   55.350517  29                GC_Basal_Dendrite_Max_Path_Distance
# 0   35.902389  29                   GC_Basal_Dendrite_Overall_Height
# 5   43.936910  29                    GC_Basal_Dendrite_Overall_Width
# 10   0.059387  29              GC_Basal_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 9          28  44.914155
# 4          28  34.114932
# 11         28   0.365278
# 1          28   1.026912
# 8          28   1.411178
# 3          28   0.463174
# 7          28   0.816011
# 2          28  32.805706
# 6          28  38.847950
# 0          28  28.929323
# 5          28  36.114457
# 10         28   0.155042

# %%
Measurement.insert(stats).execute()
# Out:
# 298

# %%
# Soma
stats = compute_morphology_stats(dir='morphology-data/GCs/Caile-granule/done/',
                             CellShort="GC", 
                             test_set=soma_tests, 
                             exclude=full_slice_only_tests,
                             source_id=28)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 29)
# (2, 'out of', 29)
# (3, 'out of', 29)
# (4, 'out of', 29)
# (5, 'out of', 29)
# (6, 'out of', 29)
# (7, 'out of', 29)
# (8, 'out of', 29)
# (9, 'out of', 29)
# (10, 'out of', 29)
# (11, 'out of', 29)
# (12, 'out of', 29)
# (13, 'out of', 29)
# (14, 'out of', 29)
# (15, 'out of', 29)
# (16, 'out of', 29)
# (17, 'out of', 29)
# (18, 'out of', 29)
# (19, 'out of', 29)
# (20, 'out of', 29)
# (21, 'out of', 29)
# (22, 'out of', 29)
# (23, 'out of', 29)
# (24, 'out of', 29)
# (25, 'out of', 29)
# (26, 'out of', 29)
# (27, 'out of', 29)
# (28, 'out of', 29)
# (29, 'out of', 29)
#          mean   n           property_id  source_id        std
# 1    3.000000  29    GC_Number_of_Stems         28   1.531283
# 0  210.936755  29  GC_Soma_Surface_Area         28  77.956143

# %%
Measurement.insert(stats).execute()
# Out:
# 300

# %% [markdown]
# ## Denizet GC archive - Denizet 2017 paper
#
# Thin, no soma

# %%
dir = 'morphology-data/GCs/Denizet-granule/Denizet2017'
cell = "GC"
exclude = full_slice_only_tests
source_id=29

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 278)
# (2, 'out of', 278)
# (3, 'out of', 278)
# (4, 'out of', 278)
# (5, 'out of', 278)
# (6, 'out of', 278)
# (7, 'out of', 278)
# (8, 'out of', 278)
# (9, 'out of', 278)
# (10, 'out of', 278)
# (11, 'out of', 278)
# (12, 'out of', 278)
# (13, 'out of', 278)
# (14, 'out of', 278)
# (15, 'out of', 278)
# (16, 'out of', 278)
# (17, 'out of', 278)
# (18, 'out of', 278)
# (19, 'out of', 278)
# (20, 'out of', 278)
# (21, 'out of', 278)
# (22, 'out of', 278)
# (23, 'out of', 278)
# (24, 'out of', 278)
# (25, 'out of', 278)
# (26, 'out of', 278)
# (27, 'out of', 278)
# (28, 'out of', 278)
# (29, 'out of', 278)
# (30, 'out of', 278)
# (31, 'out of', 278)
# (32, 'out of', 278)
# (33, 'out of', 278)
# (34, 'out of', 278)
# (35, 'out of', 278)
# (36, 'out of', 278)
# (37, 'out of', 278)
# (38, 'out of', 278)
# (39, 'out of', 278)
# (40, 'out of', 278)
# (41, 'out of', 278)
# (42, 'out of', 278)
# (43, 'out of', 278)
# (44, 'out of', 278)
# (45, 'out of', 278)
# (46, 'out of', 278)
# (47, 'out of', 278)
# (48, 'out of', 278)
# (49, 'out of', 278)
# (50, 'out of', 278)
# (51, 'out of', 278)
# (52, 'out of', 278)
# (53, 'out of', 278)
# (54, 'out of', 278)
# (55, 'out of', 278)
# (56, 'out of', 278)
# (57, 'out of', 278)
# (58, 'out of', 278)
# (59, 'out of', 278)
# (60, 'out of', 278)
# (61, 'out of', 278)
# (62, 'out of', 278)
# (63, 'out of', 278)
# (64, 'out of', 278)
# (65, 'out of', 278)
# (66, 'out of', 278)
# (67, 'out of', 278)
# (68, 'out of', 278)
# (69, 'out of', 278)
# (70, 'out of', 278)
# (71, 'out of', 278)
# (72, 'out of', 278)
# (73, 'out of', 278)
# (74, 'out of', 278)
# (75, 'out of', 278)
# (76, 'out of', 278)
# (77, 'out of', 278)
# (78, 'out of', 278)
# (79, 'out of', 278)
# (80, 'out of', 278)
# (81, 'out of', 278)
# (82, 'out of', 278)
# (83, 'out of', 278)
# (84, 'out of', 278)
# (85, 'out of', 278)
# (86, 'out of', 278)
# (87, 'out of', 278)
# (88, 'out of', 278)
# (89, 'out of', 278)
# (90, 'out of', 278)
# (91, 'out of', 278)
# (92, 'out of', 278)
# (93, 'out of', 278)
# (94, 'out of', 278)
# (95, 'out of', 278)
# (96, 'out of', 278)
# (97, 'out of', 278)
# (98, 'out of', 278)
# (99, 'out of', 278)
# (100, 'out of', 278)
# (101, 'out of', 278)
# (102, 'out of', 278)
# (103, 'out of', 278)
# (104, 'out of', 278)
# (105, 'out of', 278)
# (106, 'out of', 278)
# (107, 'out of', 278)
# (108, 'out of', 278)
# (109, 'out of', 278)
# (110, 'out of', 278)
# (111, 'out of', 278)
# (112, 'out of', 278)
# (113, 'out of', 278)
# (114, 'out of', 278)
# (115, 'out of', 278)
# (116, 'out of', 278)
# (117, 'out of', 278)
# (118, 'out of', 278)
# (119, 'out of', 278)
# (120, 'out of', 278)
# (121, 'out of', 278)
# (122, 'out of', 278)
# (123, 'out of', 278)
# (124, 'out of', 278)
# (125, 'out of', 278)
# (126, 'out of', 278)
# (127, 'out of', 278)
# (128, 'out of', 278)
# (129, 'out of', 278)
# (130, 'out of', 278)
# (131, 'out of', 278)
# (132, 'out of', 278)
# (133, 'out of', 278)
# (134, 'out of', 278)
# (135, 'out of', 278)
# (136, 'out of', 278)
# (137, 'out of', 278)
# (138, 'out of', 278)
# (139, 'out of', 278)
# (140, 'out of', 278)
# (141, 'out of', 278)
# (142, 'out of', 278)
# (143, 'out of', 278)
# (144, 'out of', 278)
# (145, 'out of', 278)
# (146, 'out of', 278)
# (147, 'out of', 278)
# (148, 'out of', 278)
# (149, 'out of', 278)
# (150, 'out of', 278)
# (151, 'out of', 278)
# (152, 'out of', 278)
# (153, 'out of', 278)
# (154, 'out of', 278)
# (155, 'out of', 278)
# (156, 'out of', 278)
# (157, 'out of', 278)
# (158, 'out of', 278)
# (159, 'out of', 278)
# (160, 'out of', 278)
# (161, 'out of', 278)
# (162, 'out of', 278)
# (163, 'out of', 278)
# (164, 'out of', 278)
# (165, 'out of', 278)
# (166, 'out of', 278)
# (167, 'out of', 278)
# (168, 'out of', 278)
# (169, 'out of', 278)
# (170, 'out of', 278)
# (171, 'out of', 278)
# (172, 'out of', 278)
# (173, 'out of', 278)
# (174, 'out of', 278)
# (175, 'out of', 278)
# (176, 'out of', 278)
# (177, 'out of', 278)
# (178, 'out of', 278)
# (179, 'out of', 278)
# (180, 'out of', 278)
# (181, 'out of', 278)
# (182, 'out of', 278)
# (183, 'out of', 278)
# (184, 'out of', 278)
# (185, 'out of', 278)
# (186, 'out of', 278)
# (187, 'out of', 278)
# (188, 'out of', 278)
# (189, 'out of', 278)
# (190, 'out of', 278)
# (191, 'out of', 278)
# (192, 'out of', 278)
# (193, 'out of', 278)
# (194, 'out of', 278)
# (195, 'out of', 278)
# (196, 'out of', 278)
# (197, 'out of', 278)
# (198, 'out of', 278)
# (199, 'out of', 278)
# (200, 'out of', 278)
# (201, 'out of', 278)
# (202, 'out of', 278)
# (203, 'out of', 278)
# (204, 'out of', 278)
# (205, 'out of', 278)
# (206, 'out of', 278)
# (207, 'out of', 278)
# (208, 'out of', 278)
# (209, 'out of', 278)
# (210, 'out of', 278)
# (211, 'out of', 278)
# (212, 'out of', 278)
# (213, 'out of', 278)
# (214, 'out of', 278)
# (215, 'out of', 278)
# (216, 'out of', 278)
# (217, 'out of', 278)
# (218, 'out of', 278)
# (219, 'out of', 278)
# (220, 'out of', 278)
# (221, 'out of', 278)
# (222, 'out of', 278)
# (223, 'out of', 278)
# (224, 'out of', 278)
# (225, 'out of', 278)
# (226, 'out of', 278)
# (227, 'out of', 278)
# (228, 'out of', 278)
# (229, 'out of', 278)
# (230, 'out of', 278)
# (231, 'out of', 278)
# (232, 'out of', 278)
# (233, 'out of', 278)
# (234, 'out of', 278)
# (235, 'out of', 278)
# (236, 'out of', 278)
# (237, 'out of', 278)
# (238, 'out of', 278)
# (239, 'out of', 278)
# (240, 'out of', 278)
# (241, 'out of', 278)
# (242, 'out of', 278)
# (243, 'out of', 278)
# (244, 'out of', 278)
# (245, 'out of', 278)
# (246, 'out of', 278)
# (247, 'out of', 278)
# (248, 'out of', 278)
# (249, 'out of', 278)
# (250, 'out of', 278)
# (251, 'out of', 278)
# (252, 'out of', 278)
# (253, 'out of', 278)
# (254, 'out of', 278)
# (255, 'out of', 278)
# (256, 'out of', 278)
# (257, 'out of', 278)
# (258, 'out of', 278)
# (259, 'out of', 278)
# (260, 'out of', 278)
# (261, 'out of', 278)
# (262, 'out of', 278)
# (263, 'out of', 278)
# (264, 'out of', 278)
# (265, 'out of', 278)
# (266, 'out of', 278)
# (267, 'out of', 278)
# (268, 'out of', 278)
# (269, 'out of', 278)
# (270, 'out of', 278)
# (271, 'out of', 278)
# (272, 'out of', 278)
# (273, 'out of', 278)
# (274, 'out of', 278)
# (275, 'out of', 278)
# (276, 'out of', 278)
# (277, 'out of', 278)
# (278, 'out of', 278)
#           mean    n                                        property_id  \
# 11   73.241751  278  GC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0    43.609241  278  GC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3     0.936376  278             GC_Apical_Dendrite_Average_Contraction
# 5     1.001700  278                GC_Apical_Dendrite_Average_Diameter
# 2     1.999541  278             GC_Apical_Dendrite_Average_Ralls_Ratio
# 8     1.009581  278               GC_Apical_Dendrite_Fractal_Dimension
# 1     3.007194  278                GC_Apical_Dendrite_Max_Branch_Order
# 7   241.528872  278          GC_Apical_Dendrite_Max_Euclidean_Distance
# 6   266.214473  278               GC_Apical_Dendrite_Max_Path_Distance
# 4   225.114224  278                  GC_Apical_Dendrite_Overall_Height
# 10   56.146533  278                   GC_Apical_Dendrite_Overall_Width
# 9     0.488281  278             GC_Apical_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 11         29  13.701382
# 0          29  13.576808
# 3          29   0.016920
# 5          29   0.082582
# 2          29   0.005981
# 8          29   0.006591
# 1          29   0.864956
# 7          29  73.690535
# 6          29  78.471839
# 4          29  71.749505
# 10         29  31.872215
# 9          29   0.220670

# %%
Measurement.insert(stats).execute()
# Out:
# 312

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 278)
# (2, 'out of', 278)
# (3, 'out of', 278)
# (4, 'out of', 278)
# (5, 'out of', 278)
# (6, 'out of', 278)
# (7, 'out of', 278)
# (8, 'out of', 278)
# (9, 'out of', 278)
# (10, 'out of', 278)
# (11, 'out of', 278)
# (12, 'out of', 278)
# (13, 'out of', 278)
# (14, 'out of', 278)
# (15, 'out of', 278)
# (16, 'out of', 278)
# (17, 'out of', 278)
# (18, 'out of', 278)
# (19, 'out of', 278)
# (20, 'out of', 278)
# (21, 'out of', 278)
# (22, 'out of', 278)
# (23, 'out of', 278)
# (24, 'out of', 278)
# (25, 'out of', 278)
# (26, 'out of', 278)
# (27, 'out of', 278)
# (28, 'out of', 278)
# (29, 'out of', 278)
# (30, 'out of', 278)
# (31, 'out of', 278)
# (32, 'out of', 278)
# (33, 'out of', 278)
# (34, 'out of', 278)
# (35, 'out of', 278)
# (36, 'out of', 278)
# (37, 'out of', 278)
# (38, 'out of', 278)
# (39, 'out of', 278)
# (40, 'out of', 278)
# (41, 'out of', 278)
# (42, 'out of', 278)
# (43, 'out of', 278)
# (44, 'out of', 278)
# (45, 'out of', 278)
# (46, 'out of', 278)
# (47, 'out of', 278)
# (48, 'out of', 278)
# (49, 'out of', 278)
# (50, 'out of', 278)
# (51, 'out of', 278)
# (52, 'out of', 278)
# (53, 'out of', 278)
# (54, 'out of', 278)
# (55, 'out of', 278)
# (56, 'out of', 278)
# (57, 'out of', 278)
# (58, 'out of', 278)
# (59, 'out of', 278)
# (60, 'out of', 278)
# (61, 'out of', 278)
# (62, 'out of', 278)
# (63, 'out of', 278)
# (64, 'out of', 278)
# (65, 'out of', 278)
# (66, 'out of', 278)
# (67, 'out of', 278)
# (68, 'out of', 278)
# (69, 'out of', 278)
# (70, 'out of', 278)
# (71, 'out of', 278)
# (72, 'out of', 278)
# (73, 'out of', 278)
# (74, 'out of', 278)
# (75, 'out of', 278)
# (76, 'out of', 278)
# (77, 'out of', 278)
# (78, 'out of', 278)
# (79, 'out of', 278)
# (80, 'out of', 278)
# (81, 'out of', 278)
# (82, 'out of', 278)
# (83, 'out of', 278)
# (84, 'out of', 278)
# (85, 'out of', 278)
# (86, 'out of', 278)
# (87, 'out of', 278)
# (88, 'out of', 278)
# (89, 'out of', 278)
# (90, 'out of', 278)
# (91, 'out of', 278)
# (92, 'out of', 278)
# (93, 'out of', 278)
# (94, 'out of', 278)
# (95, 'out of', 278)
# (96, 'out of', 278)
# (97, 'out of', 278)
# (98, 'out of', 278)
# (99, 'out of', 278)
# (100, 'out of', 278)
# (101, 'out of', 278)
# (102, 'out of', 278)
# (103, 'out of', 278)
# (104, 'out of', 278)
# (105, 'out of', 278)
# (106, 'out of', 278)
# (107, 'out of', 278)
# (108, 'out of', 278)
# (109, 'out of', 278)
# (110, 'out of', 278)
# (111, 'out of', 278)
# (112, 'out of', 278)
# (113, 'out of', 278)
# (114, 'out of', 278)
# (115, 'out of', 278)
# (116, 'out of', 278)
# (117, 'out of', 278)
# (118, 'out of', 278)
# (119, 'out of', 278)
# (120, 'out of', 278)
# (121, 'out of', 278)
# (122, 'out of', 278)
# (123, 'out of', 278)
# (124, 'out of', 278)
# (125, 'out of', 278)
# (126, 'out of', 278)
# (127, 'out of', 278)
# (128, 'out of', 278)
# (129, 'out of', 278)
# (130, 'out of', 278)
# (131, 'out of', 278)
# (132, 'out of', 278)
# (133, 'out of', 278)
# (134, 'out of', 278)
# (135, 'out of', 278)
# (136, 'out of', 278)
# (137, 'out of', 278)
# (138, 'out of', 278)
# (139, 'out of', 278)
# (140, 'out of', 278)
# (141, 'out of', 278)
# (142, 'out of', 278)
# (143, 'out of', 278)
# (144, 'out of', 278)
# (145, 'out of', 278)
# (146, 'out of', 278)
# (147, 'out of', 278)
# (148, 'out of', 278)
# (149, 'out of', 278)
# (150, 'out of', 278)
# (151, 'out of', 278)
# (152, 'out of', 278)
# (153, 'out of', 278)
# (154, 'out of', 278)
# (155, 'out of', 278)
# (156, 'out of', 278)
# (157, 'out of', 278)
# (158, 'out of', 278)
# (159, 'out of', 278)
# (160, 'out of', 278)
# (161, 'out of', 278)
# (162, 'out of', 278)
# (163, 'out of', 278)
# (164, 'out of', 278)
# (165, 'out of', 278)
# (166, 'out of', 278)
# (167, 'out of', 278)
# (168, 'out of', 278)
# (169, 'out of', 278)
# (170, 'out of', 278)
# (171, 'out of', 278)
# (172, 'out of', 278)
# (173, 'out of', 278)
# (174, 'out of', 278)
# (175, 'out of', 278)
# (176, 'out of', 278)
# (177, 'out of', 278)
# (178, 'out of', 278)
# (179, 'out of', 278)
# (180, 'out of', 278)
# (181, 'out of', 278)
# (182, 'out of', 278)
# (183, 'out of', 278)
# (184, 'out of', 278)
# (185, 'out of', 278)
# (186, 'out of', 278)
# (187, 'out of', 278)
# (188, 'out of', 278)
# (189, 'out of', 278)
# (190, 'out of', 278)
# (191, 'out of', 278)
# (192, 'out of', 278)
# (193, 'out of', 278)
# (194, 'out of', 278)
# (195, 'out of', 278)
# (196, 'out of', 278)
# (197, 'out of', 278)
# (198, 'out of', 278)
# (199, 'out of', 278)
# (200, 'out of', 278)
# (201, 'out of', 278)
# (202, 'out of', 278)
# (203, 'out of', 278)
# (204, 'out of', 278)
# (205, 'out of', 278)
# (206, 'out of', 278)
# (207, 'out of', 278)
# (208, 'out of', 278)
# (209, 'out of', 278)
# (210, 'out of', 278)
# (211, 'out of', 278)
# (212, 'out of', 278)
# (213, 'out of', 278)
# (214, 'out of', 278)
# (215, 'out of', 278)
# (216, 'out of', 278)
# (217, 'out of', 278)
# (218, 'out of', 278)
# (219, 'out of', 278)
# (220, 'out of', 278)
# (221, 'out of', 278)
# (222, 'out of', 278)
# (223, 'out of', 278)
# (224, 'out of', 278)
# (225, 'out of', 278)
# (226, 'out of', 278)
# (227, 'out of', 278)
# (228, 'out of', 278)
# (229, 'out of', 278)
# (230, 'out of', 278)
# (231, 'out of', 278)
# (232, 'out of', 278)
# (233, 'out of', 278)
# (234, 'out of', 278)
# (235, 'out of', 278)
# (236, 'out of', 278)
# (237, 'out of', 278)
# (238, 'out of', 278)
# (239, 'out of', 278)
# (240, 'out of', 278)
# (241, 'out of', 278)
# (242, 'out of', 278)
# (243, 'out of', 278)
# (244, 'out of', 278)
# (245, 'out of', 278)
# (246, 'out of', 278)
# (247, 'out of', 278)
# (248, 'out of', 278)
# (249, 'out of', 278)
# (250, 'out of', 278)
# (251, 'out of', 278)
# (252, 'out of', 278)
# (253, 'out of', 278)
# (254, 'out of', 278)
# (255, 'out of', 278)
# (256, 'out of', 278)
# (257, 'out of', 278)
# (258, 'out of', 278)
# (259, 'out of', 278)
# (260, 'out of', 278)
# (261, 'out of', 278)
# (262, 'out of', 278)
# (263, 'out of', 278)
# (264, 'out of', 278)
# (265, 'out of', 278)
# (266, 'out of', 278)
# (267, 'out of', 278)
# (268, 'out of', 278)
# (269, 'out of', 278)
# (270, 'out of', 278)
# (271, 'out of', 278)
# (272, 'out of', 278)
# (273, 'out of', 278)
# (274, 'out of', 278)
# (275, 'out of', 278)
# (276, 'out of', 278)
# (277, 'out of', 278)
# (278, 'out of', 278)
#         mean    n                                        property_id  \
# 9   0.995899  278  GC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4   0.782489  278  GC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 11  0.020281  278              GC_Basal_Dendrite_Average_Contraction
# 1   0.021583  278                 GC_Basal_Dendrite_Average_Diameter
# 8   0.021583  278              GC_Basal_Dendrite_Average_Ralls_Ratio
# 3   0.021906  278                GC_Basal_Dendrite_Fractal_Dimension
# 7   0.043165  278                 GC_Basal_Dendrite_Max_Branch_Order
# 2   2.039904  278           GC_Basal_Dendrite_Max_Euclidean_Distance
# 6   2.155128  278                GC_Basal_Dendrite_Max_Path_Distance
# 0   1.854326  278                   GC_Basal_Dendrite_Overall_Height
# 5   0.521434  278                    GC_Basal_Dendrite_Overall_Width
# 10  0.001799  278              GC_Basal_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 9          29   9.564679
# 4          29   8.304895
# 11         29   0.136626
# 1          29   0.145317
# 8          29   0.206639
# 3          29   0.147502
# 7          29   0.336518
# 2          29  17.440499
# 6          29  18.233868
# 0          29  16.294912
# 5          29   3.856135
# 10         29   0.029934

# %%
Measurement.insert(stats).execute()
# Out:
# 324

# %% [markdown]
# ## Denizet GC archive - Siopi 2016 paper
#
# Thin, no soma

# %%
dir = 'morphology-data/GCs/Denizet-granule/Siopi2016'
cell = "GC"
exclude = full_slice_only_tests
source_id=30

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 55)
# (2, 'out of', 55)
# (3, 'out of', 55)
# (4, 'out of', 55)
# (5, 'out of', 55)
# (6, 'out of', 55)
# (7, 'out of', 55)
# (8, 'out of', 55)
# (9, 'out of', 55)
# (10, 'out of', 55)
# (11, 'out of', 55)
# (12, 'out of', 55)
# (13, 'out of', 55)
# (14, 'out of', 55)
# (15, 'out of', 55)
# (16, 'out of', 55)
# (17, 'out of', 55)
# (18, 'out of', 55)
# (19, 'out of', 55)
# (20, 'out of', 55)
# (21, 'out of', 55)
# (22, 'out of', 55)
# (23, 'out of', 55)
# (24, 'out of', 55)
# (25, 'out of', 55)
# (26, 'out of', 55)
# (27, 'out of', 55)
# (28, 'out of', 55)
# (29, 'out of', 55)
# (30, 'out of', 55)
# (31, 'out of', 55)
# (32, 'out of', 55)
# (33, 'out of', 55)
# (34, 'out of', 55)
# (35, 'out of', 55)
# (36, 'out of', 55)
# (37, 'out of', 55)
# (38, 'out of', 55)
# (39, 'out of', 55)
# (40, 'out of', 55)
# (41, 'out of', 55)
# (42, 'out of', 55)
# (43, 'out of', 55)
# (44, 'out of', 55)
# (45, 'out of', 55)
# (46, 'out of', 55)
# (47, 'out of', 55)
# (48, 'out of', 55)
# (49, 'out of', 55)
# (50, 'out of', 55)
# (51, 'out of', 55)
# (52, 'out of', 55)
# (53, 'out of', 55)
# (54, 'out of', 55)
# (55, 'out of', 55)
#          mean   n                                        property_id  \
# 9  110.755927  55  GC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0   57.402215  55  GC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3    0.896975  55             GC_Apical_Dendrite_Average_Contraction
# 6    1.017058  55               GC_Apical_Dendrite_Fractal_Dimension
# 1    4.709091  55                GC_Apical_Dendrite_Max_Branch_Order
# 5  222.650533  55          GC_Apical_Dendrite_Max_Euclidean_Distance
# 4  260.682947  55               GC_Apical_Dendrite_Max_Path_Distance
# 2  207.640244  55                  GC_Apical_Dendrite_Overall_Height
# 8   58.202484  55                   GC_Apical_Dendrite_Overall_Width
# 7    0.501405  55             GC_Apical_Dendrite_Partition_Asymmetry
#
#    source_id         std
# 9         30   16.096792
# 0         30   14.251680
# 3         30    0.030670
# 6         30    0.009189
# 1         30    1.855437
# 5         30  114.229122
# 4         30  130.328375
# 2         30  110.610196
# 8         30   31.270504
# 7         30    0.211890

# %%
Measurement.insert(stats).execute()
# Out:
# 334

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 55)
# (2, 'out of', 55)
# (3, 'out of', 55)
# (4, 'out of', 55)
# (5, 'out of', 55)
# (6, 'out of', 55)
# (7, 'out of', 55)
# (8, 'out of', 55)
# (9, 'out of', 55)
# (10, 'out of', 55)
# (11, 'out of', 55)
# (12, 'out of', 55)
# (13, 'out of', 55)
# (14, 'out of', 55)
# (15, 'out of', 55)
# (16, 'out of', 55)
# (17, 'out of', 55)
# (18, 'out of', 55)
# (19, 'out of', 55)
# (20, 'out of', 55)
# (21, 'out of', 55)
# (22, 'out of', 55)
# (23, 'out of', 55)
# (24, 'out of', 55)
# (25, 'out of', 55)
# (26, 'out of', 55)
# (27, 'out of', 55)
# (28, 'out of', 55)
# (29, 'out of', 55)
# (30, 'out of', 55)
# (31, 'out of', 55)
# (32, 'out of', 55)
# (33, 'out of', 55)
# (34, 'out of', 55)
# (35, 'out of', 55)
# (36, 'out of', 55)
# (37, 'out of', 55)
# (38, 'out of', 55)
# (39, 'out of', 55)
# (40, 'out of', 55)
# (41, 'out of', 55)
# (42, 'out of', 55)
# (43, 'out of', 55)
# (44, 'out of', 55)
# (45, 'out of', 55)
# (46, 'out of', 55)
# (47, 'out of', 55)
# (48, 'out of', 55)
# (49, 'out of', 55)
# (50, 'out of', 55)
# (51, 'out of', 55)
# (52, 'out of', 55)
# (53, 'out of', 55)
# (54, 'out of', 55)
# (55, 'out of', 55)
#          mean   n                                        property_id  \
# 9   12.985015  55  GC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4    8.314025  55  GC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 11   0.207433  55              GC_Basal_Dendrite_Average_Contraction
# 1    0.236364  55                 GC_Basal_Dendrite_Average_Diameter
# 8    0.218182  55              GC_Basal_Dendrite_Average_Ralls_Ratio
# 3    0.242680  55                GC_Basal_Dendrite_Fractal_Dimension
# 7    0.636364  55                 GC_Basal_Dendrite_Max_Branch_Order
# 2   10.787564  55           GC_Basal_Dendrite_Max_Euclidean_Distance
# 6   13.489264  55                GC_Basal_Dendrite_Max_Path_Distance
# 0    8.667623  55                   GC_Basal_Dendrite_Overall_Height
# 5    5.155287  55                    GC_Basal_Dendrite_Overall_Width
# 10   0.046320  55              GC_Basal_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 9          30  37.407652
# 4          30  24.791403
# 11         30   0.373290
# 1          30   0.424848
# 8          30   0.623506
# 3          30   0.436430
# 7          30   1.393017
# 2          30  23.740510
# 6          30  30.676399
# 0          30  20.730029
# 5          30  12.146225
# 10         30   0.150955

# %%
Measurement.insert(stats).execute()
# Out:
# 346

# %% [markdown]
# ## Guthrie GC archive
#
# No radii, full thickness slices

# %%
dir = 'morphology-data/GCs/Guthrie-granule/'
cell = "GC"
exclude = full_diameter_only_tests
source_id=31

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 39)
# (2, 'out of', 39)
# (3, 'out of', 39)
# (4, 'out of', 39)
# (5, 'out of', 39)
# (6, 'out of', 39)
# (7, 'out of', 39)
# (8, 'out of', 39)
# (9, 'out of', 39)
# (10, 'out of', 39)
# (11, 'out of', 39)
# (12, 'out of', 39)
# (13, 'out of', 39)
# (14, 'out of', 39)
# (15, 'out of', 39)
# (16, 'out of', 39)
# (17, 'out of', 39)
# (18, 'out of', 39)
# (19, 'out of', 39)
# (20, 'out of', 39)
# (21, 'out of', 39)
# (22, 'out of', 39)
# (23, 'out of', 39)
# (24, 'out of', 39)
# (25, 'out of', 39)
# (26, 'out of', 39)
# (27, 'out of', 39)
# (28, 'out of', 39)
# (29, 'out of', 39)
# (30, 'out of', 39)
# (31, 'out of', 39)
# (32, 'out of', 39)
# (33, 'out of', 39)
# (34, 'out of', 39)
# (35, 'out of', 39)
# (36, 'out of', 39)
# (37, 'out of', 39)
# (38, 'out of', 39)
# (39, 'out of', 39)
#           mean   n                                        property_id  \
# 12   80.459110  39  GC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 1    51.969690  39  GC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 9     1.022800  39               GC_Apical_Dendrite_Fractal_Dimension
# 2     2.025641  39                GC_Apical_Dendrite_Max_Branch_Order
# 8   159.535182  39          GC_Apical_Dendrite_Max_Euclidean_Distance
# 6   196.894769  39               GC_Apical_Dendrite_Max_Path_Distance
# 0     2.179487  39          GC_Apical_Dendrite_Number_of_Bifurcations
# 5     5.358974  39              GC_Apical_Dendrite_Number_of_Branches
# 7    26.490769  39                   GC_Apical_Dendrite_Overall_Depth
# 4   148.369631  39                  GC_Apical_Dendrite_Overall_Height
# 11   34.099513  39                   GC_Apical_Dendrite_Overall_Width
# 10    0.342430  39             GC_Apical_Dendrite_Partition_Asymmetry
# 3   271.567846  39                    GC_Apical_Dendrite_Total_Length
#
#     source_id        std
# 12         31  24.723338
# 1          31  16.754017
# 9          31   0.022970
# 2          31   1.049717
# 8          31  34.758912
# 6          31  66.400300
# 0          31   1.356311
# 5          31   2.712622
# 7          31  19.899931
# 4          31  33.222903
# 11         31  18.035191
# 10         31   0.271083
# 3          31  99.391950

# %%
Measurement.insert(stats).execute()
# Out:
# 359

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 39)
# (2, 'out of', 39)
# (3, 'out of', 39)
# (4, 'out of', 39)
# (5, 'out of', 39)
# (6, 'out of', 39)
# (7, 'out of', 39)
# (8, 'out of', 39)
# (9, 'out of', 39)
# (10, 'out of', 39)
# (11, 'out of', 39)
# (12, 'out of', 39)
# (13, 'out of', 39)
# (14, 'out of', 39)
# (15, 'out of', 39)
# (16, 'out of', 39)
# (17, 'out of', 39)
# (18, 'out of', 39)
# (19, 'out of', 39)
# (20, 'out of', 39)
# (21, 'out of', 39)
# (22, 'out of', 39)
# (23, 'out of', 39)
# (24, 'out of', 39)
# (25, 'out of', 39)
# (26, 'out of', 39)
# (27, 'out of', 39)
# (28, 'out of', 39)
# (29, 'out of', 39)
# (30, 'out of', 39)
# (31, 'out of', 39)
# (32, 'out of', 39)
# (33, 'out of', 39)
# (34, 'out of', 39)
# (35, 'out of', 39)
# (36, 'out of', 39)
# (37, 'out of', 39)
# (38, 'out of', 39)
# (39, 'out of', 39)
#          mean   n                                        property_id  \
# 9   23.525600  39  GC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4   15.565147  39  GC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 3    0.777707  39                GC_Basal_Dendrite_Fractal_Dimension
# 8    0.282051  39                 GC_Basal_Dendrite_Max_Branch_Order
# 7   17.195619  39           GC_Basal_Dendrite_Max_Euclidean_Distance
# 5   21.078282  39                GC_Basal_Dendrite_Max_Path_Distance
# 12   0.307692  39           GC_Basal_Dendrite_Number_of_Bifurcations
# 1    2.076923  39               GC_Basal_Dendrite_Number_of_Branches
# 6    7.446667  39                    GC_Basal_Dendrite_Overall_Depth
# 0   11.584840  39                   GC_Basal_Dendrite_Overall_Height
# 11  12.788849  39                    GC_Basal_Dendrite_Overall_Width
# 10   0.008547  39              GC_Basal_Dendrite_Partition_Asymmetry
# 2   38.829195  39                     GC_Basal_Dendrite_Total_Length
#
#     source_id        std
# 9          31  42.879746
# 4          31  33.082430
# 3          31   0.457781
# 8          31   0.503766
# 7          31  13.298646
# 5          31  16.579127
# 12         31   0.605693
# 1          31   1.802912
# 6          31   8.627395
# 0          31  11.333211
# 11         31  12.553607
# 10         31   0.052687
# 2          31  36.420299

# %%
Measurement.insert(stats).execute()
# Out:
# 372

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 39)
# (2, 'out of', 39)
# (3, 'out of', 39)
# (4, 'out of', 39)
# (5, 'out of', 39)
# (6, 'out of', 39)
# (7, 'out of', 39)
# (8, 'out of', 39)
# (9, 'out of', 39)
# (10, 'out of', 39)
# (11, 'out of', 39)
# (12, 'out of', 39)
# (13, 'out of', 39)
# (14, 'out of', 39)
# (15, 'out of', 39)
# (16, 'out of', 39)
# (17, 'out of', 39)
# (18, 'out of', 39)
# (19, 'out of', 39)
# (20, 'out of', 39)
# (21, 'out of', 39)
# (22, 'out of', 39)
# (23, 'out of', 39)
# (24, 'out of', 39)
# (25, 'out of', 39)
# (26, 'out of', 39)
# (27, 'out of', 39)
# (28, 'out of', 39)
# (29, 'out of', 39)
# (30, 'out of', 39)
# (31, 'out of', 39)
# (32, 'out of', 39)
# (33, 'out of', 39)
# (34, 'out of', 39)
# (35, 'out of', 39)
# (36, 'out of', 39)
# (37, 'out of', 39)
# (38, 'out of', 39)
# (39, 'out of', 39)
#          mean   n           property_id  source_id         std
# 1    2.461538  39    GC_Number_of_Stems         31    1.194993
# 0  489.091744  39  GC_Soma_Surface_Area         31  153.495366

# %%
Measurement.insert(stats).execute()
# Out:
# 374

# %% [markdown]
# ## Koehl GC archive
#
# No radii, thin slices

# %%
dir = 'morphology-data/GCs/Koehl-granule/'
cell = "GC"
exclude = full_diameter_only_tests + full_slice_only_tests
source_id=32

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 42)
# (2, 'out of', 42)
# (3, 'out of', 42)
# (4, 'out of', 42)
# (5, 'out of', 42)
# (6, 'out of', 42)
# (7, 'out of', 42)
# (8, 'out of', 42)
# (9, 'out of', 42)
# (10, 'out of', 42)
# (11, 'out of', 42)
# (12, 'out of', 42)
# (13, 'out of', 42)
# (14, 'out of', 42)
# (15, 'out of', 42)
# (16, 'out of', 42)
# (17, 'out of', 42)
# (18, 'out of', 42)
# (19, 'out of', 42)
# (20, 'out of', 42)
# (21, 'out of', 42)
# (22, 'out of', 42)
# (23, 'out of', 42)
# (24, 'out of', 42)
# (25, 'out of', 42)
# (26, 'out of', 42)
# (27, 'out of', 42)
# (28, 'out of', 42)
# (29, 'out of', 42)
# (30, 'out of', 42)
# (31, 'out of', 42)
# (32, 'out of', 42)
# (33, 'out of', 42)
# (34, 'out of', 42)
# (35, 'out of', 42)
# (36, 'out of', 42)
# (37, 'out of', 42)
# (38, 'out of', 42)
# (39, 'out of', 42)
# (40, 'out of', 42)
# (41, 'out of', 42)
# (42, 'out of', 42)
#          mean   n                                        property_id  \
# 8   66.052979  42  GC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0   37.988692  42  GC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 2    1.025657  42               GC_Apical_Dendrite_Fractal_Dimension
# 1    2.309524  42                GC_Apical_Dendrite_Max_Branch_Order
# 4  269.447167  42          GC_Apical_Dendrite_Max_Euclidean_Distance
# 3  305.190571  42               GC_Apical_Dendrite_Max_Path_Distance
# 5  252.328095  42                  GC_Apical_Dendrite_Overall_Height
# 7   63.524519  42                   GC_Apical_Dendrite_Overall_Width
# 6    0.360318  42             GC_Apical_Dendrite_Partition_Asymmetry
#
#    source_id        std
# 8         32  18.237557
# 0         32  17.426736
# 2         32   0.012413
# 1         32   0.912560
# 4         32  59.995620
# 3         32  65.648362
# 5         32  56.945886
# 7         32  35.648774
# 6         32   0.267310

# %%
Measurement.insert(stats).execute()
# Out:
# 383

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 42)
# (2, 'out of', 42)
# (3, 'out of', 42)
# (4, 'out of', 42)
# (5, 'out of', 42)
# (6, 'out of', 42)
# (7, 'out of', 42)
# (8, 'out of', 42)
# (9, 'out of', 42)
# (10, 'out of', 42)
# (11, 'out of', 42)
# (12, 'out of', 42)
# (13, 'out of', 42)
# (14, 'out of', 42)
# (15, 'out of', 42)
# (16, 'out of', 42)
# (17, 'out of', 42)
# (18, 'out of', 42)
# (19, 'out of', 42)
# (20, 'out of', 42)
# (21, 'out of', 42)
# (22, 'out of', 42)
# (23, 'out of', 42)
# (24, 'out of', 42)
# (25, 'out of', 42)
# (26, 'out of', 42)
# (27, 'out of', 42)
# (28, 'out of', 42)
# (29, 'out of', 42)
# (30, 'out of', 42)
# (31, 'out of', 42)
# (32, 'out of', 42)
# (33, 'out of', 42)
# (34, 'out of', 42)
# (35, 'out of', 42)
# (36, 'out of', 42)
# (37, 'out of', 42)
# (38, 'out of', 42)
# (39, 'out of', 42)
# (40, 'out of', 42)
# (41, 'out of', 42)
# (42, 'out of', 42)
#         mean   n                                        property_id  \
# 6  18.288888  42  GC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 3  16.704140  42  GC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 2   0.951720  42                GC_Basal_Dendrite_Fractal_Dimension
# 5   0.333333  42                 GC_Basal_Dendrite_Max_Branch_Order
# 1  41.538291  42           GC_Basal_Dendrite_Max_Euclidean_Distance
# 4  45.786834  42                GC_Basal_Dendrite_Max_Path_Distance
# 0  35.120930  42                   GC_Basal_Dendrite_Overall_Height
# 8  18.996133  42                    GC_Basal_Dendrite_Overall_Width
# 7   0.011905  42              GC_Basal_Dendrite_Partition_Asymmetry
#
#    source_id        std
# 6         32  30.147005
# 3         32  27.874867
# 2         32   0.264488
# 5         32   0.519462
# 1         32  21.086308
# 4         32  23.357809
# 0         32  20.371701
# 8         32  14.461052
# 7         32   0.076228

# %%
Measurement.insert(stats).execute()
# Out:
# 392

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 42)
# (2, 'out of', 42)
# (3, 'out of', 42)
# (4, 'out of', 42)
# (5, 'out of', 42)
# (6, 'out of', 42)
# (7, 'out of', 42)
# (8, 'out of', 42)
# (9, 'out of', 42)
# (10, 'out of', 42)
# (11, 'out of', 42)
# (12, 'out of', 42)
# (13, 'out of', 42)
# (14, 'out of', 42)
# (15, 'out of', 42)
# (16, 'out of', 42)
# (17, 'out of', 42)
# (18, 'out of', 42)
# (19, 'out of', 42)
# (20, 'out of', 42)
# (21, 'out of', 42)
# (22, 'out of', 42)
# (23, 'out of', 42)
# (24, 'out of', 42)
# (25, 'out of', 42)
# (26, 'out of', 42)
# (27, 'out of', 42)
# (28, 'out of', 42)
# (29, 'out of', 42)
# (30, 'out of', 42)
# (31, 'out of', 42)
# (32, 'out of', 42)
# (33, 'out of', 42)
# (34, 'out of', 42)
# (35, 'out of', 42)
# (36, 'out of', 42)
# (37, 'out of', 42)
# (38, 'out of', 42)
# (39, 'out of', 42)
# (40, 'out of', 42)
# (41, 'out of', 42)
# (42, 'out of', 42)
#          mean   n           property_id  source_id        std
# 1    2.428571  42    GC_Number_of_Stems         32   0.791107
# 0  293.257000  42  GC_Soma_Surface_Area         32  50.263596

# %%
Measurement.insert(stats).execute()
# Out:
# 394

# %% [markdown]
# ## Saghatelyan GC archive
#
# No soma, thick slices, no radii

# %%
dir = 'morphology-data/GCs/Saghatelyan-granule/'
cell = "GC"
exclude = full_diameter_only_tests
source_id=33

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 6)
# (2, 'out of', 6)
# (3, 'out of', 6)
# (4, 'out of', 6)
# (5, 'out of', 6)
# (6, 'out of', 6)
#            mean  n                                        property_id  \
# 12    30.193800  6  GC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 1     49.868533  6  GC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 9      1.064947  6               GC_Apical_Dendrite_Fractal_Dimension
# 2      3.333333  6                GC_Apical_Dendrite_Max_Branch_Order
# 8    298.517000  6          GC_Apical_Dendrite_Max_Euclidean_Distance
# 6    489.386000  6               GC_Apical_Dendrite_Max_Path_Distance
# 0      5.000000  6          GC_Apical_Dendrite_Number_of_Bifurcations
# 5     11.000000  6              GC_Apical_Dendrite_Number_of_Branches
# 7    143.000000  6                   GC_Apical_Dendrite_Overall_Depth
# 4    253.941333  6                  GC_Apical_Dendrite_Overall_Height
# 11   157.244650  6                   GC_Apical_Dendrite_Overall_Width
# 10     0.368148  6             GC_Apical_Dendrite_Partition_Asymmetry
# 3   1327.965000  6                    GC_Apical_Dendrite_Total_Length
#
#     source_id         std
# 12         33   14.201954
# 1          33   15.474176
# 9          33    0.040905
# 2          33    0.942809
# 8          33   62.089577
# 6          33   86.960954
# 0          33    2.449490
# 5          33    4.898979
# 7          33   60.216277
# 4          33   43.000654
# 11         33   59.937887
# 10         33    0.201871
# 3          33  494.415417

# %%
Measurement.insert(stats).execute()
# Out:
# 407

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 6)
# (2, 'out of', 6)
# (3, 'out of', 6)
# (4, 'out of', 6)
# (5, 'out of', 6)
# (6, 'out of', 6)
#        mean  n                               property_id  source_id        std
# 3  0.174468  6       GC_Basal_Dendrite_Fractal_Dimension         33   0.390123
# 6  2.640233  6  GC_Basal_Dendrite_Max_Euclidean_Distance         33   5.903741
# 4  4.468250  6       GC_Basal_Dendrite_Max_Path_Distance         33   9.991311
# 1  0.500000  6      GC_Basal_Dendrite_Number_of_Branches         33   1.118034
# 5  1.000000  6           GC_Basal_Dendrite_Overall_Depth         33   2.236068
# 0  2.474867  6          GC_Basal_Dendrite_Overall_Height         33   5.533970
# 7  2.651850  6           GC_Basal_Dendrite_Overall_Width         33   5.929717
# 2  9.223183  6            GC_Basal_Dendrite_Total_Length         33  20.623665

# %%
Measurement.insert(stats).execute()
# Out:
# 415

# %% [markdown]
# ## Sailor GC archive
#
# No soma, no basal, thickish slices

# %%
dir = 'morphology-data/GCs/Sailor-granule/'
cell = "GC"
exclude = full_slice_only_tests
source_id=34

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 11)
# (2, 'out of', 11)
# (3, 'out of', 11)
# (4, 'out of', 11)
# (5, 'out of', 11)
# (6, 'out of', 11)
# (7, 'out of', 11)
# (8, 'out of', 11)
# (9, 'out of', 11)
# (10, 'out of', 11)
# (11, 'out of', 11)
#           mean   n                                        property_id  \
# 11   51.474482  11  GC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0    46.470773  11  GC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3     0.900339  11             GC_Apical_Dendrite_Average_Contraction
# 5     1.047391  11                GC_Apical_Dendrite_Average_Diameter
# 2     2.044855  11             GC_Apical_Dendrite_Average_Ralls_Ratio
# 8     1.015708  11               GC_Apical_Dendrite_Fractal_Dimension
# 1     3.454545  11                GC_Apical_Dendrite_Max_Branch_Order
# 7   328.319636  11          GC_Apical_Dendrite_Max_Euclidean_Distance
# 6   394.740091  11               GC_Apical_Dendrite_Max_Path_Distance
# 4   293.976636  11                  GC_Apical_Dendrite_Overall_Height
# 10  147.127018  11                   GC_Apical_Dendrite_Overall_Width
# 9     0.495671  11             GC_Apical_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 11         34  24.124284
# 0          34   7.107435
# 3          34   0.012752
# 5          34   0.101917
# 2          34   0.182326
# 8          34   0.002794
# 1          34   0.782030
# 7          34  70.224262
# 6          34  79.070553
# 4          34  69.612748
# 10         34  79.172932
# 9          34   0.147251

# %%
Measurement.insert(stats).execute()
# Out:
# 427

# %% [markdown]
# ## Urban GC archive - no spines
#
# Thin slices

# %%
dir = 'morphology-data/GCs/Urban-granule/nospines/'
cell = "GC"
exclude = full_slice_only_tests
source_id=35

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 39)
# (2, 'out of', 39)
# (3, 'out of', 39)
# (4, 'out of', 39)
# (5, 'out of', 39)
# (6, 'out of', 39)
# (7, 'out of', 39)
# (8, 'out of', 39)
# (9, 'out of', 39)
# (10, 'out of', 39)
# (11, 'out of', 39)
# (12, 'out of', 39)
# (13, 'out of', 39)
# (14, 'out of', 39)
# (15, 'out of', 39)
# (16, 'out of', 39)
# (17, 'out of', 39)
# (18, 'out of', 39)
# (19, 'out of', 39)
# (20, 'out of', 39)
# (21, 'out of', 39)
# (22, 'out of', 39)
# (23, 'out of', 39)
# (24, 'out of', 39)
# (25, 'out of', 39)
# (26, 'out of', 39)
# (27, 'out of', 39)
# (28, 'out of', 39)
# (29, 'out of', 39)
# (30, 'out of', 39)
# (31, 'out of', 39)
# (32, 'out of', 39)
# (33, 'out of', 39)
# (34, 'out of', 39)
# (35, 'out of', 39)
# (36, 'out of', 39)
# (37, 'out of', 39)
# (38, 'out of', 39)
# (39, 'out of', 39)
#           mean   n                                        property_id  \
# 11   76.528456  39  GC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0    55.717387  39  GC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3     0.886852  39             GC_Apical_Dendrite_Average_Contraction
# 5     0.774154  39                GC_Apical_Dendrite_Average_Diameter
# 2     1.967728  39             GC_Apical_Dendrite_Average_Ralls_Ratio
# 8     1.054852  39               GC_Apical_Dendrite_Fractal_Dimension
# 1     6.256410  39                GC_Apical_Dendrite_Max_Branch_Order
# 7   248.639000  39          GC_Apical_Dendrite_Max_Euclidean_Distance
# 6   293.171974  39               GC_Apical_Dendrite_Max_Path_Distance
# 4   234.460410  39                  GC_Apical_Dendrite_Overall_Height
# 10   59.070569  39                   GC_Apical_Dendrite_Overall_Width
# 9     0.476501  39             GC_Apical_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 11         35  10.316840
# 0          35  11.322318
# 3          35   0.100300
# 5          35   0.120933
# 2          35   0.059980
# 8          35   0.084060
# 1          35   2.084349
# 7          35  71.475736
# 6          35  83.298710
# 4          35  70.529809
# 10         35  23.943786
# 9          35   0.131040

# %%
Measurement.insert(stats).execute()
# Out:
# 439

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 39)
# (2, 'out of', 39)
# (3, 'out of', 39)
# (4, 'out of', 39)
# (5, 'out of', 39)
# (6, 'out of', 39)
# (7, 'out of', 39)
# (8, 'out of', 39)
# (9, 'out of', 39)
# (10, 'out of', 39)
# (11, 'out of', 39)
# (12, 'out of', 39)
# (13, 'out of', 39)
# (14, 'out of', 39)
# (15, 'out of', 39)
# (16, 'out of', 39)
# (17, 'out of', 39)
# (18, 'out of', 39)
# (19, 'out of', 39)
# (20, 'out of', 39)
# (21, 'out of', 39)
# (22, 'out of', 39)
# (23, 'out of', 39)
# (24, 'out of', 39)
# (25, 'out of', 39)
# (26, 'out of', 39)
# (27, 'out of', 39)
# (28, 'out of', 39)
# (29, 'out of', 39)
# (30, 'out of', 39)
# (31, 'out of', 39)
# (32, 'out of', 39)
# (33, 'out of', 39)
# (34, 'out of', 39)
# (35, 'out of', 39)
# (36, 'out of', 39)
# (37, 'out of', 39)
# (38, 'out of', 39)
# (39, 'out of', 39)
#          mean   n                                        property_id  \
# 9   15.578949  39  GC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4   15.720608  39  GC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 11   0.822589  39              GC_Basal_Dendrite_Average_Contraction
# 1    0.725135  39                 GC_Basal_Dendrite_Average_Diameter
# 8    0.298962  39              GC_Basal_Dendrite_Average_Ralls_Ratio
# 3    1.007565  39                GC_Basal_Dendrite_Fractal_Dimension
# 7    0.179487  39                 GC_Basal_Dendrite_Max_Branch_Order
# 2   15.456798  39           GC_Basal_Dendrite_Max_Euclidean_Distance
# 6   18.605092  39                GC_Basal_Dendrite_Max_Path_Distance
# 0   12.996382  39                   GC_Basal_Dendrite_Overall_Height
# 5   12.454675  39                    GC_Basal_Dendrite_Overall_Width
# 10   0.012821  39              GC_Basal_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 9          35  38.579817
# 4          35  40.152245
# 11         35   0.216432
# 1          35   0.211948
# 8          35   0.702891
# 3          35   0.254863
# 7          35   0.445594
# 2          35   6.838483
# 6          35  10.938739
# 0          35   8.162631
# 5          35   6.486280
# 10         35   0.079031

# %%
Measurement.insert(stats).execute()
# Out:
# 451

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 39)
# (2, 'out of', 39)
# (3, 'out of', 39)
# (4, 'out of', 39)
# (5, 'out of', 39)
# (6, 'out of', 39)
# (7, 'out of', 39)
# (8, 'out of', 39)
# (9, 'out of', 39)
# (10, 'out of', 39)
# (11, 'out of', 39)
# (12, 'out of', 39)
# (13, 'out of', 39)
# (14, 'out of', 39)
# (15, 'out of', 39)
# (16, 'out of', 39)
# (17, 'out of', 39)
# (18, 'out of', 39)
# (19, 'out of', 39)
# (20, 'out of', 39)
# (21, 'out of', 39)
# (22, 'out of', 39)
# (23, 'out of', 39)
# (24, 'out of', 39)
# (25, 'out of', 39)
# (26, 'out of', 39)
# (27, 'out of', 39)
# (28, 'out of', 39)
# (29, 'out of', 39)
# (30, 'out of', 39)
# (31, 'out of', 39)
# (32, 'out of', 39)
# (33, 'out of', 39)
# (34, 'out of', 39)
# (35, 'out of', 39)
# (36, 'out of', 39)
# (37, 'out of', 39)
# (38, 'out of', 39)
# (39, 'out of', 39)
#         mean   n           property_id  source_id        std
# 1   3.435897  39    GC_Number_of_Stems         35   1.215179
# 0  58.309859  39  GC_Soma_Surface_Area         35  30.063080

# %%
Measurement.insert(stats).execute()
# Out:
# 453

# %% [markdown]
# ## Fukunaga MC archive

# %%
dir = 'morphology-data/MCs/fukunaga-done/done/'
cell = "MC"
exclude = []
source_id=36

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 7)
# (2, 'out of', 7)
# (3, 'out of', 7)
# (4, 'out of', 7)
# (5, 'out of', 7)
# (6, 'out of', 7)
# (7, 'out of', 7)
#            mean  n                                        property_id  \
# 17    79.941829  7  MC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 2     67.488743  7  MC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 6      0.771708  7             MC_Apical_Dendrite_Average_Contraction
# 8      2.708349  7                MC_Apical_Dendrite_Average_Diameter
# 13     1.095113  7             MC_Apical_Dendrite_Average_Ralls_Ratio
# 14     0.886156  7               MC_Apical_Dendrite_Fractal_Dimension
# 3      6.000000  7                MC_Apical_Dendrite_Max_Branch_Order
# 12   216.541604  7          MC_Apical_Dendrite_Max_Euclidean_Distance
# 10   263.694747  7               MC_Apical_Dendrite_Max_Path_Distance
# 0     11.000000  7          MC_Apical_Dendrite_Number_of_Bifurcations
# 9     21.714286  7              MC_Apical_Dendrite_Number_of_Branches
# 11   167.902857  7                   MC_Apical_Dendrite_Overall_Depth
# 7     90.625707  7                  MC_Apical_Dendrite_Overall_Height
# 16    71.294051  7                   MC_Apical_Dendrite_Overall_Width
# 15     0.314063  7             MC_Apical_Dendrite_Partition_Asymmetry
# 4    576.934461  7                    MC_Apical_Dendrite_Total_Length
# 1   3033.634571  7                   MC_Apical_Dendrite_Total_Surface
# 5   2150.807286  7                    MC_Apical_Dendrite_Total_Volume
#
#     source_id          std
# 17         36    34.447129
# 2          36    28.456023
# 6          36     0.315414
# 8          36     2.772595
# 13         36     0.471574
# 14         36     0.361810
# 3          36     3.817254
# 12         36    86.847743
# 10         36   106.372360
# 0          36     8.246211
# 9          36    16.420495
# 11         36    71.040974
# 7          36    38.464641
# 16         36    41.634789
# 15         36     0.207503
# 4          36   337.121593
# 1          36  1528.405535
# 5          36  1180.448257

# %%
Measurement.insert(stats).execute()
# Out:
# 471

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 7)
# (2, 'out of', 7)
# (3, 'out of', 7)
# (4, 'out of', 7)
# (5, 'out of', 7)
# (6, 'out of', 7)
# (7, 'out of', 7)
#             mean  n                                        property_id  \
# 14     84.151500  7  MC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 5      48.751043  7  MC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 16      0.843132  7              MC_Basal_Dendrite_Average_Contraction
# 4       0.963327  7                 MC_Basal_Dendrite_Average_Diameter
# 12      1.324086  7              MC_Basal_Dendrite_Average_Ralls_Ratio
# 3       1.032364  7                MC_Basal_Dendrite_Fractal_Dimension
# 11      4.285714  7                 MC_Basal_Dendrite_Max_Branch_Order
# 13    741.104286  7           MC_Basal_Dendrite_Max_Euclidean_Distance
# 7    1019.706857  7                MC_Basal_Dendrite_Max_Path_Distance
# 17     14.000000  7           MC_Basal_Dendrite_Number_of_Bifurcations
# 1      33.000000  7               MC_Basal_Dendrite_Number_of_Branches
# 8     274.840000  7                    MC_Basal_Dendrite_Overall_Depth
# 0    1035.240429  7                   MC_Basal_Dendrite_Overall_Height
# 6     767.221714  7                    MC_Basal_Dendrite_Overall_Width
# 15      0.334930  7              MC_Basal_Dendrite_Partition_Asymmetry
# 2    8323.601429  7                     MC_Basal_Dendrite_Total_Length
# 10  25468.842857  7                    MC_Basal_Dendrite_Total_Surface
# 9    7649.262857  7                     MC_Basal_Dendrite_Total_Volume
#
#     source_id          std
# 14         36     9.320916
# 5          36     6.765166
# 16         36     0.016582
# 4          36     0.097350
# 12         36     0.043619
# 3          36     0.003629
# 11         36     1.030158
# 13         36    70.832502
# 7          36    93.821933
# 17         36     5.237229
# 1          36    10.609968
# 8          36    66.519093
# 0          36   148.547550
# 6          36   131.126619
# 15         36     0.144190
# 2          36  2585.979375
# 10         36  9355.474891
# 9          36  3574.031629

# %%
Measurement.insert(stats).execute()
# Out:
# 489

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 7)
# (2, 'out of', 7)
# (3, 'out of', 7)
# (4, 'out of', 7)
# (5, 'out of', 7)
# (6, 'out of', 7)
# (7, 'out of', 7)
#           mean  n           property_id  source_id         std
# 1     5.714286  7    MC_Number_of_Stems         36    0.880631
# 0  1370.544286  7  MC_Soma_Surface_Area         36  305.354162

# %%
Measurement.insert(stats).execute()
# Out:
# 491

# %% [markdown]
# ## Imai MC archive

# %%
dir = 'morphology-data/MCs/imai-done/apical/'
cell = "MC"
exclude = []
source_id=37

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 4)
# (2, 'out of', 4)
# (3, 'out of', 4)
# (4, 'out of', 4)
#            mean  n                                        property_id  \
# 17    86.623625  4  MC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 2     67.484350  4  MC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 6      0.896162  4             MC_Apical_Dendrite_Average_Contraction
# 8      1.336090  4                MC_Apical_Dendrite_Average_Diameter
# 13     1.606345  4             MC_Apical_Dendrite_Average_Ralls_Ratio
# 14     1.028500  4               MC_Apical_Dendrite_Fractal_Dimension
# 3      8.000000  4                MC_Apical_Dendrite_Max_Branch_Order
# 12   292.835250  4          MC_Apical_Dendrite_Max_Euclidean_Distance
# 10   365.078250  4               MC_Apical_Dendrite_Max_Path_Distance
# 0     19.500000  4          MC_Apical_Dendrite_Number_of_Bifurcations
# 9     39.750000  4              MC_Apical_Dendrite_Number_of_Branches
# 11   100.500000  4                   MC_Apical_Dendrite_Overall_Depth
# 7    266.006250  4                  MC_Apical_Dendrite_Overall_Height
# 16    66.965600  4                   MC_Apical_Dendrite_Overall_Width
# 15     0.392446  4             MC_Apical_Dendrite_Partition_Asymmetry
# 4    723.272500  4                    MC_Apical_Dendrite_Total_Length
# 1   4129.847500  4                   MC_Apical_Dendrite_Total_Surface
# 5   3063.310000  4                    MC_Apical_Dendrite_Total_Volume
#
#     source_id          std
# 17         37     5.779131
# 2          37     5.584569
# 6          37     0.020390
# 8          37     0.203535
# 13         37     0.059010
# 14         37     0.007664
# 3          37     0.707107
# 12         37    23.551411
# 10         37    10.614060
# 0          37     1.802776
# 9          37     3.960745
# 11         37    27.771388
# 7          37    23.781524
# 16         37    16.683492
# 15         37     0.095410
# 4          37    76.551485
# 1          37   919.600871
# 5          37  1111.436902

# %%
Measurement.insert(stats).execute()
# Out:
# 509

# %%
# Basal
dir = 'morphology-data/MCs/imai-done/lateral/'
exclude = full_diameter_only_tests
source_id = 38

stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 13)
# (2, 'out of', 13)
# (3, 'out of', 13)
# (4, 'out of', 13)
# (5, 'out of', 13)
# (6, 'out of', 13)
# (7, 'out of', 13)
# (8, 'out of', 13)
# (9, 'out of', 13)
# (10, 'out of', 13)
# (11, 'out of', 13)
# (12, 'out of', 13)
# (13, 'out of', 13)
#            mean   n                                        property_id  \
# 9     57.063285  13  MC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4     42.463131  13  MC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 3      1.007279  13                MC_Basal_Dendrite_Fractal_Dimension
# 8      2.307692  13                 MC_Basal_Dendrite_Max_Branch_Order
# 7    760.584538  13           MC_Basal_Dendrite_Max_Euclidean_Distance
# 5    830.457846  13                MC_Basal_Dendrite_Max_Path_Distance
# 12     4.384615  13           MC_Basal_Dendrite_Number_of_Bifurcations
# 1     12.692308  13               MC_Basal_Dendrite_Number_of_Branches
# 6    134.692308  13                    MC_Basal_Dendrite_Overall_Depth
# 0   1031.289692  13                   MC_Basal_Dendrite_Overall_Height
# 11   547.882308  13                    MC_Basal_Dendrite_Overall_Width
# 10     0.300000  13              MC_Basal_Dendrite_Partition_Asymmetry
# 2   3431.816923  13                     MC_Basal_Dendrite_Total_Length
#
#     source_id          std
# 9          38    11.036456
# 4          38    17.701485
# 3          38     0.001411
# 8          38     0.910166
# 7          38   136.940719
# 5          38   154.972850
# 12         38     2.558198
# 1          38     5.729608
# 6          38    39.946858
# 0          38   252.407565
# 11         38   183.213060
# 10         38     0.196443
# 2          38  1454.251192

# %%
Measurement.insert(stats).execute()
# Out:
# 552

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 13)
# (2, 'out of', 13)
# (3, 'out of', 13)
# (4, 'out of', 13)
# (5, 'out of', 13)
# (6, 'out of', 13)
# (7, 'out of', 13)
# (8, 'out of', 13)
# (9, 'out of', 13)
# (10, 'out of', 13)
# (11, 'out of', 13)
# (12, 'out of', 13)
# (13, 'out of', 13)
#           mean   n           property_id  source_id         std
# 1     3.923077  13    MC_Number_of_Stems         38    1.268648
# 0  1381.282923  13  MC_Soma_Surface_Area         38  634.326164

# %%
Measurement.insert(stats).execute()
# Out:
# 554

# %% [markdown]
# ## Urban MC archive - Burton & Urban 2014

# %%
dir = 'morphology-data/MCs/urban-done/BurtonUrban2014/'
cell = "MC"
exclude = full_slice_only_tests
source_id=39

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 32)
# (2, 'out of', 32)
# (3, 'out of', 32)
# (4, 'out of', 32)
# (5, 'out of', 32)
# (6, 'out of', 32)
# (7, 'out of', 32)
# (8, 'out of', 32)
# (9, 'out of', 32)
# (10, 'out of', 32)
# (11, 'out of', 32)
# (12, 'out of', 32)
# (13, 'out of', 32)
# (14, 'out of', 32)
# (15, 'out of', 32)
# (16, 'out of', 32)
# (17, 'out of', 32)
# (18, 'out of', 32)
# (19, 'out of', 32)
# (20, 'out of', 32)
# (21, 'out of', 32)
# (22, 'out of', 32)
# (23, 'out of', 32)
# (24, 'out of', 32)
# (25, 'out of', 32)
# (26, 'out of', 32)
# (27, 'out of', 32)
# (28, 'out of', 32)
# (29, 'out of', 32)
# (30, 'out of', 32)
# (31, 'out of', 32)
# (32, 'out of', 32)
#           mean   n                                        property_id  \
# 11   89.092328  32  MC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0    65.597944  32  MC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3     0.742970  32             MC_Apical_Dendrite_Average_Contraction
# 5     1.283407  32                MC_Apical_Dendrite_Average_Diameter
# 2     1.246277  32             MC_Apical_Dendrite_Average_Ralls_Ratio
# 8     1.079138  32               MC_Apical_Dendrite_Fractal_Dimension
# 1     9.250000  32                MC_Apical_Dendrite_Max_Branch_Order
# 7   248.774094  32          MC_Apical_Dendrite_Max_Euclidean_Distance
# 6   395.460719  32               MC_Apical_Dendrite_Max_Path_Distance
# 4   131.908588  32                  MC_Apical_Dendrite_Overall_Height
# 10  176.944409  32                   MC_Apical_Dendrite_Overall_Width
# 9     0.502941  32             MC_Apical_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 11         39   9.184030
# 0          39  11.636556
# 3          39   0.041105
# 5          39   0.258818
# 2          39   0.126439
# 8          39   0.024796
# 1          39   2.657536
# 7          39  48.610215
# 6          39  73.921431
# 4          39  68.947035
# 10         39  57.142362
# 9          39   0.088752

# %%
Measurement.insert(stats).execute()
# Out:
# 566

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 32)
# (2, 'out of', 32)
# (3, 'out of', 32)
# (4, 'out of', 32)
# (5, 'out of', 32)
# (6, 'out of', 32)
# (7, 'out of', 32)
# (8, 'out of', 32)
# (9, 'out of', 32)
# (10, 'out of', 32)
# (11, 'out of', 32)
# (12, 'out of', 32)
# (13, 'out of', 32)
# (14, 'out of', 32)
# (15, 'out of', 32)
# (16, 'out of', 32)
# (17, 'out of', 32)
# (18, 'out of', 32)
# (19, 'out of', 32)
# (20, 'out of', 32)
# (21, 'out of', 32)
# (22, 'out of', 32)
# (23, 'out of', 32)
# (24, 'out of', 32)
# (25, 'out of', 32)
# (26, 'out of', 32)
# (27, 'out of', 32)
# (28, 'out of', 32)
# (29, 'out of', 32)
# (30, 'out of', 32)
# (31, 'out of', 32)
# (32, 'out of', 32)
#           mean   n                                        property_id  \
# 9    82.934784  32  MC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4    38.199116  32  MC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 11    0.708472  32              MC_Basal_Dendrite_Average_Contraction
# 1     1.024726  32                 MC_Basal_Dendrite_Average_Diameter
# 8     0.886891  32              MC_Basal_Dendrite_Average_Ralls_Ratio
# 3     1.047663  32                MC_Basal_Dendrite_Fractal_Dimension
# 7     2.156250  32                 MC_Basal_Dendrite_Max_Branch_Order
# 2   569.732469  32           MC_Basal_Dendrite_Max_Euclidean_Distance
# 6   765.420531  32                MC_Basal_Dendrite_Max_Path_Distance
# 0   729.817353  32                   MC_Basal_Dendrite_Overall_Height
# 5   188.185369  32                    MC_Basal_Dendrite_Overall_Width
# 10    0.293707  32              MC_Basal_Dendrite_Partition_Asymmetry
#
#     source_id         std
# 9          39   23.319023
# 4          39   19.587075
# 11         39    0.058978
# 1          39    0.245481
# 8          39    0.313384
# 3          39    0.016990
# 7          39    1.003412
# 2          39  186.360067
# 6          39  222.717956
# 0          39  346.831268
# 5          39   93.740935
# 10         39    0.225959

# %%
Measurement.insert(stats).execute()
# Out:
# 578

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 32)
# (2, 'out of', 32)
# (3, 'out of', 32)
# (4, 'out of', 32)
# (5, 'out of', 32)
# (6, 'out of', 32)
# (7, 'out of', 32)
# (8, 'out of', 32)
# (9, 'out of', 32)
# (10, 'out of', 32)
# (11, 'out of', 32)
# (12, 'out of', 32)
# (13, 'out of', 32)
# (14, 'out of', 32)
# (15, 'out of', 32)
# (16, 'out of', 32)
# (17, 'out of', 32)
# (18, 'out of', 32)
# (19, 'out of', 32)
# (20, 'out of', 32)
# (21, 'out of', 32)
# (22, 'out of', 32)
# (23, 'out of', 32)
# (24, 'out of', 32)
# (25, 'out of', 32)
# (26, 'out of', 32)
# (27, 'out of', 32)
# (28, 'out of', 32)
# (29, 'out of', 32)
# (30, 'out of', 32)
# (31, 'out of', 32)
# (32, 'out of', 32)
#           mean   n           property_id  source_id         std
# 1     6.218750  32    MC_Number_of_Stems         39    1.653299
# 0  1532.763937  32  MC_Soma_Surface_Area         39  695.434509

# %%
Measurement.insert(stats).execute()
# Out:
# 580

# %% [markdown]
# ## Urban MC archive - Burton 2017

# %%
dir = 'morphology-data/MCs/urban-done/Burton2017/'
cell = "MC"
exclude = full_slice_only_tests
source_id=41

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 3)
# (2, 'out of', 3)
# (3, 'out of', 3)
#           mean  n                                        property_id  \
# 11   88.560567  3  MC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0    79.850567  3  MC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3     0.822330  3             MC_Apical_Dendrite_Average_Contraction
# 5     0.955352  3                MC_Apical_Dendrite_Average_Diameter
# 2     0.945164  3             MC_Apical_Dendrite_Average_Ralls_Ratio
# 8     1.068573  3               MC_Apical_Dendrite_Fractal_Dimension
# 1    13.333333  3                MC_Apical_Dendrite_Max_Branch_Order
# 7   350.069667  3          MC_Apical_Dendrite_Max_Euclidean_Distance
# 6   450.317333  3               MC_Apical_Dendrite_Max_Path_Distance
# 4   105.266533  3                  MC_Apical_Dendrite_Overall_Height
# 10  255.944667  3                   MC_Apical_Dendrite_Overall_Width
# 9     0.524295  3             MC_Apical_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 11         41   4.092158
# 0          41   3.241047
# 3          41   0.034897
# 5          41   0.025094
# 2          41   0.087214
# 8          41   0.012654
# 1          41   1.885618
# 7          41  14.595527
# 6          41  16.139690
# 4          41  14.559185
# 10         41  36.392360
# 9          41   0.041154

# %%
Measurement.insert(stats).execute()
# Out:
# 592

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 3)
# (2, 'out of', 3)
# (3, 'out of', 3)
#            mean  n                                        property_id  \
# 9     83.982567  3  MC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4     54.280633  3  MC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 11     0.767566  3              MC_Basal_Dendrite_Average_Contraction
# 1      0.811660  3                 MC_Basal_Dendrite_Average_Diameter
# 8      0.950500  3              MC_Basal_Dendrite_Average_Ralls_Ratio
# 3      1.060120  3                MC_Basal_Dendrite_Fractal_Dimension
# 7      4.333333  3                 MC_Basal_Dendrite_Max_Branch_Order
# 2    702.102667  3           MC_Basal_Dendrite_Max_Euclidean_Distance
# 6    899.647333  3                MC_Basal_Dendrite_Max_Path_Distance
# 0   1127.214333  3                   MC_Basal_Dendrite_Overall_Height
# 5    162.248333  3                    MC_Basal_Dendrite_Overall_Width
# 10     0.263468  3              MC_Basal_Dendrite_Partition_Asymmetry
#
#     source_id         std
# 9          41    6.527652
# 4          41    2.961739
# 11         41    0.023730
# 1          41    0.187695
# 8          41    0.068390
# 3          41    0.016199
# 7          41    0.471405
# 2          41   51.284098
# 6          41   79.417991
# 0          41  174.776862
# 5          41   20.518662
# 10         41    0.156539

# %%
Measurement.insert(stats).execute()
# Out:
# 604

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 3)
# (2, 'out of', 3)
# (3, 'out of', 3)
#           mean  n           property_id  source_id         std
# 1     4.333333  3    MC_Number_of_Stems         41    0.471405
# 0  2033.163333  3  MC_Soma_Surface_Area         41  294.335555

# %%
Measurement.insert(stats).execute()
# Out:
# 606

# %% [markdown]
# ## Urban MC archive - Case 2017

# %%
dir = 'morphology-data/MCs/urban-done/Case2017/'
cell = "MC"
exclude = []
source_id=40

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 6)
# (2, 'out of', 6)
# (3, 'out of', 6)
# (4, 'out of', 6)
# (5, 'out of', 6)
# (6, 'out of', 6)
#            mean  n                                        property_id  \
# 17    88.379633  6  MC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 2     74.899983  6  MC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 6      0.801003  6             MC_Apical_Dendrite_Average_Contraction
# 8      1.415694  6                MC_Apical_Dendrite_Average_Diameter
# 13     1.085338  6             MC_Apical_Dendrite_Average_Ralls_Ratio
# 14     1.051842  6               MC_Apical_Dendrite_Fractal_Dimension
# 3      8.666667  6                MC_Apical_Dendrite_Max_Branch_Order
# 12   256.859500  6          MC_Apical_Dendrite_Max_Euclidean_Distance
# 10   400.213833  6               MC_Apical_Dendrite_Max_Path_Distance
# 0     18.333333  6          MC_Apical_Dendrite_Number_of_Bifurcations
# 9     37.166667  6              MC_Apical_Dendrite_Number_of_Branches
# 11    69.543333  6                   MC_Apical_Dendrite_Overall_Depth
# 7    164.883717  6                  MC_Apical_Dendrite_Overall_Height
# 16   153.121550  6                   MC_Apical_Dendrite_Overall_Width
# 15     0.510920  6             MC_Apical_Dendrite_Partition_Asymmetry
# 4    806.772333  6                    MC_Apical_Dendrite_Total_Length
# 1   3842.656667  6                   MC_Apical_Dendrite_Total_Surface
# 5   2524.475000  6                    MC_Apical_Dendrite_Total_Volume
#
#     source_id         std
# 17         40    7.070227
# 2          40   12.861719
# 6          40    0.043778
# 8          40    0.364401
# 13         40    0.120399
# 14         40    0.017167
# 3          40    2.624669
# 12         40   62.783085
# 10         40   81.109513
# 0          40    9.603240
# 9          40   19.143464
# 11         40   20.041241
# 7          40   90.122449
# 16         40   52.724992
# 15         40    0.147084
# 4          40  146.960139
# 1          40  579.924004
# 5          40  503.399377

# %%
Measurement.insert(stats).execute()
# Out:
# 624

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 6)
# (2, 'out of', 6)
# (3, 'out of', 6)
# (4, 'out of', 6)
# (5, 'out of', 6)
# (6, 'out of', 6)
#             mean  n                                        property_id  \
# 14     82.005400  6  MC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 5      54.787333  6  MC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 16      0.824421  6              MC_Basal_Dendrite_Average_Contraction
# 4       0.813339  6                 MC_Basal_Dendrite_Average_Diameter
# 12      0.662295  6              MC_Basal_Dendrite_Average_Ralls_Ratio
# 3       1.027985  6                MC_Basal_Dendrite_Fractal_Dimension
# 11      6.333333  6                 MC_Basal_Dendrite_Max_Branch_Order
# 13    794.337000  6           MC_Basal_Dendrite_Max_Euclidean_Distance
# 7     944.093833  6                MC_Basal_Dendrite_Max_Path_Distance
# 17     10.000000  6           MC_Basal_Dendrite_Number_of_Bifurcations
# 1      24.000000  6               MC_Basal_Dendrite_Number_of_Branches
# 8     126.023333  6                    MC_Basal_Dendrite_Overall_Depth
# 0    1107.057667  6                   MC_Basal_Dendrite_Overall_Height
# 6     525.067667  6                    MC_Basal_Dendrite_Overall_Width
# 15      0.368125  6              MC_Basal_Dendrite_Partition_Asymmetry
# 2    4026.205000  6                     MC_Basal_Dendrite_Total_Length
# 10  11703.595000  6                    MC_Basal_Dendrite_Total_Surface
# 9    3952.710000  6                     MC_Basal_Dendrite_Total_Volume
#
#     source_id          std
# 14         40     2.814333
# 5          40    18.689437
# 16         40     0.023729
# 4          40     0.192124
# 12         40     0.227920
# 3          40     0.008298
# 11         40     8.399735
# 13         40   162.625430
# 7          40   197.268037
# 17         40     7.979139
# 1          40    16.881943
# 8          40    43.979227
# 0          40   347.743828
# 6          40   198.869908
# 15         40     0.278712
# 2          40  1287.073027
# 10         40  4941.209827
# 9          40  1863.688098

# %%
Measurement.insert(stats).execute()
# Out:
# 642

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 6)
# (2, 'out of', 6)
# (3, 'out of', 6)
# (4, 'out of', 6)
# (5, 'out of', 6)
# (6, 'out of', 6)
#           mean  n           property_id  source_id         std
# 1     5.500000  6    MC_Number_of_Stems         40    1.118034
# 0  1403.845167  6  MC_Soma_Surface_Area         40  490.053701

# %%
Measurement.insert(stats).execute()
# Out:
# 644

# %% [markdown]
# ## Fukunaga TC archive

# %%
dir = 'morphology-data/TCs/fukunaga/'
cell = "TC"
exclude = []
source_id=42

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 8)
# (2, 'out of', 8)
# (3, 'out of', 8)
# (4, 'out of', 8)
# (5, 'out of', 8)
# (6, 'out of', 8)
# (7, 'out of', 8)
# (8, 'out of', 8)
#            mean  n                                        property_id  \
# 17    90.355263  8  TC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 2     71.598475  8  TC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 6      0.867449  8             TC_Apical_Dendrite_Average_Contraction
# 8      0.812704  8                TC_Apical_Dendrite_Average_Diameter
# 13     1.430574  8             TC_Apical_Dendrite_Average_Ralls_Ratio
# 14     1.046829  8               TC_Apical_Dendrite_Fractal_Dimension
# 3      8.875000  8                TC_Apical_Dendrite_Max_Branch_Order
# 12   170.061250  8          TC_Apical_Dendrite_Max_Euclidean_Distance
# 10   241.125500  8               TC_Apical_Dendrite_Max_Path_Distance
# 0     34.875000  8          TC_Apical_Dendrite_Number_of_Bifurcations
# 9     70.000000  8              TC_Apical_Dendrite_Number_of_Branches
# 11    77.377500  8                   TC_Apical_Dendrite_Overall_Depth
# 7    117.345388  8                  TC_Apical_Dendrite_Overall_Height
# 16    74.965075  8                   TC_Apical_Dendrite_Overall_Width
# 15     0.487831  8             TC_Apical_Dendrite_Partition_Asymmetry
# 4   1205.746125  8                    TC_Apical_Dendrite_Total_Length
# 1   3297.716250  8                   TC_Apical_Dendrite_Total_Surface
# 5   1426.782750  8                    TC_Apical_Dendrite_Total_Volume
#
#     source_id          std
# 17         42     9.210468
# 2          42     6.228703
# 6          42     0.027709
# 8          42     0.254121
# 13         42     0.085786
# 14         42     0.009740
# 3          42     3.099899
# 12         42    64.589748
# 10         42    93.661294
# 0          42    22.657435
# 9          42    44.897105
# 11         42    47.501393
# 7          42    51.792396
# 16         42    25.947091
# 15         42     0.093473
# 4          42   570.709705
# 1          42  1919.235054
# 5          42  1346.871253

# %%
Measurement.insert(stats).execute()
# Out:
# 662

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 8)
# (2, 'out of', 8)
# (3, 'out of', 8)
# (4, 'out of', 8)
# (5, 'out of', 8)
# (6, 'out of', 8)
# (7, 'out of', 8)
# (8, 'out of', 8)
#            mean  n                                        property_id  \
# 14    78.390875  8  TC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 5     47.866500  8  TC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 16     0.709839  8              TC_Basal_Dendrite_Average_Contraction
# 4      0.866638  8                 TC_Basal_Dendrite_Average_Diameter
# 12     1.144040  8              TC_Basal_Dendrite_Average_Ralls_Ratio
# 3      0.907250  8                TC_Basal_Dendrite_Fractal_Dimension
# 11     3.250000  8                 TC_Basal_Dendrite_Max_Branch_Order
# 13   409.940500  8           TC_Basal_Dendrite_Max_Euclidean_Distance
# 7    571.949750  8                TC_Basal_Dendrite_Max_Path_Distance
# 17     4.750000  8           TC_Basal_Dendrite_Number_of_Bifurcations
# 1     11.500000  8               TC_Basal_Dendrite_Number_of_Branches
# 8    159.252500  8                    TC_Basal_Dendrite_Overall_Depth
# 0    503.453000  8                   TC_Basal_Dendrite_Overall_Height
# 6    217.187087  8                    TC_Basal_Dendrite_Overall_Width
# 15     0.384785  8              TC_Basal_Dendrite_Partition_Asymmetry
# 2   1967.880125  8                     TC_Basal_Dendrite_Total_Length
# 10  6004.276250  8                    TC_Basal_Dendrite_Total_Surface
# 9   1748.779250  8                     TC_Basal_Dendrite_Total_Volume
#
#     source_id          std
# 14         42    34.936669
# 5          42    25.230130
# 16         42     0.274349
# 4          42     0.355687
# 12         42     0.505258
# 3          42     0.343151
# 11         42     1.639360
# 13         42   238.912071
# 7          42   337.170805
# 17         42     2.989565
# 1          42     6.964194
# 8          42   105.051852
# 0          42   331.304899
# 6          42   153.114328
# 15         42     0.228706
# 2          42  1476.031581
# 10         42  4980.178426
# 9          42  1568.320361

# %%
Measurement.insert(stats).execute()
# Out:
# 680

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 8)
# (2, 'out of', 8)
# (3, 'out of', 8)
# (4, 'out of', 8)
# (5, 'out of', 8)
# (6, 'out of', 8)
# (7, 'out of', 8)
# (8, 'out of', 8)
#          mean  n           property_id  source_id         std
# 1    3.000000  8    TC_Number_of_Stems         42    1.000000
# 0  496.065375  8  TC_Soma_Surface_Area         42  158.615486

# %%
Measurement.insert(stats).execute()
# Out:
# 682

# %% [markdown]
# ## Urban TC archive - Burton 2017

# %%
dir = 'morphology-data/TCs/urban/Burton2017'
cell = "TC"
exclude = full_slice_only_tests
source_id=41

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 4)
# (2, 'out of', 4)
# (3, 'out of', 4)
# (4, 'out of', 4)
#           mean  n                                        property_id  \
# 11   94.976300  4  TC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0    79.443975  4  TC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3     0.815713  4             TC_Apical_Dendrite_Average_Contraction
# 5     0.810989  4                TC_Apical_Dendrite_Average_Diameter
# 2     1.120430  4             TC_Apical_Dendrite_Average_Ralls_Ratio
# 8     1.055705  4               TC_Apical_Dendrite_Fractal_Dimension
# 1    17.500000  4                TC_Apical_Dendrite_Max_Branch_Order
# 7   190.151000  4          TC_Apical_Dendrite_Max_Euclidean_Distance
# 6   291.207500  4               TC_Apical_Dendrite_Max_Path_Distance
# 4   104.027100  4                  TC_Apical_Dendrite_Overall_Height
# 10  130.753325  4                   TC_Apical_Dendrite_Overall_Width
# 9     0.604785  4             TC_Apical_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 11         41   3.495362
# 0          41   6.403636
# 3          41   0.032431
# 5          41   0.153522
# 2          41   0.162045
# 8          41   0.013312
# 1          41   4.031129
# 7          41  28.340398
# 6          41  65.998413
# 4          41  24.397720
# 10         41  36.159114
# 9          41   0.020174

# %%
Measurement.insert(stats).execute()
# Out:
# 694

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 4)
# (2, 'out of', 4)
# (3, 'out of', 4)
# (4, 'out of', 4)
#           mean  n                                        property_id  \
# 9    66.974150  4  TC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4    45.793975  4  TC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 11    0.727533  4              TC_Basal_Dendrite_Average_Contraction
# 1     1.055360  4                 TC_Basal_Dendrite_Average_Diameter
# 8     0.580031  4              TC_Basal_Dendrite_Average_Ralls_Ratio
# 3     1.049482  4                TC_Basal_Dendrite_Fractal_Dimension
# 7     3.500000  4                 TC_Basal_Dendrite_Max_Branch_Order
# 2   663.845500  4           TC_Basal_Dendrite_Max_Euclidean_Distance
# 6   895.501000  4                TC_Basal_Dendrite_Max_Path_Distance
# 0   633.469000  4                   TC_Basal_Dendrite_Overall_Height
# 5   243.120200  4                    TC_Basal_Dendrite_Overall_Width
# 10    0.206424  4              TC_Basal_Dendrite_Partition_Asymmetry
#
#     source_id         std
# 9          41   39.129883
# 4          41   28.161006
# 11         41    0.050440
# 1          41    0.045100
# 8          41    0.340322
# 3          41    0.016232
# 7          41    2.598076
# 2          41   97.260241
# 6          41  114.813259
# 0          41  170.783465
# 5          41  128.256679
# 10         41    0.207587

# %%
Measurement.insert(stats).execute()
# Out:
# 706

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 4)
# (2, 'out of', 4)
# (3, 'out of', 4)
# (4, 'out of', 4)
#          mean  n           property_id  source_id         std
# 1     3.50000  4    TC_Number_of_Stems         41    1.118034
# 0  1524.10725  4  TC_Soma_Surface_Area         41  653.587890

# %%
Measurement.insert(stats).execute()
# Out:
# 708

# %% [markdown]
# ## Urban TC archive - BurtonUrban2014

# %%
dir = 'morphology-data/TCs/urban/BurtonUrban2014'
cell = "TC"
exclude = full_slice_only_tests
source_id=39

# %%
# Apical
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=apical_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 25)
# (2, 'out of', 25)
# (3, 'out of', 25)
# (4, 'out of', 25)
# (5, 'out of', 25)
# (6, 'out of', 25)
# (7, 'out of', 25)
# (8, 'out of', 25)
# (9, 'out of', 25)
# (10, 'out of', 25)
# (11, 'out of', 25)
# (12, 'out of', 25)
# (13, 'out of', 25)
# (14, 'out of', 25)
# (15, 'out of', 25)
# (16, 'out of', 25)
# (17, 'out of', 25)
# (18, 'out of', 25)
# (19, 'out of', 25)
# (20, 'out of', 25)
# (21, 'out of', 25)
# (22, 'out of', 25)
# (23, 'out of', 25)
# (24, 'out of', 25)
# (25, 'out of', 25)
#           mean   n                                        property_id  \
# 11   90.446168  25  TC_Apical_Dendrite_Average_Bifurcation_Angle_L...
# 0    68.662104  25  TC_Apical_Dendrite_Average_Bifurcation_Angle_R...
# 3     0.745994  25             TC_Apical_Dendrite_Average_Contraction
# 5     1.031612  25                TC_Apical_Dendrite_Average_Diameter
# 2     1.229013  25             TC_Apical_Dendrite_Average_Ralls_Ratio
# 8     1.073119  25               TC_Apical_Dendrite_Fractal_Dimension
# 1     9.640000  25                TC_Apical_Dendrite_Max_Branch_Order
# 7   169.204360  25          TC_Apical_Dendrite_Max_Euclidean_Distance
# 6   277.745320  25               TC_Apical_Dendrite_Max_Path_Distance
# 4   108.261820  25                  TC_Apical_Dendrite_Overall_Height
# 10  103.533052  25                   TC_Apical_Dendrite_Overall_Width
# 9     0.530965  25             TC_Apical_Dendrite_Partition_Asymmetry
#
#     source_id        std
# 11         39   7.224367
# 0          39   6.237311
# 3          39   0.036882
# 5          39   0.209092
# 2          39   0.122527
# 8          39   0.019122
# 1          39   2.480000
# 7          39  37.947770
# 6          39  54.296267
# 4          39  49.758029
# 10         39  47.978451
# 9          39   0.106179

# %%
Measurement.insert(stats).execute()
# Out:
# 720

# %%
# Basal
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=basal_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 25)
# (2, 'out of', 25)
# (3, 'out of', 25)
# (4, 'out of', 25)
# (5, 'out of', 25)
# (6, 'out of', 25)
# (7, 'out of', 25)
# (8, 'out of', 25)
# (9, 'out of', 25)
# (10, 'out of', 25)
# (11, 'out of', 25)
# (12, 'out of', 25)
# (13, 'out of', 25)
# (14, 'out of', 25)
# (15, 'out of', 25)
# (16, 'out of', 25)
# (17, 'out of', 25)
# (18, 'out of', 25)
# (19, 'out of', 25)
# (20, 'out of', 25)
# (21, 'out of', 25)
# (22, 'out of', 25)
# (23, 'out of', 25)
# (24, 'out of', 25)
# (25, 'out of', 25)
#           mean   n                                        property_id  \
# 9    80.502520  25  TC_Basal_Dendrite_Average_Bifurcation_Angle_Local
# 4    41.262640  25  TC_Basal_Dendrite_Average_Bifurcation_Angle_Re...
# 11    0.678597  25              TC_Basal_Dendrite_Average_Contraction
# 1     1.116533  25                 TC_Basal_Dendrite_Average_Diameter
# 8     0.891300  25              TC_Basal_Dendrite_Average_Ralls_Ratio
# 3     1.047283  25                TC_Basal_Dendrite_Fractal_Dimension
# 7     2.280000  25                 TC_Basal_Dendrite_Max_Branch_Order
# 2   478.756040  25           TC_Basal_Dendrite_Max_Euclidean_Distance
# 6   692.657960  25                TC_Basal_Dendrite_Max_Path_Distance
# 0   552.243580  25                   TC_Basal_Dendrite_Overall_Height
# 5   177.822924  25                    TC_Basal_Dendrite_Overall_Width
# 10    0.222204  25              TC_Basal_Dendrite_Partition_Asymmetry
#
#     source_id         std
# 9          39   26.311127
# 4          39   21.421853
# 11         39    0.046349
# 1          39    0.252862
# 8          39    0.339208
# 3          39    0.017803
# 7          39    1.865905
# 2          39  161.807436
# 6          39  208.479438
# 0          39  326.200361
# 5          39  149.719165
# 10         39    0.241289

# %%
Measurement.insert(stats).execute()
# Out:
# 732

# %%
# Soma
stats = compute_morphology_stats(dir=dir,
                             CellShort=cell, 
                             test_set=soma_tests, 
                             exclude=exclude,
                             source_id=source_id)\
        .values()

DataFrame(stats).sort("property_id")
# Out:
# (1, 'out of', 25)
# (2, 'out of', 25)
# (3, 'out of', 25)
# (4, 'out of', 25)
# (5, 'out of', 25)
# (6, 'out of', 25)
# (7, 'out of', 25)
# (8, 'out of', 25)
# (9, 'out of', 25)
# (10, 'out of', 25)
# (11, 'out of', 25)
# (12, 'out of', 25)
# (13, 'out of', 25)
# (14, 'out of', 25)
# (15, 'out of', 25)
# (16, 'out of', 25)
# (17, 'out of', 25)
# (18, 'out of', 25)
# (19, 'out of', 25)
# (20, 'out of', 25)
# (21, 'out of', 25)
# (22, 'out of', 25)
# (23, 'out of', 25)
# (24, 'out of', 25)
# (25, 'out of', 25)
#          mean   n           property_id  source_id         std
# 1     4.92000  25    TC_Number_of_Stems         39    1.597999
# 0  1183.60256  25  TC_Soma_Surface_Area         39  681.986659

# %%
Measurement.insert(stats).execute()
# Out:
# 734

# %% [markdown]
# ## Pool experimental values

# %%
props = Property\
        .select(Property.id)\
        .where(Property.type == 'Morphology')

# %%
[p.id for p in props]
# Out:
# [u'GC_Soma_Surface_Area',
#  u'GC_Number_of_Stems',
#  u'GC_Basal_Dendrite_Number_of_Bifurcations',
#  u'GC_Basal_Dendrite_Number_of_Branches',
#  u'GC_Basal_Dendrite_Overall_Width',
#  u'GC_Basal_Dendrite_Overall_Height',
#  u'GC_Basal_Dendrite_Overall_Depth',
#  u'GC_Basal_Dendrite_Average_Diameter',
#  u'GC_Basal_Dendrite_Total_Length',
#  u'GC_Basal_Dendrite_Total_Surface',
#  u'GC_Basal_Dendrite_Total_Volume',
#  u'GC_Basal_Dendrite_Max_Euclidean_Distance',
#  u'GC_Basal_Dendrite_Max_Path_Distance',
#  u'GC_Basal_Dendrite_Max_Branch_Order',
#  u'GC_Basal_Dendrite_Average_Contraction',
#  u'GC_Basal_Dendrite_Total_Fragmentation',
#  u'GC_Basal_Dendrite_Partition_Asymmetry',
#  u'GC_Basal_Dendrite_Average_Ralls_Ratio',
#  u'GC_Basal_Dendrite_Average_Bifurcation_Angle_Local',
#  u'GC_Basal_Dendrite_Average_Bifurcation_Angle_Remote',
#  u'GC_Basal_Dendrite_Fractal_Dimension',
#  u'GC_Apical_Dendrite_Number_of_Bifurcations',
#  u'GC_Apical_Dendrite_Number_of_Branches',
#  u'GC_Apical_Dendrite_Overall_Width',
#  u'GC_Apical_Dendrite_Overall_Height',
#  u'GC_Apical_Dendrite_Overall_Depth',
#  u'GC_Apical_Dendrite_Average_Diameter',
#  u'GC_Apical_Dendrite_Total_Length',
#  u'GC_Apical_Dendrite_Total_Surface',
#  u'GC_Apical_Dendrite_Total_Volume',
#  u'GC_Apical_Dendrite_Max_Euclidean_Distance',
#  u'GC_Apical_Dendrite_Max_Path_Distance',
#  u'GC_Apical_Dendrite_Max_Branch_Order',
#  u'GC_Apical_Dendrite_Average_Contraction',
#  u'GC_Apical_Dendrite_Total_Fragmentation',
#  u'GC_Apical_Dendrite_Partition_Asymmetry',
#  u'GC_Apical_Dendrite_Average_Ralls_Ratio',
#  u'GC_Apical_Dendrite_Average_Bifurcation_Angle_Local',
#  u'GC_Apical_Dendrite_Average_Bifurcation_Angle_Remote',
#  u'GC_Apical_Dendrite_Fractal_Dimension',
#  u'MC_Soma_Surface_Area',
#  u'MC_Number_of_Stems',
#  u'MC_Basal_Dendrite_Number_of_Bifurcations',
#  u'MC_Basal_Dendrite_Number_of_Branches',
#  u'MC_Basal_Dendrite_Overall_Width',
#  u'MC_Basal_Dendrite_Overall_Height',
#  u'MC_Basal_Dendrite_Overall_Depth',
#  u'MC_Basal_Dendrite_Average_Diameter',
#  u'MC_Basal_Dendrite_Total_Length',
#  u'MC_Basal_Dendrite_Total_Surface',
#  u'MC_Basal_Dendrite_Total_Volume',
#  u'MC_Basal_Dendrite_Max_Euclidean_Distance',
#  u'MC_Basal_Dendrite_Max_Path_Distance',
#  u'MC_Basal_Dendrite_Max_Branch_Order',
#  u'MC_Basal_Dendrite_Average_Contraction',
#  u'MC_Basal_Dendrite_Total_Fragmentation',
#  u'MC_Basal_Dendrite_Partition_Asymmetry',
#  u'MC_Basal_Dendrite_Average_Ralls_Ratio',
#  u'MC_Basal_Dendrite_Average_Bifurcation_Angle_Local',
#  u'MC_Basal_Dendrite_Average_Bifurcation_Angle_Remote',
#  u'MC_Basal_Dendrite_Fractal_Dimension',
#  u'MC_Apical_Dendrite_Number_of_Bifurcations',
#  u'MC_Apical_Dendrite_Number_of_Branches',
#  u'MC_Apical_Dendrite_Overall_Width',
#  u'MC_Apical_Dendrite_Overall_Height',
#  u'MC_Apical_Dendrite_Overall_Depth',
#  u'MC_Apical_Dendrite_Average_Diameter',
#  u'MC_Apical_Dendrite_Total_Length',
#  u'MC_Apical_Dendrite_Total_Surface',
#  u'MC_Apical_Dendrite_Total_Volume',
#  u'MC_Apical_Dendrite_Max_Euclidean_Distance',
#  u'MC_Apical_Dendrite_Max_Path_Distance',
#  u'MC_Apical_Dendrite_Max_Branch_Order',
#  u'MC_Apical_Dendrite_Average_Contraction',
#  u'MC_Apical_Dendrite_Total_Fragmentation',
#  u'MC_Apical_Dendrite_Partition_Asymmetry',
#  u'MC_Apical_Dendrite_Average_Ralls_Ratio',
#  u'MC_Apical_Dendrite_Average_Bifurcation_Angle_Local',
#  u'MC_Apical_Dendrite_Average_Bifurcation_Angle_Remote',
#  u'MC_Apical_Dendrite_Fractal_Dimension',
#  u'TC_Soma_Surface_Area',
#  u'TC_Number_of_Stems',
#  u'TC_Basal_Dendrite_Number_of_Bifurcations',
#  u'TC_Basal_Dendrite_Number_of_Branches',
#  u'TC_Basal_Dendrite_Overall_Width',
#  u'TC_Basal_Dendrite_Overall_Height',
#  u'TC_Basal_Dendrite_Overall_Depth',
#  u'TC_Basal_Dendrite_Average_Diameter',
#  u'TC_Basal_Dendrite_Total_Length',
#  u'TC_Basal_Dendrite_Total_Surface',
#  u'TC_Basal_Dendrite_Total_Volume',
#  u'TC_Basal_Dendrite_Max_Euclidean_Distance',
#  u'TC_Basal_Dendrite_Max_Path_Distance',
#  u'TC_Basal_Dendrite_Max_Branch_Order',
#  u'TC_Basal_Dendrite_Average_Contraction',
#  u'TC_Basal_Dendrite_Total_Fragmentation',
#  u'TC_Basal_Dendrite_Partition_Asymmetry',
#  u'TC_Basal_Dendrite_Average_Ralls_Ratio',
#  u'TC_Basal_Dendrite_Average_Bifurcation_Angle_Local',
#  u'TC_Basal_Dendrite_Average_Bifurcation_Angle_Remote',
#  u'TC_Basal_Dendrite_Fractal_Dimension',
#  u'TC_Apical_Dendrite_Number_of_Bifurcations',
#  u'TC_Apical_Dendrite_Number_of_Branches',
#  u'TC_Apical_Dendrite_Overall_Width',
#  u'TC_Apical_Dendrite_Overall_Height',
#  u'TC_Apical_Dendrite_Overall_Depth',
#  u'TC_Apical_Dendrite_Average_Diameter',
#  u'TC_Apical_Dendrite_Total_Length',
#  u'TC_Apical_Dendrite_Total_Surface',
#  u'TC_Apical_Dendrite_Total_Volume',
#  u'TC_Apical_Dendrite_Max_Euclidean_Distance',
#  u'TC_Apical_Dendrite_Max_Path_Distance',
#  u'TC_Apical_Dendrite_Max_Branch_Order',
#  u'TC_Apical_Dendrite_Average_Contraction',
#  u'TC_Apical_Dendrite_Total_Fragmentation',
#  u'TC_Apical_Dendrite_Partition_Asymmetry',
#  u'TC_Apical_Dendrite_Average_Ralls_Ratio',
#  u'TC_Apical_Dendrite_Average_Bifurcation_Angle_Local',
#  u'TC_Apical_Dendrite_Average_Bifurcation_Angle_Remote',
#  u'TC_Apical_Dendrite_Fractal_Dimension']

# %%
from olfactorybulb.utilities import pool_experimental_measurements

for prop in props:
    pool_experimental_measurements(prop.id)
# Out:
# Pooled 4 measurements of GC_Soma_Surface_Area with mean: 263.14775783439677 std: 181.1414885100263 n: 149
# Pooled 4 measurements of GC_Number_of_Stems with mean: 2.6686278255508196 std: 1.2067626463739296 n: 149
# Pooled 1 measurements of GC_Basal_Dendrite_Number_of_Bifurcations with mean: 0.2783149582266985 std: 0.4659709918578107 n: 39
# Pooled 2 measurements of GC_Basal_Dendrite_Number_of_Branches with mean: 2.1423881065439407 std: 1.5320653628193264 n: 45
# Pooled 7 measurements of GC_Basal_Dendrite_Overall_Width with mean: 7.44911751122887 std: 15.90172087077613 n: 488
# Pooled 7 measurements of GC_Basal_Dendrite_Overall_Height with mean: 9.1539751716503 std: 21.407467941016954 n: 488
# Pooled 2 measurements of GC_Basal_Dendrite_Overall_Depth with mean: 6.09725506529152 std: 7.4755876751298835 n: 45
# Pooled 4 measurements of GC_Basal_Dendrite_Average_Diameter with mean: 0.22295458965198944 std: 0.5025434467921008 n: 401
# Pooled 2 measurements of GC_Basal_Dendrite_Total_Length with mean: 38.850798962265024 std: 34.08235877485553 n: 45
# Pooled 0 measurements of GC_Basal_Dendrite_Total_Surface with mean: nan std: nan n: 0
# Pooled 0 measurements of GC_Basal_Dendrite_Total_Volume with mean: nan std: nan n: 0
# Pooled 7 measurements of GC_Basal_Dendrite_Max_Euclidean_Distance with mean: 11.361206681486088 std: 24.076515106150424 n: 488
# Pooled 7 measurements of GC_Basal_Dendrite_Max_Path_Distance with mean: 13.632660797811504 std: 25.966851595737907 n: 488
# Pooled 6 measurements of GC_Basal_Dendrite_Max_Branch_Order with mean: 0.2263798792867792 std: 0.6797866634147149 n: 482
# Pooled 4 measurements of GC_Basal_Dendrite_Average_Contraction with mean: 0.15968538621679546 std: 0.3417057443775243 n: 401
# Pooled 0 measurements of GC_Basal_Dendrite_Total_Fragmentation with mean: nan std: nan n: 0
# Pooled 6 measurements of GC_Basal_Dendrite_Partition_Asymmetry with mean: 0.008851837886805679 std: 0.07204642102111117 n: 482
# Pooled 4 measurements of GC_Basal_Dendrite_Average_Ralls_Ratio with mean: 0.12473119148874023 std: 0.6428076186444731 n: 401
# Pooled 6 measurements of GC_Basal_Dendrite_Average_Bifurcation_Angle_Local with mean: 8.051612116491976 std: 26.930919915911133 n: 482
# Pooled 6 measurements of GC_Basal_Dendrite_Average_Bifurcation_Angle_Remote with mean: 6.738438248700377 std: 23.20118738362157 n: 482
# Pooled 7 measurements of GC_Basal_Dendrite_Fractal_Dimension with mean: 0.31210865416650285 std: 0.4752547601485492 n: 488
# Pooled 2 measurements of GC_Apical_Dendrite_Number_of_Bifurcations with mean: 2.6734805284032492 std: 1.8305239413923955 n: 45
# Pooled 2 measurements of GC_Apical_Dendrite_Number_of_Branches with mean: 6.450134077295296 std: 4.475932234873697 n: 45
# Pooled 8 measurements of GC_Apical_Dendrite_Overall_Width with mean: 59.31734377668637 std: 39.90243341371754 n: 499
# Pooled 8 measurements of GC_Apical_Dendrite_Overall_Height with mean: 223.41874663492214 std: 81.13537650227973 n: 499
# Pooled 2 measurements of GC_Apical_Dendrite_Overall_Depth with mean: 41.59444470606774 std: 53.55500581496883 n: 45
# Pooled 4 measurements of GC_Apical_Dendrite_Average_Diameter with mean: 1.0170291350890222 std: 0.19583916828845 n: 357
# Pooled 2 measurements of GC_Apical_Dendrite_Total_Length with mean: 421.69405547478567 std: 375.10330697611107 n: 45
# Pooled 0 measurements of GC_Apical_Dendrite_Total_Surface with mean: nan std: nan n: 0
# Pooled 0 measurements of GC_Apical_Dendrite_Total_Volume with mean: nan std: nan n: 0
# Pooled 8 measurements of GC_Apical_Dendrite_Max_Euclidean_Distance with mean: 241.15760098534133 std: 84.017035601744 n: 499
# Pooled 8 measurements of GC_Apical_Dendrite_Max_Path_Distance with mean: 285.4803559109752 std: 96.91543696180868 n: 499
# Pooled 8 measurements of GC_Apical_Dendrite_Max_Branch_Order with mean: 3.3647893300319183 std: 1.6134217453179673 n: 499
# Pooled 5 measurements of GC_Apical_Dendrite_Average_Contraction with mean: 0.9201614692514429 std: 0.04266113033435607 n: 412
# Pooled 0 measurements of GC_Apical_Dendrite_Total_Fragmentation with mean: nan std: nan n: 0
# Pooled 8 measurements of GC_Apical_Dendrite_Partition_Asymmetry with mean: 0.46661710100820497 std: 0.2222617181248961 n: 499
# Pooled 4 measurements of GC_Apical_Dendrite_Average_Ralls_Ratio with mean: 1.9689903282898351 std: 0.19866343098000852 n: 357
# Pooled 8 measurements of GC_Apical_Dendrite_Average_Bifurcation_Angle_Local with mean: 76.86409126189479 std: 20.511934673650345 n: 499
# Pooled 8 measurements of GC_Apical_Dendrite_Average_Bifurcation_Angle_Remote with mean: 45.97082146891451 std: 15.624354985808115 n: 499
# Pooled 8 measurements of GC_Apical_Dendrite_Fractal_Dimension with mean: 1.0183622074054484 std: 0.030830122170025787 n: 499
# Pooled 5 measurements of MC_Soma_Surface_Area with mean: 1479.2545120700665 std: 667.1882209357191 n: 61
# Pooled 5 measurements of MC_Number_of_Stems with mean: 5.5554147571698795 std: 1.690239671517434 n: 61
# Pooled 3 measurements of MC_Basal_Dendrite_Number_of_Bifurcations with mean: 9.182032638895874 std: 7.320431446795443 n: 26
# Pooled 3 measurements of MC_Basal_Dendrite_Number_of_Branches with mean: 20.868415182784535 std: 10.529249938138324 n: 26
# Pooled 5 measurements of MC_Basal_Dendrite_Overall_Width with mean: 329.05422087320795 std: 234.90678603888034 n: 61
# Pooled 5 measurements of MC_Basal_Dendrite_Overall_Height with mean: 898.3007174357294 std: 359.4296010146357 n: 61
# Pooled 3 measurements of MC_Basal_Dendrite_Overall_Depth with mean: 180.28506196840348 std: 96.32974607868294 n: 26
# Pooled 4 measurements of MC_Basal_Dendrite_Average_Diameter with mean: 0.9902723971972375 std: 0.28885477969157985 n: 48
# Pooled 3 measurements of MC_Basal_Dendrite_Total_Length with mean: 4644.167684781486 std: 2630.195955653198 n: 26
# Pooled 2 measurements of MC_Basal_Dendrite_Total_Surface with mean: 21375.397952388004 std: 8921.324389998133 n: 13
# Pooled 2 measurements of MC_Basal_Dendrite_Total_Volume with mean: 7225.05061381843 std: 3575.239625451756 n: 13
# Pooled 5 measurements of MC_Basal_Dendrite_Max_Euclidean_Distance with mean: 667.4361075065249 std: 209.9030050114535 n: 61
# Pooled 5 measurements of MC_Basal_Dendrite_Max_Path_Distance with mean: 847.7573000604123 std: 208.91176318833632 n: 61
# Pooled 5 measurements of MC_Basal_Dendrite_Max_Branch_Order with mean: 2.8486251602841826 std: 2.063868660557151 n: 61
# Pooled 4 measurements of MC_Basal_Dendrite_Average_Contraction with mean: 0.7367523059498483 std: 0.07276141610894617 n: 48
# Pooled 0 measurements of MC_Basal_Dendrite_Total_Fragmentation with mean: nan std: nan n: 0
# Pooled 5 measurements of MC_Basal_Dendrite_Partition_Asymmetry with mean: 0.32732062975574566 std: 0.20086239150120141 n: 61
# Pooled 4 measurements of MC_Basal_Dendrite_Average_Ralls_Ratio with mean: 0.9916734692040903 std: 0.34993815934129624 n: 48
# Pooled 5 measurements of MC_Basal_Dendrite_Average_Bifurcation_Angle_Local with mean: 74.93422122191643 std: 21.607130213914 n: 61
# Pooled 5 measurements of MC_Basal_Dendrite_Average_Bifurcation_Angle_Remote with mean: 43.521218201278614 std: 18.33141076848418 n: 61
# Pooled 5 measurements of MC_Basal_Dendrite_Fractal_Dimension with mean: 1.0382461924846407 std: 0.02130711763658131 n: 61
# Pooled 3 measurements of MC_Apical_Dendrite_Number_of_Bifurcations with mean: 18.299791002952883 std: 8.657669569917735 n: 17
# Pooled 3 measurements of MC_Apical_Dendrite_Number_of_Branches with mean: 32.07005086559587 std: 19.52392185577503 n: 17
# Pooled 5 measurements of MC_Apical_Dendrite_Overall_Width with mean: 165.84186015860325 std: 73.01989346658917 n: 52
# Pooled 5 measurements of MC_Apical_Dendrite_Overall_Height with mean: 137.19437001122748 std: 67.79821727020547 n: 52
# Pooled 3 measurements of MC_Apical_Dendrite_Overall_Depth with mean: 114.15412443691297 std: 48.81589844108009 n: 17
# Pooled 5 measurements of MC_Apical_Dendrite_Average_Diameter with mean: 1.5157332577853362 std: 1.3563893249031238 n: 52
# Pooled 3 measurements of MC_Apical_Dendrite_Total_Length with mean: 730.5850380447125 std: 182.2545710760089 n: 17
# Pooled 3 measurements of MC_Apical_Dendrite_Total_Surface with mean: 3737.625421206349 std: 1021.0266387946745 n: 17
# Pooled 3 measurements of MC_Apical_Dendrite_Total_Volume with mean: 3016.6121750392767 std: 635.1900384911136 n: 17
# Pooled 5 measurements of MC_Apical_Dendrite_Max_Euclidean_Distance with mean: 252.3965974312837 std: 57.81990484088315 n: 52
# Pooled 5 measurements of MC_Apical_Dendrite_Max_Path_Distance with mean: 346.4060918987236 std: 91.53418287938956 n: 52
# Pooled 5 measurements of MC_Apical_Dendrite_Max_Branch_Order with mean: 8.296563324135692 std: 2.8439066284534507 n: 52
# Pooled 5 measurements of MC_Apical_Dendrite_Average_Contraction with mean: 0.7785440680193368 std: 0.15770500502877832 n: 52
# Pooled 0 measurements of MC_Apical_Dendrite_Total_Fragmentation with mean: nan std: nan n: 0
# Pooled 5 measurements of MC_Apical_Dendrite_Partition_Asymmetry with mean: 0.47144692173716124 std: 0.1500481765579963 n: 52
# Pooled 5 measurements of MC_Apical_Dendrite_Average_Ralls_Ratio with mean: 1.1964888370098983 std: 0.21069649281425723 n: 52
# Pooled 5 measurements of MC_Apical_Dendrite_Average_Bifurcation_Angle_Local with mean: 85.87710349681763 std: 14.585954654822586 n: 52
# Pooled 5 measurements of MC_Apical_Dendrite_Average_Bifurcation_Angle_Remote with mean: 68.65049665807548 std: 17.098501291576817 n: 52
# Pooled 5 measurements of MC_Apical_Dendrite_Fractal_Dimension with mean: 1.046040880392817 std: 0.12870587892026253 n: 52
# Pooled 3 measurements of TC_Soma_Surface_Area with mean: 1097.4602236714222 std: 587.272444670926 n: 37
# Pooled 3 measurements of TC_Number_of_Stems with mean: 4.228675423908468 std: 2.2062375232639733 n: 37
# Pooled 1 measurements of TC_Basal_Dendrite_Number_of_Bifurcations with mean: 4.880544202541854 std: 3.1442654328739903 n: 8
# Pooled 1 measurements of TC_Basal_Dendrite_Number_of_Branches with mean: 13.045390102253407 std: 5.615299554206159 n: 8
# Pooled 3 measurements of TC_Basal_Dendrite_Overall_Width with mean: 177.17783428091067 std: 130.9021062030309 n: 37
# Pooled 3 measurements of TC_Basal_Dendrite_Overall_Height with mean: 569.1404789949802 std: 286.6674564685436 n: 37
# Pooled 1 measurements of TC_Basal_Dendrite_Overall_Depth with mean: 77.10658453126527 std: 94.12561131508603 n: 8
# Pooled 3 measurements of TC_Basal_Dendrite_Average_Diameter with mean: 1.044144089924267 std: 0.2337507088359185 n: 37
# Pooled 1 measurements of TC_Basal_Dendrite_Total_Length with mean: 1617.0290309296097 std: 1156.4781844268798 n: 8
# Pooled 1 measurements of TC_Basal_Dendrite_Total_Surface with mean: 8368.715900704276 std: 3231.422813116347 n: 8
# Pooled 1 measurements of TC_Basal_Dendrite_Total_Volume with mean: 1663.742992975585 std: 1099.3541882008426 n: 8
# Pooled 3 measurements of TC_Basal_Dendrite_Max_Euclidean_Distance with mean: 435.19908350491096 std: 179.5615598405265 n: 37
# Pooled 3 measurements of TC_Basal_Dendrite_Max_Path_Distance with mean: 699.5624268900242 std: 236.46744783387302 n: 37
# Pooled 3 measurements of TC_Basal_Dendrite_Max_Branch_Order with mean: 2.523825727458935 std: 2.104585607172443 n: 37
# Pooled 3 measurements of TC_Basal_Dendrite_Average_Contraction with mean: 0.7122673296811768 std: 0.19498211524839187 n: 37
# Pooled 0 measurements of TC_Basal_Dendrite_Total_Fragmentation with mean: nan std: nan n: 0
# Pooled 3 measurements of TC_Basal_Dendrite_Partition_Asymmetry with mean: 0.27822427496241 std: 0.2113197033624326 n: 37
# Pooled 3 measurements of TC_Basal_Dendrite_Average_Ralls_Ratio with mean: 0.8863078149833938 std: 0.4293849951566814 n: 37
# Pooled 3 measurements of TC_Basal_Dendrite_Average_Bifurcation_Angle_Local with mean: 79.99047201212977 std: 32.04083955550747 n: 37
# Pooled 3 measurements of TC_Basal_Dendrite_Average_Bifurcation_Angle_Remote with mean: 46.44344997102077 std: 21.157360306100564 n: 37
# Pooled 3 measurements of TC_Basal_Dendrite_Fractal_Dimension with mean: 1.0300194649033438 std: 0.1357039593811114 n: 37
# Pooled 1 measurements of TC_Apical_Dendrite_Number_of_Bifurcations with mean: 23.019032479360156 std: 27.568778487823106 n: 8
# Pooled 1 measurements of TC_Apical_Dendrite_Number_of_Branches with mean: 77.70126369113282 std: 53.10035398462747 n: 8
# Pooled 3 measurements of TC_Apical_Dendrite_Overall_Width with mean: 92.0463140957275 std: 39.73091860911297 n: 37
# Pooled 3 measurements of TC_Apical_Dendrite_Overall_Height with mean: 115.51437483204977 std: 51.404720741918425 n: 37
# Pooled 1 measurements of TC_Apical_Dendrite_Overall_Depth with mean: 97.79780896848501 std: 57.83260377031701 n: 8
# Pooled 3 measurements of TC_Apical_Dendrite_Average_Diameter with mean: 0.939498059999507 std: 0.27812468694131354 n: 37
# Pooled 1 measurements of TC_Apical_Dendrite_Total_Length with mean: 1049.1284476411138 std: 478.37910473515427 n: 8
# Pooled 1 measurements of TC_Apical_Dendrite_Total_Surface with mean: 2902.0580785317507 std: 1881.725178238423 n: 8
# Pooled 1 measurements of TC_Apical_Dendrite_Total_Volume with mean: 1351.5532401118971 std: 1127.766657568623 n: 8
# Pooled 3 measurements of TC_Apical_Dendrite_Max_Euclidean_Distance with mean: 174.57230142267264 std: 44.13438344766885 n: 37
# Pooled 3 measurements of TC_Apical_Dendrite_Max_Path_Distance with mean: 273.9977081903386 std: 65.42427752980322 n: 37
# Pooled 3 measurements of TC_Apical_Dendrite_Max_Branch_Order with mean: 10.61836517253129 std: 4.809761736779623 n: 37
# Pooled 3 measurements of TC_Apical_Dendrite_Average_Contraction with mean: 0.7859248237825525 std: 0.05865639757184614 n: 37
# Pooled 0 measurements of TC_Apical_Dendrite_Total_Fragmentation with mean: nan std: nan n: 0
# Pooled 3 measurements of TC_Apical_Dendrite_Partition_Asymmetry with mean: 0.5193300331436894 std: 0.09533008600317902 n: 37
# Pooled 3 measurements of TC_Apical_Dendrite_Average_Ralls_Ratio with mean: 1.2653661479518523 std: 0.14648892398751331 n: 37
# Pooled 3 measurements of TC_Apical_Dendrite_Average_Bifurcation_Angle_Local with mean: 91.70869912664553 std: 6.8355735868556255 n: 37
# Pooled 3 measurements of TC_Apical_Dendrite_Average_Bifurcation_Angle_Remote with mean: 70.74739628947907 std: 6.257557109304874 n: 37
# Pooled 3 measurements of TC_Apical_Dendrite_Fractal_Dimension with mean: 1.066122869289228 std: 0.022239073216561895 n: 37
